# %%
from gurobipy import Model, GRB, quicksum
import pandas as pd

# Load data
tasks = pd.read_csv("./open_v2/task.csv")
#tasks= tasks[:20]
agvs = pd.read_csv("./open_v2/agv.csv")
# agvs = agvs[:3]
# === Parameters & sets ===
depot = (0, 0)
points = [(idx + 1, row['x'], row['y']) for idx, row in tasks.iterrows()]
points = [(0, *depot)] + points + [(len(points) + 1, *depot)]

distance = {
    i_idx: {
        j_idx: abs(i_x - j_x) + abs(i_y - j_y)
        for j_idx, j_x, j_y in points
    }
    for i_idx, i_x, i_y in points
}

NODE = len(tasks) + 2
K = list(range(len(agvs)))
N = list(range(1, len(points) - 1))
N_s = list(range(0, len(points) - 1))
N_t = list(range(0, len(points)))
N_s_t = list(range(0, len(points)))
# T_max = [int(tasks['demand'].sum() // agvs.iloc[i]['capacity']) for i in range(len(agvs))]
T_max = [4 for _ in range(len(agvs))]

v = agvs['speed_cells_per_sec'].tolist()
Q = agvs['capacity'].tolist()
D = agvs['max_distance'].tolist()
s = [0] + tasks['service_time'].tolist() + [0]
u = [0] + tasks['demand'].tolist() + [0]
deadlines = [0] + tasks['deadline'].tolist() + [0]
demand_max = max(tasks['demand'])
dead_line_max = max(tasks['deadline'])
M = 1000
alpha, beta = 1, 2

# %%
# === Build Gurobi model ===
model = Model("Corrected_AGV_Routing")
x, y, o, t = {}, {}, {}, {}

for k in K:
    for r in range(T_max[k]):
        for i in N_s_t:
            for j in N_s_t:
                if i != j:
                    x[k, i, j, r] = model.addVar(vtype=GRB.BINARY, name=f"x_{k}_{i}_{j}_{r}")
        for i in N_s_t:
            y[k, i, r] = model.addVar(vtype=GRB.BINARY, name=f"y_{k}_{i}_{r}")
            o[k, i, r] = model.addVar(vtype=GRB.INTEGER, name=f"o_{k}_{i}_{r}")
            t[k, i, r] = model.addVar(vtype=GRB.CONTINUOUS, name=f"t_{k}_{i}_{r}")

late = {}
for i in N:
    late[i] = model.addVar(vtype=GRB.CONTINUOUS, name=f"late_{i}")

model.update()

# === Constraints ===

# 1. Start depot only once

for k in K:
    model.addConstr(quicksum(x[k, 0, j, 0] for j in N ) == 1)

for k in K:
    for r in range(T_max[k]):
        for j in N:
            model.addConstr(quicksum(x[k, i, j, r] for i in N_s if i != j ) == quicksum(x[k, j, i, r] for i in N_t if i != j ))


for k in K:
    for r in range(T_max[k]):
        for j in N_t:
            model.addConstr(quicksum(x[k, i, j, r] for i in N_s if i != j ) == y[k, j, r])

# 3. Time sequencing (big-M)
for k in K:
    for r in range(T_max[k]):
        for i in N_s:
            for j in N_t:
                if i != j :
                    # Replace the big-M constraint with this:
                    model.addConstr(
                        (x[k, i, j, r] == 1) >> 
                        (t[k, j, r] >= t[k, i, r] + distance[i][j] / v[k] + s[i])
                    )

# New, more direct capacity constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(
            quicksum(u[i] * y[k, i, r] for i in N) <= Q[k]
        )

# 6. Distance constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(quicksum(distance[i][j] * x[k, i, j, r] for i in N_s_t for j in N_s_t if i != j ) <= D[k])

# 7. Each task must be served at least once
for j in N:
    model.addConstr(quicksum(y[k, j, r] for k in K for r in range(T_max[k])) == 1)

# 8. Start times are 0
for k in K:
    model.addConstr(t[k, 0, 0] == 0)

# Remove the old lateness constraints and use this instead:
for i in N:
    for k in K:
        for r in range(T_max[k]):
            # The lateness constraint for node 'i' is only active IF vehicle 'k' visits it on trip 'r'
            model.addConstr(
                (y[k, i, r] == 1) >>
                (late[i] >= t[k, i, r] - deadlines[i])
            )

# You still need this to ensure lateness is non-negative
for i in N:
    model.addConstr(late[i] >= 0)
for k in K:
    for r in range(1, T_max[k]):
        # (r-1)번째 경로의 '최종 목적지' 도착 시간이 (r)번째 경로의 '출발지' 출발 시간보다 작거나 같아야 함
        model.addConstr(t[k, N_t[-1], r-1] <= t[k, 0, r])           

tardiness = quicksum(late[i] for i in N)

travel_cost = quicksum(
    (distance[i][j] / v[k]) * x[k, i, j, r]
    for k in K for r in range(T_max[k])
    for i in N_s_t for j in N_s_t
    if i != j
)
# model.addConstr(alpha * travel_cost + beta * tardiness >= 5000)
# === Objective ===
model.setObjective(alpha * travel_cost + beta * tardiness, GRB.MINIMIZE)
model.setParam(GRB.Param.TimeLimit, 3600*3)
model.Params.MIPFocus     = 1       # lean to finding high-quality incumbents quickly
model.Params.Presolve     = 2  
# model.Params.Heuristics = 0.9  # Try increasing heuristic effort
# === Solve ===

USER_UB = 12000
model.setParam(GRB.Param.Cutoff, USER_UB)

model.optimize()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2636023
# Academic license - for non-commercial use only - expires 2026-03-13
# Set parameter TimeLimit to value 10800
# Set parameter MIPFocus to value 1
# Set parameter Presolve to value 2
# Set parameter Cutoff to value 12000
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# Cutoff  12000
# TimeLimit  10800
# MIPFocus  1
# Presolve  2
#
# Optimize a model with 12515 rows, 636580 columns and 2455885 nonzeros
# Model fingerprint: 0xe99496bf
# Model has 618060 simple general constraints
#   618060 INDICATOR
# Variable types: 6220 continuous, 630360 integer (624240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [5e-01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   GenCon rhs range [7e+00, 7e+02]
#   GenCon coe range [1e+00, 1e+00]
# Presolve removed 3235 rows and 16995 columns (presolve time = 5s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 10s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 15s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 20s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 25s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 30s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 35s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 40s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 45s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 50s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 55s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 60s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 65s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 70s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 75s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 80s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 85s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 90s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 95s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 100s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 105s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 110s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 115s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 120s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 125s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 130s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 135s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 140s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 145s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 150s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 155s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 160s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 165s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 170s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 175s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 180s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 185s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 190s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 195s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 200s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 205s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 210s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 215s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 220s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 225s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 230s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 235s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 240s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 245s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 250s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 255s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 260s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 265s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 270s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 275s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 280s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 285s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 290s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 295s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 300s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 305s)...
# Presolve removed 3235 rows and 16995 columns (presolve time = 324s)...
# Presolve removed 5335 rows and 19095 columns (presolve time = 325s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 330s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 335s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 340s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 345s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 350s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 355s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 360s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 365s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 370s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 375s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 380s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 385s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 390s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 395s)...
# Presolve removed 142079 rows and 292223 columns (presolve time = 537s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 540s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 545s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 550s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 555s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 560s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 565s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 570s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 575s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 580s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 585s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 590s)...
# Presolve removed 142079 rows and 292343 columns (presolve time = 595s)...
# Presolve removed 142079 rows and 292343 columns (presolve time =
#  14611 12399  740.66667   80  274          -  720.90000      -  54.6 9167s
#  14731 12632  738.00000   81  232          -  720.90000      -  56.2 9216s
#  15004 12667  738.00000   83  223          -  720.90000      -  58.9 9275s
#  15130 12753  745.50000   87  172          -  720.90000      -  60.9 9330s
#  15258 12979  745.50000   89  166          -  720.90000      -  62.9 9387s
#  15527 13018  746.33333  100  140          -  720.90000      -  66.7 9453s
#  15656 13108  746.33333  102  151          -  720.90000      -  69.1 9525s
#  15789 13260  778.46667  103  206          -  720.90000      -  71.7 9590s
#  15985 13267  746.20000  107  146          -  720.90000      -  74.6 9744s
#  16057 13445  746.33333  108  147          -  720.90000      -  75.5 9817s
#  16259 13611  747.75000  109  169          -  720.90000      -  78.2 9887s
#  16497 13878  747.95000  112  207          -  720.90000      -  81.2 9952s
#  16843 13998  749.75000  118  153          -  720.90000      -  85.3 10032s
#  17084 14171  754.50000  124  130          -  720.90000      -  88.4 10100s
#  17376 14323  750.85714  128  214          -  720.90000      -  91.0 10165s
#  17683 14569  751.50000  132  120          -  720.90000      -  93.5 10223s
#  18079 14712  753.00000  140   94          -  720.90000      -  95.9 10290s
#  18402 14913  759.00000  144  108          -  720.90000      -  98.2 10355s
#  18759 15140  765.00000  152   92          -  720.90000      -   100 10403s
#  19171 15283  863.00000  157   89          -  720.90000      -   103 10469s
#  19525 15489  893.00000  163   87          -  720.90000      -   105 10538s

# %%
# === AGV 별 전체 경로 문자열로 저장 ===
from collections import defaultdict

# 경로 재구성
agv_routes = defaultdict(lambda: defaultdict(list))  # agv_routes[k][r] = [(i, j)]

if model.status in [GRB.OPTIMAL, GRB.TIME_LIMIT, GRB.INTERRUPTED]:
    for k in K:
        for r in range(T_max[k]):
            arcs = []
            for i in N_s_t:
                for j in N_s_t:
                    if i != j and (k, i, j, r) in x and x[k, i, j, r].X > 0.5:
                        arcs.append((i, j))
            if arcs:
                agv_routes[k][r] = arcs

    # 각 AGV별 경로 정렬 및 문자열화
    final_paths = []
    for k in agv_routes:
        full_path = []
        used = set()
        for r in sorted(agv_routes[k].keys()):
            arcs = agv_routes[k][r]
            # 경로를 순서대로 정렬
            route = []
            current = 0  # depot에서 시작
            while True:
                next_nodes = [j for (i, j) in arcs if i == current and (i, j) not in used]
                if not next_nodes:
                    break
                next_node = next_nodes[0]
                route.append(next_node)
                used.add((current, next_node))
                current = next_node
            # 노드 이름 포맷 변경: 0 → DEPOT, others → T 00XX
            formatted = ["DEPOT"]
            for node in route:
                if node == 0 or node == len(N_s_t) - 1:
                    formatted.append("DEPOT")
                else:
                    formatted.append(f"T{node:04d}")
            full_path.extend(formatted)

        # 중복 DEPOT 제거
        clean_path = [full_path[0]]
        for node in full_path[1:]:
            if node != "DEPOT" or clean_path[-1] != "DEPOT":
                clean_path.append(node)

        final_paths.append({
            "agv_id": f"A{k+1:03d}",
            "route": ",".join(clean_path)
        })

    # CSV 저장
    path_df = pd.DataFrame(final_paths)
    output_path = "0930_agv_routes_formatted_1.csv"
    path_df.to_csv(output_path, index=False)
    print(f"📁 AGV 경로가 저장되었습니다: {output_path}")
else:
    print("⚠️ 최적 해를 찾지 못했기 때문에 경로를 저장하지 않습니다.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      11 for i in N_s_t:
#      12     for j in N_s_t:
# ---> 13         if i != j and (k, i, j, r) in x and x[k, i, j, r].X > 0.5:
#      14             arcs.append((i, j))
#      15 if arcs:
#
# File src\\gurobipy\\var.pxi:128, in gurobipy._core.Var.__getattr__()
#
# File src\\gurobipy\\var.pxi:156, in gurobipy._core.Var.getAttr()
#
# File src\\gurobipy\\_attrutil.pyx:117, in gurobipy._attrutil._getattr()
#
# AttributeError: Unable to retrieve attribute 'X'

# %%
import matplotlib.pyplot as plt

# 좌표 dict로 변환 (노드 번호 → (x, y))
coord = {i: (x, y) for i, x, y in points}

plt.figure(figsize=(12, 8))

# 모든 노드를 scatter
for i, (xi, yi) in coord.items():
    plt.scatter(xi, yi, c='black', zorder=3)
    plt.text(xi + 0.5, yi + 0.5, f"{i}", fontsize=9)

colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan', 'magenta', 'brown']

for k in K:
    for r in range(T_max[k]):
        route_color = colors[(k * 3 + r) % len(colors)]
        for i in coord:
            for j in coord:
                if i != j and (k, i, j, r) in x:
                    if x[k, i, j, r].X > 0.5:
                        xi, yi = coord[i]
                        xj, yj = coord[j]
                        plt.arrow(xi, yi, xj - xi, yj - yi, 
                                    head_width=1, length_includes_head=True, 
                                    color=route_color, alpha=0.7, zorder=2)
        plt.plot([], [], color=route_color, label=f"AGV {k}, Route {r}")

plt.title("AGV Routing Plan")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
# plt.legend()
plt.axis("equal")
plt.show()

# %%
k = 2
r = 1
for i in N_s_t:
    for j in N_s_t:
        if i!=j and x[k,i,j,r].x > 0.5:
            print(k,r,i,j)
print("=====================")
 
for i in N_s_t:
    if o[k,i,r].x > 0.5:
        print(k,r,i,o[k,i,r].x)
# Out:
# 2 1 0 7
# 2 1 7 17
# 2 1 17 21
# =====================

# %%
t
# Out:
# {(0, 0, 0): <gurobi.Var t_0_0_0 (value 0.0)>,
#  (0, 1, 0): <gurobi.Var t_0_1_0 (value 97.0)>,
#  (0, 2, 0): <gurobi.Var t_0_2_0 (value 86.5)>,
#  (0, 3, 0): <gurobi.Var t_0_3_0 (value 8.0)>,
#  (0, 4, 0): <gurobi.Var t_0_4_0 (value 6.0)>,
#  (0, 5, 0): <gurobi.Var t_0_5_0 (value 14.5)>,
#  (0, 6, 0): <gurobi.Var t_0_6_0 (value 0.0)>,
#  (0, 7, 0): <gurobi.Var t_0_7_0 (value 87.0)>,
#  (0, 8, 0): <gurobi.Var t_0_8_0 (value 0.0)>,
#  (0, 9, 0): <gurobi.Var t_0_9_0 (value 13.5)>,
#  (0, 10, 0): <gurobi.Var t_0_10_0 (value 0.0)>,
#  (0, 11, 0): <gurobi.Var t_0_11_0 (value 0.0)>,
#  (0, 12, 0): <gurobi.Var t_0_12_0 (value 48.5)>,
#  (0, 13, 0): <gurobi.Var t_0_13_0 (value 0.0)>,
#  (0, 14, 0): <gurobi.Var t_0_14_0 (value 133.0)>,
#  (0, 15, 0): <gurobi.Var t_0_15_0 (value 25.0)>,
#  (0, 16, 0): <gurobi.Var t_0_16_0 (value 37.0)>,
#  (0, 17, 0): <gurobi.Var t_0_17_0 (value 26.5)>,
#  (0, 18, 0): <gurobi.Var t_0_18_0 (value 0.0)>,
#  (0, 19, 0): <gurobi.Var t_0_19_0 (value 29.0)>,
#  (0, 20, 0): <gurobi.Var t_0_20_0 (value 0.0)>,
#  (0, 21, 0): <gurobi.Var t_0_21_0 (value 245.0)>,
#  (0, 0, 1): <gurobi.Var t_0_0_1 (value 245.0)>,
#  (0, 1, 1): <gurobi.Var t_0_1_1 (value 0.0)>,
#  (0, 2, 1): <gurobi.Var t_0_2_1 (value 0.0)>,
#  (0, 3, 1): <gurobi.Var t_0_3_1 (value 0.0)>,
#  (0, 4, 1): <gurobi.Var t_0_4_1 (value 0.0)>,
#  (0, 5, 1): <gurobi.Var t_0_5_1 (value 0.0)>,
#  (0, 6, 1): <gurobi.Var t_0_6_1 (value 0.0)>,
#  (0, 7, 1): <gurobi.Var t_0_7_1 (value 0.0)>,
#  (0, 8, 1): <gurobi.Var t_0_8_1 (value 0.0)>,
#  (0, 9, 1): <gurobi.Var t_0_9_1 (value 0.0)>,
#  (0, 10, 1): <gurobi.Var t_0_10_1 (value 0.0)>,
#  (0, 11, 1): <gurobi.Var t_0_11_1 (value 0.0)>,
#  (0, 12, 1): <gurobi.Var t_0_12_1 (value 0.0)>,
#  (0, 13, 1): <gurobi.Var t_0_13_1 (value 0.0)>,
#  (0, 14, 1): <gurobi.Var t_0_14_1 (value 0.0)>,
#  (0, 15, 1): <gurobi.Var t_0_15_1 (value 0.0)>,
#  (0, 16, 1): <gurobi.Var t_0_16_1 (value 0.0)>,
#  (0, 17, 1): <gurobi.Var t_0_17_1 (value 0.0)>,
#  (0, 18, 1): <gurobi.Var t_0_18_1 (value 281.5)>,
#  (0, 19, 1): <gurobi.Var t_0_19_1 (value 0.0)>,
#  (0, 20, 1): <gurobi.Var t_0_20_1 (value 0.0)>,
#  (0, 21, 1): <gurobi.Var t_0_21_1 (value 394.0)>,
#  (0, 0, 2): <gurobi.Var t_0_0_2 (value 394.0)>,
#  (0, 1, 2): <gurobi.Var t_0_1_2 (value 0.0)>,
#  (0, 2, 2): <gurobi.Var t_0_2_2 (value 0.0)>,
#  (0, 3, 2): <gurobi.Var t_0_3_2 (value 0.0)>,
#  (0, 4, 2): <gurobi.Var t_0_4_2 (value 479.5)>,
#  (0, 5, 2): <gurobi.Var t_0_5_2 (value 418.0)>,
#  (0, 6, 2): <gurobi.Var t_0_6_2 (value 565.5)>,
#  (0, 7, 2): <gurobi.Var t_0_7_2 (value 0.0)>,
#  (0, 8, 2): <gurobi.Var t_0_8_2 (value 0.0)>,
#  (0, 9, 2): <gurobi.Var t_0_9_2 (value 0.0)>,
#  (0, 10, 2): <gurobi.Var t_0_10_2 (value 638.5)>,
#  (0, 11, 2): <gurobi.Var t_0_11_2 (value 0.0)>,
#  (0, 12, 2): <gurobi.Var t_0_12_2 (value 0.0)>,
#  (0, 13, 2): <gurobi.Var t_0_13_2 (value 0.0)>,
#  (0, 14, 2): <gurobi.Var t_0_14_2 (value 0.0)>,
#  (0, 15, 2): <gurobi.Var t_0_15_2 (value 0.0)>,
#  (0, 16, 2): <gurobi.Var t_0_16_2 (value 0.0)>,
#  (0, 17, 2): <gurobi.Var t_0_17_2 (value 0.0)>,
#  (0, 18, 2): <gurobi.Var t_0_18_2 (value 0.0)>,
#  (0, 19, 2): <gurobi.Var t_0_19_2 (value 0.0)>,
#  (0, 20, 2): <gurobi.Var t_0_20_2 (value 0.0)>,
#  (0, 21, 2): <gurobi.Var t_0_21_2 (value 769.0)>,
#  (0, 0, 3): <gurobi.Var t_0_0_3 (value 769.0)>,
#  (0, 1, 3): <gurobi.Var t_0_1_3 (value 0.0)>,
#  (0, 2, 3): <gurobi.Var t_0_2_3 (value 0.0)>,
#  (0, 3, 3): <gurobi.Var t_0_3_3 (value 0.0)>,
#  (0, 4, 3): <gurobi.Var t_0_4_3 (value 0.0)>,
#  (0, 5, 3): <gurobi.Var t_0_5_3 (value 0.0)>,
#  (0, 6, 3): <gurobi.Var t_0_6_3 (value 0.0)>,
#  (0, 7, 3): <gurobi.Var t_0_7_3 (value 0.0)>,
#  (0, 8, 3): <gurobi.Var t_0_8_3 (value 0.0)>,
#  (0, 9, 3): <gurobi.Var t_0_9_3 (value 0.0)>,
#  (0, 10, 3): <gurobi.Var t_0_10_3 (value 0.0)>,
#  (0, 11, 3): <gurobi.Var t_0_11_3 (value 0.0)>,
#  (0, 12, 3): <gurobi.Var t_0_12_3 (value 0.0)>,
#  (0, 13, 3): <gurobi.Var t_0_13_3 (value 0.0)>,
#  (0, 14, 3): <gurobi.Var t_0_14_3 (value 0.0)>,
#  (0, 15, 3): <gurobi.Var t_0_15_3 (value 0.0)>,
#  (0, 16, 3): <gurobi.Var t_0_16_3 (value 0.0)>,
#  (0, 17, 3): <gurobi.Var t_0_17_3 (value 0.0)>,
#  (0, 18, 3): <gurobi.Var t_0_18_3 (value 0.0)>,
#  (0, 19, 3): <gurobi.Var t_0_19_3 (value 0.0)>,
#  (0, 20, 3): <gurobi.Var t_0_20_3 (value 0.0)>,
#  (0, 21, 3): <gurobi.Var t_0_21_3 (value 769.0)>,
#  (1, 0, 0): <gurobi.Var t_1_0_0 (value 0.0)>,
#  (1, 1, 0): <gurobi.Var t_1_1_0 (value 1.0)>,
#  (1, 2, 0): <gurobi.Var t_1_2_0 (value 0.0)>,
#  (1, 3, 0): <gurobi.Var t_1_3_0 (value 0.0)>,
#  (1, 4, 0): <gurobi.Var t_1_4_0 (value 0.0)>,
#  (1, 5, 0): <gurobi.Var t_1_5_0 (value 9.0)>,
#  (1, 6, 0): <gurobi.Var t_1_6_0 (value 0.0)>,
#  (1, 7, 0): <gurobi.Var t_1_7_0 (value 0.0)>,
#  (1, 8, 0): <gurobi.Var t_1_8_0 (value 0.0)>,
#  (1, 9, 0): <gurobi.Var t_1_9_0 (value -0.0)>,
#  (1, 10, 0): <gurobi.Var t_1_10_0 (value 0.0)>,
#  (1, 11, 0): <gurobi.Var t_1_11_0 (value -0.0)>,
#  (1, 12, 0): <gurobi.Var t_1_12_0 (value -0.0)>,
#  (1, 13, 0): <gurobi.Var t_1_13_0 (value 0.0)>,
#  (1, 14, 0): <gurobi.Var t_1_14_0 (value 0.0)>,
#  (1, 15, 0): <gurobi.Var t_1_15_0 (value 72.0)>,
#  (1, 16, 0): <gurobi.Var t_1_16_0 (value 0.0)>,
#  (1, 17, 0): <gurobi.Var t_1_17_0 (value -0.0)>,
#  (1, 18, 0): <gurobi.Var t_1_18_0 (value -0.0)>,
#  (1, 19, 0): <gurobi.Var t_1_19_0 (value 0.0)>,
#  (1, 20, 0): <gurobi.Var t_1_20_0 (value 34.0)>,
#  (1, 21, 0): <gurobi.Var t_1_21_0 (value 87.0)>,
#  (1, 0, 1): <gurobi.Var t_1_0_1 (value 87.0)>,
#  (1, 1, 1): <gurobi.Var t_1_1_1 (value 0.0)>,
#  (1, 2, 1): <gurobi.Var t_1_2_1 (value 0.0)>,
#  (1, 3, 1): <gurobi.Var t_1_3_1 (value 0.0)>,
#  (1, 4, 1): <gurobi.Var t_1_4_1 (value 0.0)>,
#  (1, 5, 1): <gurobi.Var t_1_5_1 (value 0.0)>,
#  (1, 6, 1): <gurobi.Var t_1_6_1 (value 0.0)>,
#  (1, 7, 1): <gurobi.Var t_1_7_1 (value 0.0)>,
#  (1, 8, 1): <gurobi.Var t_1_8_1 (value 0.0)>,
#  (1, 9, 1): <gurobi.Var t_1_9_1 (value 0.0)>,
#  (1, 10, 1): <gurobi.Var t_1_10_1 (value 0.0)>,
#  (1, 11, 1): <gurobi.Var t_1_11_1 (value 0.0)>,
#  (1, 12, 1): <gurobi.Var t_1_12_1 (value 0.0)>,
#  (1, 13, 1): <gurobi.Var t_1_13_1 (value 0.0)>,
#  (1, 14, 1): <gurobi.Var t_1_14_1 (value 0.0)>,
#  (1, 15, 1): <gurobi.Var t_1_15_1 (value 0.0)>,
#  (1, 16, 1): <gurobi.Var t_1_16_1 (value 0.0)>,
#  (1, 17, 1): <gurobi.Var t_1_17_1 (value 0.0)>,
#  (1, 18, 1): <gurobi.Var t_1_18_1 (value 0.0)>,
#  (1, 19, 1): <gurobi.Var t_1_19_1 (value 0.0)>,
#  (1, 20, 1): <gurobi.Var t_1_20_1 (value 0.0)>,
#  (1, 21, 1): <gurobi.Var t_1_21_1 (value 0.0)>,
#  (1, 0, 2): <gurobi.Var t_1_0_2 (value 0.0)>,
#  (1, 1, 2): <gurobi.Var t_1_1_2 (value 0.0)>,
#  (1, 2, 2): <gurobi.Var t_1_2_2 (value 0.0)>,
#  (1, 3, 2): <gurobi.Var t_1_3_2 (value 0.0)>,
#  (1, 4, 2): <gurobi.Var t_1_4_2 (value 0.0)>,
#  (1, 5, 2): <gurobi.Var t_1_5_2 (value 0.0)>,
#  (1, 6, 2): <gurobi.Var t_1_6_2 (value 0.0)>,
#  (1, 7, 2): <gurobi.Var t_1_7_2 (value 0.0)>,
#  (1, 8, 2): <gurobi.Var t_1_8_2 (value 59.0)>,
#  (1, 9, 2): <gurobi.Var t_1_9_2 (value 0.0)>,
#  (1, 10, 2): <gurobi.Var t_1_10_2 (value 0.0)>,
#  (1, 11, 2): <gurobi.Var t_1_11_2 (value 0.0)>,
#  (1, 12, 2): <gurobi.Var t_1_12_2 (value 0.0)>,
#  (1, 13, 2): <gurobi.Var t_1_13_2 (value 0.0)>,
#  (1, 14, 2): <gurobi.Var t_1_14_2 (value 0.0)>,
#  (1, 15, 2): <gurobi.Var t_1_15_2 (value 131.0)>,
#  (1, 16, 2): <gurobi.Var t_1_16_2 (value 0.0)>,
#  (1, 17, 2): <gurobi.Var t_1_17_2 (value 0.0)>,
#  (1, 18, 2): <gurobi.Var t_1_18_2 (value 0.0)>,
#  (1, 19, 2): <gurobi.Var t_1_19_2 (value 0.0)>,
#  (1, 20, 2): <gurobi.Var t_1_20_2 (value 0.0)>,
#  (1, 21, 2): <gurobi.Var t_1_21_2 (value 287.0)>,
#  (1, 0, 3): <gurobi.Var t_1_0_3 (value 287.0)>,
#  (1, 1, 3): <gurobi.Var t_1_1_3 (value 0.0)>,
#  (1, 2, 3): <gurobi.Var t_1_2_3 (value 0.0)>,
#  (1, 3, 3): <gurobi.Var t_1_3_3 (value 0.0)>,
#  (1, 4, 3): <gurobi.Var t_1_4_3 (value 0.0)>,
#  (1, 5, 3): <gurobi.Var t_1_5_3 (value 0.0)>,
#  (1, 6, 3): <gurobi.Var t_1_6_3 (value 0.0)>,
#  (1, 7, 3): <gurobi.Var t_1_7_3 (value 0.0)>,
#  (1, 8, 3): <gurobi.Var t_1_8_3 (value 0.0)>,
#  (1, 9, 3): <gurobi.Var t_1_9_3 (value 0.0)>,
#  (1, 10, 3): <gurobi.Var t_1_10_3 (value 0.0)>,
#  (1, 11, 3): <gurobi.Var t_1_11_3 (value 0.0)>,
#  (1, 12, 3): <gurobi.Var t_1_12_3 (value 0.0)>,
#  (1, 13, 3): <gurobi.Var t_1_13_3 (value 0.0)>,
#  (1, 14, 3): <gurobi.Var t_1_14_3 (value 0.0)>,
#  (1, 15, 3): <gurobi.Var t_1_15_3 (value 0.0)>,
#  (1, 16, 3): <gurobi.Var t_1_16_3 (value 0.0)>,
#  (1, 17, 3): <gurobi.Var t_1_17_3 (value 0.0)>,
#  (1, 18, 3): <gurobi.Var t_1_18_3 (value 0.0)>,
#  (1, 19, 3): <gurobi.Var t_1_19_3 (value 0.0)>,
#  (1, 20, 3): <gurobi.Var t_1_20_3 (value 0.0)>,
#  (1, 21, 3): <gurobi.Var t_1_21_3 (value 287.0)>,
#  (2, 0, 0): <gurobi.Var t_2_0_0 (value 0.0)>,
#  (2, 1, 0): <gurobi.Var t_2_1_0 (value 0.0)>,
#  (2, 2, 0): <gurobi.Var t_2_2_0 (value 0.0)>,
#  (2, 3, 0): <gurobi.Var t_2_3_0 (value 0.0)>,
#  (2, 4, 0): <gurobi.Var t_2_4_0 (value 0.0)>,
#  (2, 5, 0): <gurobi.Var t_2_5_0 (value 0.0)>,
#  (2, 6, 0): <gurobi.Var t_2_6_0 (value 0.0)>,
#  (2, 7, 0): <gurobi.Var t_2_7_0 (value 0.0)>,
#  (2, 8, 0): <gurobi.Var t_2_8_0 (value 32.5)>,
#  (2, 9, 0): <gurobi.Var t_2_9_0 (value 0.0)>,
#  (2, 10, 0): <gurobi.Var t_2_10_0 (value 0.0)>,
#  (2, 11, 0): <gurobi.Var t_2_11_0 (value 0.0)>,
#  (2, 12, 0): <gurobi.Var t_2_12_0 (value 50.5)>,
#  (2, 13, 0): <gurobi.Var t_2_13_0 (value 0.0)>,
#  (2, 14, 0): <gurobi.Var t_2_14_0 (value 0.0)>,
#  (2, 15, 0): <gurobi.Var t_2_15_0 (value 7.0)>,
#  (2, 16, 0): <gurobi.Var t_2_16_0 (value 20.0)>,
#  (2, 17, 0): <gurobi.Var t_2_17_0 (value 121.5)>,
#  (2, 18, 0): <gurobi.Var t_2_18_0 (value 0.0)>,
#  (2, 19, 0): <gurobi.Var t_2_19_0 (value 130.0)>,
#  (2, 20, 0): <gurobi.Var t_2_20_0 (value 0.0)>,
#  (2, 21, 0): <gurobi.Var t_2_21_0 (value 236.0)>,
#  (2, 0, 1): <gurobi.Var t_2_0_1 (value 236.0)>,
#  (2, 1, 1): <gurobi.Var t_2_1_1 (value 0.0)>,
#  (2, 2, 1): <gurobi.Var t_2_2_1 (value 0.0)>,
#  (2, 3, 1): <gurobi.Var t_2_3_1 (value 0.0)>,
#  (2, 4, 1): <gurobi.Var t_2_4_1 (value 0.0)>,
#  (2, 5, 1): <gurobi.Var t_2_5_1 (value 0.0)>,
#  (2, 6, 1): <gurobi.Var t_2_6_1 (value 0.0)>,
#  (2, 7, 1): <gurobi.Var t_2_7_1 (value 277.5)>,
#  (2, 8, 1): <gurobi.Var t_2_8_1 (value 0.0)>,
#  (2, 9, 1): <gurobi.Var t_2_9_1 (value 0.0)>,
#  (2, 10, 1): <gurobi.Var t_2_10_1 (value 0.0)>,
#  (2, 11, 1): <gurobi.Var t_2_11_1 (value 0.0)>,
#  (2, 12, 1): <gurobi.Var t_2_12_1 (value 0.0)>,
#  (2, 13, 1): <gurobi.Var t_2_13_1 (value 0.0)>,
#  (2, 14, 1): <gurobi.Var t_2_14_1 (value 0.0)>,
#  (2, 15, 1): <gurobi.Var t_2_15_1 (value 0.0)>,
#  (2, 16, 1): <gurobi.Var t_2_16_1 (value 0.0)>,
#  (2, 17, 1): <gurobi.Var t_2_17_1 (value 367.5)>,
#  (2, 18, 1): <gurobi.Var t_2_18_1 (value 0.0)>,
#  (2, 19, 1): <gurobi.Var t_2_19_1 (value 0.0)>,
#  (2, 20, 1): <gurobi.Var t_2_20_1 (value 0.0)>,
#  (2, 21, 1): <gurobi.Var t_2_21_1 (value 417.0)>,
#  (2, 0, 2): <gurobi.Var t_2_0_2 (value 417.0)>,
#  (2, 1, 2): <gurobi.Var t_2_1_2 (value 590.5)>,
#  (2, 2, 2): <gurobi.Var t_2_2_2 (value 632.0)>,
#  (2, 3, 2): <gurobi.Var t_2_3_2 (value 0.0)>,
#  (2, 4, 2): <gurobi.Var t_2_4_2 (value 0.0)>,
#  (2, 5, 2): <gurobi.Var t_2_5_2 (value 0.0)>,
#  (2, 6, 2): <gurobi.Var t_2_6_2 (value 0.0)>,
#  (2, 7, 2): <gurobi.Var t_2_7_2 (value 0.0)>,
#  (2, 8, 2): <gurobi.Var t_2_8_2 (value 0.0)>,
#  (2, 9, 2): <gurobi.Var t_2_9_2 (value 0.0)>,
#  (2, 10, 2): <gurobi.Var t_2_10_2 (value 0.0)>,
#  (2, 11, 2): <gurobi.Var t_2_11_2 (value 443.5)>,
#  (2, 12, 2): <gurobi.Var t_2_12_2 (value 0.0)>,
#  (2, 13, 2): <gurobi.Var t_2_13_2 (value 716.0)>,
#  (2, 14, 2): <gurobi.Var t_2_14_2 (value 0.0)>,
#  (2, 15, 2): <gurobi.Var t_2_15_2 (value 0.0)>,
#  (2, 16, 2): <gurobi.Var t_2_16_2 (value 0.0)>,
#  (2, 17, 2): <gurobi.Var t_2_17_2 (value 0.0)>,
#  (2, 18, 2): <gurobi.Var t_2_18_2 (value 0.0)>,
#  (2, 19, 2): <gurobi.Var t_2_19_2 (value 0.0)>,
#  (2, 20, 2): <gurobi.Var t_2_20_2 (value 0.0)>,
#  (2, 21, 2): <gurobi.Var t_2_21_2 (value 798.0)>,
#  (2, 0, 3): <gurobi.Var t_2_0_3 (value 798.0)>,
#  (2, 1, 3): <gurobi.Var t_2_1_3 (value 0.0)>,
#  (2, 2, 3): <gurobi.Var t_2_2_3 (value 0.0)>,
#  (2, 3, 3): <gurobi.Var t_2_3_3 (value 0.0)>,
#  (2, 4, 3): <gurobi.Var t_2_4_3 (value 0.0)>,
#  (2, 5, 3): <gurobi.Var t_2_5_3 (value 0.0)>,
#  (2, 6, 3): <gurobi.Var t_2_6_3 (value 0.0)>,
#  (2, 7, 3): <gurobi.Var t_2_7_3 (value 0.0)>,
#  (2, 8, 3): <gurobi.Var t_2_8_3 (value 0.0)>,
#  (2, 9, 3): <gurobi.Var t_2_9_3 (value 832.0)>,
#  (2, 10, 3): <gurobi.Var t_2_10_3 (value 0.0)>,
#  (2, 11, 3): <gurobi.Var t_2_11_3 (value 0.0)>,
#  (2, 12, 3): <gurobi.Var t_2_12_3 (value 882.5)>,
#  (2, 13, 3): <gurobi.Var t_2_13_3 (value 0.0)>,
#  (2, 14, 3): <gurobi.Var t_2_14_3 (value 0.0)>,
#  (2, 15, 3): <gurobi.Var t_2_15_3 (value 0.0)>,
#  (2, 16, 3): <gurobi.Var t_2_16_3 (value 0.0)>,
#  (2, 17, 3): <gurobi.Var t_2_17_3 (value 0.0)>,
#  (2, 18, 3): <gurobi.Var t_2_18_3 (value 0.0)>,
#  (2, 19, 3): <gurobi.Var t_2_19_3 (value 0.0)>,
#  (2, 20, 3): <gurobi.Var t_2_20_3 (value 0.0)>,
#  (2, 21, 3): <gurobi.Var t_2_21_3 (value 1014.0)>}
