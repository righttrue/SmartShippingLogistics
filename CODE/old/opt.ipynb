# %%
import pandas as pd
import gurobipy as gp
from gurobipy import Model, GRB, quicksum

# %%
import numpy as np

# %%
# Load data
tasks = pd.read_csv("./open_v2/task.csv")
# tasks = tasks[:30]  # for small instance
agvs = pd.read_csv("./open_v2/agv.csv")

# %%
agvs
# Out:
#    agv_id  speed_cells_per_sec  max_distance  capacity
# 0    A001                    2           878         7
# 1    A002                    1           875         3
# 2    A003                    2           864         7
# 3    A004                    2           787         5
# 4    A005                    2           867         5
# 5    A006                    1           837         4
# 6    A007                    1           767         7
# 7    A008                    1           452         3
# 8    A009                    1           564         3
# 9    A010                    1           568         7
# 10   A011                    1           549         6
# 11   A012                    1           770         7
# 12   A013                    2           611         6
# 13   A014                    2           772         7
# 14   A015                    1           931         4

# %%
# depot 좌표
depot = (0, 0)

# 원래 task들을 1 ~ N까지 인덱스로 매핑
points = [(idx+1, row['x'], row['y']) for idx, row in tasks.iterrows()]

# depot을 맨 앞(0)과 마지막(N+1)에 추가
points = [(0, *depot)] + points + [(len(points)+1, *depot)]

# distance[i][j] 딕셔너리 생성
distance = {}
for i_idx, i_x, i_y in points:
    distance[i_idx] = {}
    for j_idx, j_x, j_y in points:
        distance[i_idx][j_idx] = abs(i_x - j_x) + abs(i_y - j_y)

# %%
NODE = len(tasks) + 2 # customer nodes + depot(start/end)
K = [k for k in range(0,len(agvs))]
N = [node for node in range(1,len(points)-1)]
N_s = [node for node in range(0,len(points)-1)]
N_t = [node for node in range(0,len(points))]
N_s_t = [node for node in range(0,len(points))]

T_max  =  [tasks['demand'].sum() // agvs.iloc[i,:].capacity for i in range(len(agvs))]

v = agvs['speed_cells_per_sec']
Q = agvs['capacity']
D = agvs['max_distance']
s = list([0])
s +=(list( tasks['service_time']))
s+=list([0])
u = list([0])
u+=(list(tasks['demand']))
u+=list([0])
M = 1000

# %%
# # Model
# model = gp.Model("AGV_Routing")

# # 변수 생성
# x = {}
# for k in K:
#     for r in range(T_max[k]):
#         for i in N_s_t:
#             for j in N_s_t:
#                 x[i, j, r] = model.addVar(vtype=GRB.BINARY, name=f"x_{i}_{j}_{r}")

# y = {}
# for k in K:
#     for r in range(T_max[k]):
#         for i in N:
#             y[i,r] = model.addVar(vtype=GRB.BINARY, name=f"y_{i}_{r}")

# o = {}
# for k in K:
#     for r in range(T_max[k]):
#         for i in N_s_t:
#             o[i,r] = model.addVar(vtype=GRB.INTEGER, name=f"o_{i}_{r}")

# t = {}
# for k in K:
#     for r in range(T_max[k]):
#         for i in N_s_t:
#             t[i,r] = model.addVar(vtype=GRB.CONTINUOUS, name=f"t_{i}_{r}")

# %%
# # 0
# for k in K:
#     for r in range(T_max[k]):
#         model.addConstr(quicksum(x[0,j,r] for j in N ) <= 1)

# # 1 
# for k in K:
#     for r in range(T_max[k]):
#         for j in N:
#             model.addConstr(quicksum(x[i,j,r] for i in N_s if i != j) == quicksum(x[j,i,r] for i in N_t if i != j))
#             model.addConstr(quicksum(x[i,j,r] for i in N_s if i != j) == y[j,r])

# # 2 
# for k in K:
#     for r in range(T_max[k]):
#         for i in N:
#             for j in N:
#                 if i!=j:
#                     model.addConstr(t[j,r]>= t[i,r] + distance[i][j]/v[k] + s[i] - M*(1-x[i,j,r]))

# # 3
# for k in K:
#     for r in range(T_max[k]):
#         for i in N:
#             model.addConstr(u[i] <= o[i,r])

# # # 4
# # for k in K:
# #     for r in range(T_max[k]):
# #         model.addConstr(quicksum(o[i,r] for i in N) <= Q[k])

# for j in N:
#     model.addConstr(
#         quicksum(y[j, r] for k in K for r in range(T_max[k])) >= 1
#     )

# # 4
# for k in K:
#     for r in range(T_max[k]):
#         model.addConstr(quicksum(distance[i][j]*x[i,j,r] for i in N for j in N if i!=j) <= D[k])

# %%
# print(1)
# # model.setObjective()


# model.optimize()

# %%
# === MODEL ===
model = gp.Model("AGV_Routing_Small")

x = {}
y = {}
o = {}
t = {}

# === VARIABLES ===
for k in K:
    for r in range(T_max[k]):
        for i in N_s_t:
            for j in N_s_t:
                if i != j:
                    x[k, i, j, r] = model.addVar(vtype=GRB.BINARY, name=f"x_{k}_{i}_{j}_{r}")
        for i in N_s_t:
            y[k, i, r] = model.addVar(vtype=GRB.BINARY, name=f"y_{k}_{i}_{r}")
            o[k, i, r] = model.addVar(vtype=GRB.INTEGER, name=f"o_{k}_{i}_{r}")
            t[k, i, r] = model.addVar(vtype=GRB.CONTINUOUS, name=f"t_{k}_{i}_{r}")

model.update()

# === CONSTRAINTS ===

# 0. Start at most once from depot
for k in K:
    for r in range(T_max[k]):
        model.addConstr(quicksum(x[k, 0, j, r] for j in N if (k, 0, j, r) in x) <= 1)

# 1. Flow conservation & visit indication
for k in K:
    for r in range(T_max[k]):
        for j in N:
            model.addConstr(
                quicksum(x[k, i, j, r] for i in N_s if i != j and (k, i, j, r) in x) ==
                quicksum(x[k, j, i, r] for i in N_t if i != j and (k, j, i, r) in x)
            )
            model.addConstr(
                quicksum(x[k, i, j, r] for i in N_s if i != j and (k, i, j, r) in x) ==
                y[k, j, r]
            )

# 2. Time sequencing with big-M
for k in K:
    for r in range(T_max[k]):
        for i in N:
            for j in N:
                if i != j and (k, i, j, r) in x:
                    model.addConstr(
                        t[k, j, r] >= t[k, i, r] + distance[i][j] / v[k] + s[i] - M * (1 - x[k, i, j, r])
                    )

# 3. Order demand only if visited
for k in K:
    for r in range(T_max[k]):
        for i in N:
            model.addConstr(o[k, i, r] >= u[i] * y[k, i, r])

# 4. Load constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(quicksum(o[k, i, r] for i in N) <= Q[k])

# 5. Distance constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(
            quicksum(distance[i][j] * x[k, i, j, r]
                     for i in N for j in N if i != j and (k, i, j, r) in x) <= D[k]
        )

# 6. Each task must be served at least once
for j in N:
    model.addConstr(
        quicksum(y[k, j, r] for k in K for r in range(T_max[k])) >= 1
    )

# === OBJECTIVE ===
model.setObjective(
    quicksum(distance[i][j] * x[k, i, j, r]
             for k in K
             for r in range(T_max[k])
             for i in N for j in N if i != j and (k, i, j, r) in x ) + 10,
    GRB.MINIMIZE
)

# === SOLVE ===
model.optimize()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2636023
# Academic license - for non-commercial use only - expires 2026-03-13
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Optimize a model with 6662659 rows, 6927024 columns and 45905900 nonzeros
# Model fingerprint: 0xeff99bd8
# Variable types: 66606 continuous, 6860418 integer (6793812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 1.97 seconds (1.86 work units)
# Thread count was 1 (of 28 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ✅ Objective value (total distance): 0.00
#
# Selected routes (AGV, Route, From → To):
#   AGV 0, Route 0: 0 → 101
#   AGV 0, Route 0: 101 → 0
#   AGV 0, Route 0: 101 → 1
#   AGV 0, Route 0: 101 → 2
#   AGV 0, Route 0: 101 → 3
#   AGV 0, Route 0: 101 → 4
#   AGV 0, Route 0: 101 → 5
#   AGV 0, Route 0: 101 → 6
#   AGV 0, Route 0: 101 → 7
#   AGV 0, Route 0: 101 → 8
#   AGV 0, Route 0: 101 → 9
#   AGV 0, Route 0: 101 → 10
#   AGV 0, Route 0: 101 → 11
#   AGV 0, Route 0: 101 → 12
#   AGV 0, Route 0: 101 → 13
#   AGV 0, Route 0: 101 → 14
#   AGV 0, Route 0: 101 → 15
#   AGV 0, Route 0: 101 → 16
#   AGV 0, Route 0: 101 → 17
#   AGV 0, Route 0: 101 → 18
#   AGV 0, Route 0: 101 → 19
#   AGV 0, Route 0: 101 → 20
#   AGV 0, Route 0: 101 → 21
#   AGV 0, Route 0: 101 → 22
#   AGV 0, Route 0: 101 → 23
#   AGV 0, Route 0: 101 → 24
#   AGV 0, Route 0: 101 → 25
#   AGV 0, Route 0: 101 → 26
#   AGV 0, Route 0: 101 → 27
#   AGV 0, Route 0: 101 → 28
#   AGV 0, Route 0: 101 → 29
#   AGV 0, Route 0: 101 → 30
#   AGV 0, Route 0: 101 → 31
#   AGV 0, Route 0: 101 → 32
#   AGV 0, Route 0: 101 → 33
#   AGV 0, Route 0: 101 → 34
#   AGV 0, Route 0: 101 → 35
#   AGV 0, Route 0: 101 → 36
#   AGV 0, Route 0: 101 → 37
#   AGV 0, Route 0: 101 → 38
#   AGV 0, Route 0: 101 → 39
#   AGV 0, Route 0: 101 → 40
#   AGV 0, Route 0: 101 → 41
#   AGV 0, Route 0: 101 → 42
#   AGV 0, Route 0: 101 → 43
#   AGV 0, Route 0: 101 → 44
#   AGV 0, Route 0: 101 → 45
#   AGV 0, Route 0: 101 → 46
#   AGV 0, Route 0: 101 → 47
#   AGV 0, Route 0: 101 → 48
#   AGV 0, Route 0: 101 → 49
#   AGV 0, Route 0: 101 → 50
#   AGV 0, Route 0: 101 → 51
#   AGV 0, Route 0: 101 → 52
#   AGV 0, Route 0: 101 → 53
#   AGV 0, Route 0: 101 → 54
#   AGV 0, Route 0: 101 → 55
#   AGV 0, Route 0: 101 → 56
#   AGV 0, Route 0: 101 → 57
#   AGV 0, Route 0: 101 → 58
#   AGV 0, Route 0: 101 → 59
#   AGV 0, Route 0: 101 → 60
#   AGV 0, Route 0: 101 → 61
#   AGV 0, Route 0: 101 → 62
#   AGV 0, Route 0: 101 → 63
#   AGV 0, Route 0: 101 → 64
#   AGV 0, Route 0: 101 → 65
#   AGV 0, Route 0: 101 → 66
#   AGV 0, Route 0: 101 → 67
#   AGV 0, Route 0: 101 → 68
#   AGV 0, Route 0: 101 → 69
#   AGV 0, Route 0: 101 → 70
#   AGV 0, Route 0: 101 → 71
#   AGV 0, Route 0: 101 → 72
#   AGV 0, Route 0: 101 → 73
#   AGV 0, Route 0: 101 → 74
#   AGV 0, Route 0: 101 → 75
#   AGV 0, Route 0: 101 → 76
#   AGV 0, Route 0: 101 → 77
#   AGV 0, Route 0: 101 → 78
#   AGV 0, Route 0: 101 → 79
#   AGV 0, Route 0: 101 → 80
#   AGV 0, Route 0: 101 → 81
#   AGV 0, Route 0: 101 → 82
#   AGV 0, Route 0: 101 → 83
#   AGV 0, Route 0: 101 → 84
#   AGV 0, Route 0: 101 → 85
#   AGV 0, Route 0: 101 → 86
#   AGV 0, Route 0: 101 → 87
#   AGV 0, Route 0: 101 → 88
#   AGV 0, Route 0: 101 → 89
#   AGV 0, Route 0: 101 → 90
#   AGV 0, Route 0: 101 → 91
#   AGV 0, Route 0: 101 → 92
#   AGV 0, Route 0: 101 → 93
#   AGV 0, Route 0: 101 → 94
#   AGV 0, Route 0: 101 → 95
#   AGV 0, Route 0: 101 → 96
#   AGV 0, Route 0: 101 → 97
#   AGV 0, Route 0: 101 → 98
#   AGV 0, Route 0: 101 → 99
#   AGV 0, Route 0: 101 → 100
#   AGV 0, Route 1: 0 → 101
#   AGV 0, Route 1: 101 → 0
#   AGV 0, Route 1: 101 → 1
#   AGV 0, Route 1: 101 → 2
#   AGV 0, Route 1: 101 → 3
#   AGV 0, Route 1: 101 → 4
#   AGV 0, Route 1: 101 → 5
#   AGV 0, Route 1: 101 → 6
#   AGV 0, Route 1: 101 → 7
#   AGV 0, Route 1: 101 → 8
#   AGV 0, Route 1: 101 → 9
#   AGV 0, Route 1: 101 → 10
#   AGV 0, Route 1: 101 → 11
#   AGV 0, Route 1: 101 → 12
#   AGV 0, Route 1: 101 → 13
#   AGV 0, Route 1: 101 → 14
#   AGV 0, Route 1: 101 → 15
#   AGV 0, Route 1: 101 → 16
#   AGV 0, Route 1: 101 → 17
#   AGV 0, Route 1: 101 → 18
#   AGV 0, Route 1: 101 → 19
#   AGV 0, Route 1: 101 → 20
#   AGV 0, Route 1: 101 → 21
#   AGV 0, Route 1: 101 → 22
#   AGV 0, Route 1: 101 → 23
#   AGV 0, Route 1: 101 → 24
#   AGV 0, Route 1: 101 → 25
#   AGV 0, Route 1: 101 → 26
#   AGV 0, Route 1: 101 → 27
#   AGV 0, Route 1: 101 → 28
#   AGV 0, Route 1: 101 → 29
#   AGV 0, Route 1: 101 → 30
#   AGV 0, Route 1: 101 → 31
#   AGV 0, Route 1: 101 → 32
#   AGV 0, Route 1: 101 → 33
#   AGV 0, Route 1: 101 → 34
#   AGV 0, Route 1: 101 → 35
#   AGV 0, Route 1: 101 → 36
#   AGV 0, Route 1: 101 → 37
#   AGV 0, Route 1: 101 → 38
#   AGV 0, Route 1: 101 → 39
#   AGV 0, Route 1: 101 → 40
#   AGV 0, Route 1: 101 → 41
#   AGV 0, Route 1: 101 → 42
#   AGV 0, Route 1: 101 → 43
#   AGV 0, Route 1: 101 → 44
#   AGV 0, Route 1: 101 → 45
#   AGV 0, Route 1: 101 → 46
#   AGV 0, Route 1: 101 → 47
#   AGV 0, Route 1: 101 → 48
#   AGV 0, Route 1: 101 → 49
#   AGV 0, Route 1: 101 → 50
#   AGV 0, Route 1: 101 → 51
#   AGV 0, Route 1: 101 → 52
#   AGV 0, Route 1: 101 → 53
#   AGV 0, Route 1: 101 → 54
#   AGV 0, Route 1: 101 → 55
#   AGV 0, Route 1: 101 → 56
#   AGV 0, Route 1: 101 → 57
#   AGV 0, Route 1: 101 → 58
#   AGV 0, Route 1: 101 → 59
#   AGV 0, Route 1: 101 → 60
#   AGV 0, Route 1: 101 → 61
#   AGV 0, Route 1: 101 → 62
#   AGV 0, Route 1: 101 → 63
#   AGV 0, Route 1: 101 → 64
#   AGV 0, Route 1: 101 → 65
#   AGV 0, Route 1: 101 → 66
#   AGV 0, Route 1: 101 → 67
#   AGV 0, Route 1: 101 → 68
#   AGV 0, Route 1: 101 → 69
#   AGV 0, Route 1: 101 → 70
#   AGV 0, Route 1: 101 → 71
#   AGV 0, Route 1: 101 → 72
#   AGV 0, Route 1: 101 → 73
#   AGV 0, Route 1: 101 → 74
#   AGV 0, Route 1: 101 → 75
#   AGV 0, Route 1: 101 → 76
#   AGV 0, Route 1: 101 → 77
#   AGV 0, Route 1: 101 → 78
#   AGV 0, Route 1: 101 → 79
#   AGV 0, Route 1: 101 → 80
#   AGV 0, Route 1: 101 → 81
#   AGV 0, Route 1: 101 → 82
#   AGV 0, Route 1: 101 → 83
#   AGV 0, Route 1: 101 → 84
#   AGV 0, Route 1: 101 → 85
#   AGV 0, Route 1: 101 → 86
#   AGV 0, Route 1: 101 → 87
#   AGV 0, Route 1: 101 → 88
#   AGV 0, Route 1: 101 → 89
#   AGV 0, Route 1: 101 → 90
#   AGV 0, Route 1: 101 → 91
#   AGV 0, Route 1: 101 → 92
#   AGV 0, Route 1: 101 → 93
#   AGV 0, Route 1: 101 → 94
#   AGV 0, Route 1: 101 → 95
#   AGV 0, Route 1: 101 → 96
#   AGV 0, Route 1: 101 → 97
#   AGV 0, Route 1: 101 → 98
#   AGV 0, Route 1: 101 → 99
#   AGV 0, Route 1: 101 → 100
#   AGV 0, Route 2: 0 → 101
#   AGV 0, Route 2: 101 → 0
#   AGV 0, Route 2: 101 → 1
#   AGV 0, Route 2: 101 → 2
#   AGV 0, Route 2: 101 → 3
#   AGV 0, Route 2: 101 → 4
#   AGV 0, Route 2: 101 → 5
#   AGV 0, Route 2: 101 → 6
#   AGV 0, Route 2: 101 → 7
#   AGV 0, Route 2: 101 → 8
#   AGV 0, Route 2: 101 → 9
#   AGV 0, Route 2: 101 → 10
#   AGV 0, Route 2: 101 → 11
#   AGV 0, Route 2: 101 → 12
#   AGV 0, Route 2: 101 → 13
#   AGV 0, Route 2: 101 → 14
#   AGV 0, Route 2: 101 → 15
#   AGV 0, Route 2: 101 → 16
#   AGV 0, Route 2: 101 → 17
#   AGV 0, Route 2: 101 → 18
#   AGV 0, Route 2: 101 → 19
#   AGV 0, Route 2: 101 → 20
#   AGV 0, Route 2: 101 → 21
#   AGV 0, Route 2: 101 → 22
#   AGV 0, Route 2: 101 → 23
#   AGV 0, Route 2: 101 → 24
#   AGV 0, Route 2: 101 → 25
#   AGV 0, Route 2: 101 → 26
#   AGV 0, Route 2: 101 → 27
#   AGV 0, Route 2: 101 → 28
#   AGV 0, Route 2: 101 → 29
#   AGV 0, Route 2: 101 → 30
#   AGV 0, Route 2: 101 → 31
#   AGV 0, Route 2: 101 → 32
#   AGV 0, Route 2: 101 → 33
#   AGV 0, Route 2: 101 → 34
#   AGV 0, Route 2: 101 → 35
#   AGV 0, Route 2: 101 → 36
#   AGV 0, Route 2: 101 → 37
#   AGV 0, Route 2: 101 → 38
#   AGV 0, Route 2: 101 → 39
#   AGV 0, Route 2: 101 → 40
#   AGV 0, Route 2: 101 → 41
#   AGV 0, Route 2: 101 → 42
#   AGV 0, Route 2: 101 → 43
#   AGV 0, Route 2: 101 → 44
#   AGV 0, Route 2: 101 → 45
#   AGV 0, Route 2: 101 → 46
#   AGV 0, Route 2: 101 → 47
#   AGV 0, Route 2: 101 → 48
#   AGV 0, Route 2: 101 → 49
#   AGV 0, Route 2: 101 → 50
#   AGV 0, Route 2: 101 → 51
#   AGV 0, Route 2: 101 → 52
#   AGV 0, Route 2: 101 → 53
#   AGV 0, Route 2: 101 → 54
#   AGV 0, Route 2: 101 → 55
#   AGV 0, Route 2: 101 → 56
#   AGV 0, Route 2: 101 → 57
#   AGV 0, Route 2: 101 → 58
#   AGV 0, Route 2: 101 → 59
#   AGV 0, Route 2: 101 → 60
#   AGV 0, Route 2: 101 → 61
#   AGV 0, Route 2: 101 → 62
#   AGV 0, Route 2: 101 → 63
#   AGV 0, Route 2: 101 → 64
#   AGV 0, Route 2: 101 → 65
#   AGV 0, Route 2: 101 → 66
#   AGV 0, Route 2: 101 → 67
#   AGV 0, Route 2: 101 → 68
#   AGV 0, Route 2: 101 → 69
#   AGV 0, Route 2: 101 → 70
#   AGV 0, Route 2: 101 → 71
#   AGV 0, Route 2: 101 → 72
#   AGV 0, Route 2: 101 → 73
#   AGV 0, Route 2: 101 → 74
#   AGV 0, Route 2: 101 → 75
#   AGV 0, Route 2: 101 → 76
#   AGV 0, Route 2: 101 → 77
#   AGV 0, Route 2: 101 → 78
#   AGV 0, Route 2: 101 → 79
#   AGV 0, Route 2: 101 → 80
#   AGV 0, Route 2: 101 → 81
#   AGV 0, Route 2: 101 → 82
#   AGV 0, Route 2: 101 → 83
#   AGV 0, Route 2: 101 → 84
#   AGV 0, Route 2: 101 → 85
#   AGV 0, Route 2: 101 → 86
#   AGV 0, Route 2: 101 → 87
#   AGV 0, Route 2: 101 → 88
#   AGV 0, Route 2: 101 → 89
#   AGV 0, Route 2: 101 → 90
#   AGV 0, Route 2: 101 → 91
#   AGV 0, Route 2: 101 → 92
#   AGV 0, Route 2: 101 → 93
#   AGV 0, Route 2: 101 → 94
#   AGV 0, Route 2: 101 → 95
#   AGV 0, Route 2: 101 → 96
#   AGV 0, Route 2: 101 → 97
#   AGV 0, Route 2: 101 → 98
#   AGV 0, Route 2: 101 → 99
#   AGV 0, Route 2: 101 → 100
#   AGV 0, Route 3: 0 → 41
#   AGV 0, Route 3: 0 → 101
#   AGV 0, Route 3: 41 → 0
#   AGV 0, Route 3: 101 → 0
#   AGV 0, Route 3: 101 → 1
#   AGV 0, Route 3: 101 → 2
#   AGV 0, Route 3: 101 → 3
#   AGV 0, Route 3: 101 → 4
#   AGV 0, Route 3: 101 → 5
#   AGV 0, Route 3: 101 → 6
#   AGV 0, Route 3: 101 → 7
#   AGV 0, Route 3: 101 → 8
#   AGV 0, Route 3: 101 → 9
#   AGV 0, Route 3: 101 → 10
#   AGV 0, Route 3: 101 → 11
#   AGV 0, Route 3: 101 → 12
#   AGV 0, Route 3: 101 → 13
#   AGV 0, Route 3: 101 → 14
#   AGV 0, Route 3: 101 → 15
#   AGV 0, Route 3: 101 → 16
#   AGV 0, Route 3: 101 → 17
#   AGV 0, Route 3: 101 → 18
#   AGV 0, Route 3: 101 → 19
#   AGV 0, Route 3: 101 → 20
#   AGV 0, Route 3: 101 → 21
#   AGV 0, Route 3: 101 → 22
#   AGV 0, Route 3: 101 → 23
#   AGV 0, Route 3: 101 → 24
#   AGV 0, Route 3: 101 → 25
#   AGV 0, Route 3: 101 → 26
#   AGV 0, Route 3: 101 → 27
#   AGV 0, Route 3: 101 → 28
#   AGV 0, Route 3: 101 → 29
#   AGV 0, Route 3: 101 → 30
#   AGV 0, Route 3: 101 → 31
#   AGV 0, Route 3: 101 → 32
#   AGV 0, Route 3: 101 → 33
#   AGV 0, Route 3: 101 → 34
#   AGV 0, Route 3: 101 → 35
#   AGV 0, Route 3: 101 → 36
#   AGV 0, Route 3: 101 → 37
#   AGV 0, Route 3: 101 → 38
#   AGV 0, Route 3: 101 → 39
#   AGV 0, Route 3: 101 → 40
#   AGV 0, Route 3: 101 → 41
#   AGV 0, Route 3: 101 → 42
#   AGV 0, Route 3: 101 → 43
#   AGV 0, Route 3: 101 → 44
#   AGV 0, Route 3: 101 → 45
#   AGV 0, Route 3: 101 → 46
#   AGV 0, Route 3: 101 → 47
#   AGV 0, Route 3: 101 → 48
#   AGV 0, Route 3: 101 → 49
#   AGV 0, Route 3: 101 → 50
#   AGV 0, Route 3: 101 → 51
#   AGV 0, Route 3: 101 → 52
#   AGV 0, Route 3: 101 → 53
#   AGV 0, Route 3: 101 → 54
#   AGV 0, Route 3: 101 → 55
#   AGV 0, Route 3: 101 → 56
#   AGV 0, Route 3: 101 → 57
#   AGV 0, Route 3: 101 → 58
#   AGV 0, Route 3: 101 → 59
#   AGV 0, Route 3: 101 → 60
#   AGV 0, Route 3: 101 → 61
#   AGV 0, Route 3: 101 → 62
#   AGV 0, Route 3: 101 → 63
#   AGV 0, Route 3: 101 → 64
#   AGV 0, Route 3: 101 → 65
#   AGV 0, Route 3: 101 → 66
#   AGV 0, Route 3: 101 → 67
#   AGV 0, Route 3: 101 → 68
#   AGV 0, Route 3: 101 → 69
#   AGV 0, Route 3: 101 → 70
#   AGV 0, Route 3: 101 → 71
#   AGV 0, Route 3: 101 → 72
#   AGV 0, Route 3: 101 → 73
#   AGV 0, Route 3: 101 → 74
#   AGV 0, Route 3: 101 → 75
#   AGV 0, Route 3: 101 → 76
#   AGV 0, Route 3: 101 → 77
#   AGV 0, Route 3: 101 → 78
#   AGV 0, Route 3: 101 → 79
#   AGV 0, Route 3: 101 → 80
#   AGV 0, Route 3: 101 → 81
#   AGV 0, Route 3: 101 → 82
#   AGV 0, Route 3: 101 → 83
#   AGV 0, Route 3: 101 → 84
#   AGV 0, Route 3: 101 → 85
#   AGV 0, Route 3: 101 → 86
#   AGV 0, Route 3: 101 → 87
#   AGV 0, Route 3: 101 → 88
#   AGV 0, Route 3: 101 → 89
#   AGV 0, Route 3: 101 → 90
#   AGV 0, Route 3: 101 → 91
#   AGV 0, Route 3: 101 → 92
#   AGV 0, Route 3: 101 → 93
#   AGV 0, Route 3: 101 → 94
#   AGV 0, Route 3: 101 → 95
#   AGV 0, Route 3: 101 → 96
#   AGV 0, Route 3: 101 → 97
#   AGV 0, Route 3: 101 → 98
#   AGV 0, Route 3: 101 → 99
#   AGV 0, Route 3: 101 → 100
#   AGV 0, Route 4: 0 → 101
#   AGV 0, Route 4: 101 → 0
#   AGV 0, Route 4: 101 → 1
#   AGV 0, Route 4: 101 → 2
#   AGV 0, Route 4: 101 → 3
#   AGV 0, Route 4: 101 → 4
#   AGV 0, Route 4: 101 → 5
#   AGV 0, Route 4: 101 → 6
#   AGV 0, Route 4: 101 → 7
#   AGV 0, Route 4: 101 → 8
#   AGV 0, Route 4: 101 → 9
#   AGV 0, Route 4: 101 → 10
#   AGV 0, Route 4: 101 → 11
#   AGV 0, Route 4: 101 → 12
#   AGV 0, Route 4: 101 → 13
#   AGV 0, Route 4: 101 → 14
#   AGV 0, Route 4: 101 → 15
#   AGV 0, Route 4: 101 → 16
#   AGV 0, Route 4: 101 → 17
#   AGV 0, Route 4: 101 → 18
#   AGV 0, Route 4: 101 → 19
#   AGV 0, Route 4: 101 → 20
#   AGV 0, Route 4: 101 → 21
#   AGV 0, Route 4: 101 → 22
#   AGV 0, Route 4: 101 → 23
#   AGV 0, Route 4: 101 → 24
#   AGV 0, Route 4: 101 → 25
#   AGV 0, Route 4: 101 → 26
#   AGV 0, Route 4: 101 → 27
#   AGV 0, Route 4: 101 → 28
#   AGV 0, Route 4: 101 → 29
#   AGV 0, Route 4: 101 → 30
#   AGV 0, Route 4: 101 → 31
#   AGV 0, Route 4: 101 → 32
#   AGV 0, Route 4: 101 → 33
#   AGV 0, Route 4: 101 → 34
#   AGV 0, Route 4: 101 → 35
#   AGV 0, Route 4: 101 → 36
#   AGV 0, Route 4: 101 → 37
#   AGV 0, Route 4: 101 → 38
#   AGV 0, Route 4: 101 → 39
#   AGV 0, Route 4: 101 → 40
#   AGV 0, Route 4: 101 → 41
#   AGV 0, Route 4: 101 → 42
#   AGV 0, Route 4: 101 → 43
#   AGV 0, Route 4: 101 → 44
#   AGV 0, Route 4: 101 → 45
#   AGV 0, Route 4: 101 → 46
#   AGV 0, Route 4: 101 → 47
#   AGV 0, Route 4: 101 → 48
#   AGV 0, Route 4: 101 → 49
#   AGV 0, Route 4: 101 → 50
#   AGV 0, Route 4: 101 → 51
#   AGV 0, Route 4: 101 → 52
#   AGV 0, Route 4: 101 → 53
#   AGV 0, Route 4: 101 → 54
#   AGV 0, Route 4: 101 → 55
#   AGV 0, Route 4: 101 → 56
#   AGV 0, Route 4: 101 → 57
#   AGV 0, Route 4: 101 → 58
#   AGV 0, Route 4: 101 → 59
#   AGV 0, Route 4: 101 → 60
#   AGV 0, Route 4: 101 → 61
#   AGV 0, Route 4: 101 → 62
#   AGV 0, Route 4: 101 → 63
#   AGV 0, Route 4: 101 → 64
#   AGV 0, Route 4: 101 → 65
#   AGV 0, Route 4: 101 → 66
#   AGV 0, Route 4: 101 → 67
#   AGV 0, Route 4: 101 → 68
#   AGV 0, Route 4: 101 → 69
#   AGV 0, Route 4: 101 → 70
#   AGV 0, Route 4: 101 → 71
#   AGV 0, Route 4: 101 → 72
#   AGV 0, Route 4: 101 → 73
#   AGV 0, Route 4: 101 → 74
#   AGV 0, Route 4: 101 → 75
#   AGV 0, Route 4: 101 → 76
#   AGV 0, Route 4: 101 → 77
#   AGV 0, Route 4: 101 → 78
#   AGV 0, Route 4: 101 → 79
#   AGV 0, Route 4: 101 → 80
#   AGV 0, Route 4: 101 → 81
#   AGV 0, Route 4: 101 → 82
#   AGV 0, Route 4: 101 → 83
#   AGV 0, Route 4: 101 → 84
#   AGV 0, Route 4: 101 → 85
#   AGV 0, Route 4: 101 → 86
#   AGV 0, Route 4: 101 → 87
#   AGV 0, Route 4: 101 → 88
#   AGV 0, Route 4: 101 → 89
#   AGV 0, Route 4: 101 → 90
#   AGV 0, Route 4: 101 → 91
#   AGV 0, Route 4: 101 → 92
#   AGV 0, Route 4: 101 → 93
#   AGV 0, Route 4: 101 → 94
#   AGV 0, Route 4: 101 → 95
#   AGV 0, Route 4: 101 → 96
#   AGV 0, Route 4: 101 → 97
#   AGV 0, Route 4: 101 → 98
#   AGV 0, Route 4: 101 → 99
#   AGV 0, Route 4: 101 → 100
#   AGV 0, Route 5: 0 → 101
#   AGV 0, Route 5: 101 → 0
#   AGV 0, Route 5: 101 → 1
#   AGV 0, Route 5: 101 → 2
#   AGV 0, Route 5: 101 → 3
#   AGV 0, Route 5: 101 → 4
#   AGV 0, Route 5: 101 → 5
#   AGV 0, Route 5: 101 → 6
#   AGV 0, Route 5: 101 → 7
#   AGV 0, Route 5: 101 → 8
#   AGV 0, Route 5: 101 → 9
#   AGV 0, Route 5: 101 → 10
#   AGV 0, Route 5: 101 → 11
#   AGV 0, Route 5: 101 → 12
#   AGV 0, Route 5: 101 → 13
#   AGV 0, Route 5: 101 → 14
#   AGV 0, Route 5: 101 → 15
#   AGV 0, Route 5: 101 → 16
#   AGV 0, Route 5: 101 → 17
#   AGV 0, Route 5: 101 → 18
#   AGV 0, Route 5: 101 → 19
#   AGV 0, Route 5: 101 → 20
#   AGV 0, Route 5: 101 → 21
#   AGV 0, Route 5: 101 → 22
#   AGV 0, Route 5: 101 → 23
#   AGV 0, Route 5: 101 → 24
#   AGV 0, Route 5: 101 → 25
#   AGV 0, Route 5: 101 → 26
#   AGV 0, Route 5: 101 → 27
#   AGV 0, Route 5: 101 → 28
#   AGV 0, Route 5: 101 → 29
#   AGV 0, Route 5: 101 → 30
#   AGV 0, Route 5: 101 → 31
#   AGV 0, Route 5: 101 → 32
#   AGV 0, Route 5: 101 → 33
#   AGV 0, Route 5: 101 → 34
#   AGV 0, Route 5: 101 → 35
#   AGV 0, Route 5: 101 → 36
#   AGV 0, Route 5: 101 → 37
#   AGV 0, Route 5: 101 → 38
#   AGV 0, Route 5: 101 → 39
#   AGV 0, Route 5: 101 → 40
#   AGV 0, Route 5: 101 → 41
#   AGV 0, Route 5: 101 → 42
#   AGV 0, Route 5: 101 → 43
#   AGV 0, Route 5: 101 → 44
#   AGV 0, Route 5: 101 → 45
#   AGV 0, Route 5: 101 → 46
#   AGV 0, Route 5: 101 → 47
#   AGV 0, Route 5: 101 → 48
#   AGV 0, Route 5: 101 → 49
#   AGV 0, Route 5: 101 → 50
#   AGV 0, Route 5: 101 → 51
#   AGV 0, Route 5: 101 → 52
#   AGV 0, Route 5: 101 → 53
#   AGV 0, Route 5: 101 → 54
#   AGV 0, Route 5: 101 → 55
#   AGV 0, Route 5: 101 → 56
#   AGV 0, Route 5: 101 → 57
#   AGV 0, Route 5: 101 → 58
#   AGV 0, Route 5: 101 → 59
#   AGV 0, Route 5: 101 → 60
#   AGV 0, Route 5: 101 → 61
#   AGV 0, Route 5: 101 → 62
#   AGV 0, Route 5: 101 → 63
#   AGV 0, Route 5: 101 → 64
#   AGV 0, Route 5: 101 → 65
#   AGV 0, Route 5: 101 → 66
#   AGV 0, Route 5: 101 → 67
#   AGV 0, Route 5: 101 → 68
#   AGV 0, Route 5: 101 → 69
#   AGV 0, Route 5: 101 → 70
#   AGV 0, Route 5: 101 → 71
#   AGV 0, Route 5: 101 → 72
#   AGV 0, Route 5: 101 → 73
#   AGV 0, Route 5: 101 → 74
#   AGV 0, Route 5: 101 → 75
#   AGV 0, Route 5: 101 → 76
#   AGV 0, Route 5: 101 → 77
#   AGV 0, Route 5: 101 → 78
#   AGV 0, Route 5: 101 → 79
#   AGV 0, Route 5: 101 → 80
#   AGV 0, Route 5: 101 → 81
#   AGV 0, Route 5: 101 → 82
#   AGV 0, Route 5: 101 → 83
#   AGV 0, Route 5: 101 → 84
#   AGV 0, Route 5: 101 → 85
#   AGV 0, Route 5: 101 → 86
#   AGV 0, Route 5: 101 → 87
#   AGV 0, Route 5: 101 → 88
#   AGV 0, Route 5: 101 → 89
#   AGV 0, Route 5: 101 → 90
#   AGV 0, Route 5: 101 → 91
#   AGV 0, Route 5: 101 → 92
#   AGV 0, Route 5: 101 → 93
#   AGV 0, Route 5: 101 → 94
#   AGV 0, Route 5: 101 → 95
#   AGV 0, Route 5: 101 → 96
#   AGV 0, Route 5: 101 → 97
#   AGV 0, Route 5: 101 → 98
#   AGV 0, Route 5: 101 → 99
#   AGV 0, Route 5: 101 → 100
#   AGV 0, Route 6: 0 → 101
#   AGV 0, Route 6: 101 → 0
#   AGV 0, Route 6: 101 → 1
#   AGV 0, Route 6: 101 → 2
#   AGV 0, Route 6: 101 → 3
#   AGV 0, Route 6: 101 → 4
#   AGV 0, Route 6: 101 → 5
#   AGV 0, Route 6: 101 → 6
#   AGV 0, Route 6: 101 → 7
#   AGV 0, Route 6: 101 → 8
#   AGV 0, Route 6: 101 → 9
#   AGV 0, Route 6: 101 → 10
#   AGV 0, Route 6: 101 → 11
#   AGV 0, Route 6: 101 → 12
#   AGV 0, Route 6: 101 → 13
#   AGV 0, Route 6: 101 → 14
#   AGV 0, Route 6: 101 → 15
#   AGV 0, Route 6: 101 → 16
#   AGV 0, Route 6: 101 → 17
#   AGV 0, Route 6: 101 → 18
#   AGV 0, Route 6: 101 → 19
#   AGV 0, Route 6: 101 → 20
#   AGV 0, Route 6: 101 → 21
#   AGV 0, Route 6: 101 → 22
#   AGV 0, Route 6: 101 → 23
#   AGV 0, Route 6: 101 → 24
#   AGV 0, Route 6: 101 → 25
#   AGV 0, Route 6: 101 → 26
#   AGV 0, Route 6: 101 → 27
#   AGV 0, Route 6: 101 → 28
#   AGV 0, Route 6: 101 → 29
#   AGV 0, Route 6: 101 → 30
#   AGV 0, Route 6: 101 → 31
#   AGV 0, Route 6: 101 → 32
#   AGV 0, Route 6: 101 → 33
#   AGV 0, Route 6: 101 → 34
#   AGV 0, Route 6: 101 → 35
#   AGV 0, Route 6: 101 → 36
#   AGV 0, Route 6: 101 → 37
#   AGV 0, Route 6: 101 → 38
#   AGV 0, Route 6: 101 → 39
#   AGV 0, Route 6: 101 → 40
#   AGV 0, Route 6: 101 → 41
#   AGV 0, Route 6: 101 → 42
#   AGV 0, Route 6: 101 → 43
#   AGV 0, Route 6: 101 → 44
#   AGV 0, Route 6: 101 → 45
#   AGV 0, Route 6: 101 → 46
#   AGV 0, Route 6: 101 → 47
#   AGV 0, Route 6: 101 → 48
#   AGV 0, Route 6: 101 → 49
#   AGV 0, Route 6: 101 → 50
#   AGV 0, Route 6: 101 → 51
#   AGV 0, Route 6: 101 → 52
#   AGV 0, Route 6: 101 → 53
#   AGV 0, Route 6: 101 → 54
#   AGV 0, Route 6: 101 → 55
#   AGV 0, Route 6: 101 → 56
#   AGV 0, Route 6: 101 → 57
#   AGV 0, Route 6: 101 → 58
#   AGV 0, Route 6: 101 → 59
#   AGV 0, Route 6: 101 → 60
#   AGV 0, Route 6: 101 → 61
#   AGV 0, Route 6: 101 → 62
#   AGV 0, Route 6: 101 → 63
#   AGV 0, Route 6: 101 → 64
#   AGV 0, Route 6: 101 → 65
#   AGV 0, Route 6: 101 → 66
#   AGV 0, Route 6: 101 → 67
#   AGV 0, Route 6: 101 → 68
#   AGV 0, Route 6: 101 → 69
#   AGV 0, Route 6: 101 → 70
#   AGV 0, Route 6: 101 → 71
#   AGV 0, Route 6: 101 → 72
#   AGV 0, Route 6: 101 → 73
#   AGV 0, Route 6: 101 → 74
#   AGV 0, Route 6: 101 → 75
#   AGV 0, Route 6: 101 → 76
#   AGV 0, Route 6: 101 → 77
#   AGV 0, Route 6: 101 → 78
#   AGV 0, Route 6: 101 → 79
#   AGV 0, Route 6: 101 → 80
#   AGV 0, Route 6: 101 → 81
#   AGV 0, Route 6: 101 → 82
#   AGV 0, Route 6: 101 → 83
#   AGV 0, Route 6: 101 → 84
#   AGV 0, Route 6: 101 → 85
#   AGV 0, Route 6: 101 → 86
#   AGV 0, Route 6: 101 → 87
#   AGV 0, Route 6: 101 → 88
#   AGV 0, Route 6: 101 → 89
#   AGV 0, Route 6: 101 → 90
#   AGV 0, Route 6: 101 → 91
#   AGV 0, Route 6: 101 → 92
#   AGV 0, Route 6: 101 → 93
#   AGV 0, Route 6: 101 → 94
#   AGV 0, Route 6: 101 → 95
#   AGV 0, Route 6: 101 → 96
#   AGV 0, Route 6: 101 → 97
#   AGV 0, Route 6: 101 → 98
#   AGV 0, Route 6: 101 → 99
#   AGV 0, Route 6: 101 → 100
#   AGV 0, Route 7: 0 → 101
#   AGV 0, Route 7: 101 → 0
#   AGV 0, Route 7: 101 → 1
#   AGV 0, Route 7: 101 → 2
#   AGV 0, Route 7: 101 → 3
#   AGV 0, Route 7: 101 → 4
#   AGV 0, Route 7: 101 → 5
#   AGV 0, Route 7: 101 → 6
#   AGV 0, Route 7: 101 → 7
#   AGV 0, Route 7: 101 → 8
#   AGV 0, Route 7: 101 → 9
#   AGV 0, Route 7: 101 → 10
#   AGV 0, Route 7: 101 → 11
#   AGV 0, Route 7: 101 → 12
#   AGV 0, Route 7: 101 → 13
#   AGV 0, Route 7: 101 → 14
#   AGV 0, Route 7: 101 → 15
#   AGV 0, Route 7: 101 → 16
#   AGV 0, Route 7: 101 → 17
#   AGV 0, Route 7: 101 → 18
#   AGV 0, Route 7: 101 → 19
#   AGV 0, Route 7: 101 → 20
#   AGV 0, Route 7: 101 → 21
#   AGV 0, Route 7: 101 → 22
#   AGV 0, Route 7: 101 → 23
#   AGV 0, Route 7: 101 → 24
#   AGV 0, Route 7: 101 → 25
#   AGV 0, Route 7: 101 → 26
#   AGV 0, Route 7: 101 → 27
#   AGV 0, Route 7: 101 → 28
#   AGV 0, Route 7: 101 → 29
#   AGV 0, Route 7: 101 → 30
#   AGV 0, Route 7: 101 → 31
#   AGV 0, Route 7: 101 → 32
#   AGV 0, Route 7: 101 → 33
#   AGV 0, Route 7: 101 → 34
#   AGV 0, Route 7: 101 → 35
#   AGV 0, Route 7: 101 → 36
#   AGV 0, Route 7: 101 → 37
#   AGV 0, Route 7: 101 → 38
#   AGV 0, Route 7: 101 → 39
#   AGV 0, Route 7: 101 → 40
#   AGV 0, Route 7: 101 → 41
#   AGV 0, Route 7: 101 → 42
#   AGV 0, Route 7: 101 → 43
#   AGV 0, Route 7: 101 → 44
#   AGV 0, Route 7: 101 → 45
#   AGV 0, Route 7: 101 → 46
#   AGV 0, Route 7: 101 → 47
#   AGV 0, Route 7: 101 → 48
#   AGV 0, Route 7: 101 → 49
#   AGV 0, Route 7: 101 → 50
#   AGV 0, Route 7: 101 → 51
#   AGV 0, Route 7: 101 → 52
#   AGV 0, Route 7: 101 → 53
#   AGV 0, Route 7: 101 → 54
#   AGV 0, Route 7: 101 → 55
#   AGV 0, Route 7: 101 → 56
#   AGV 0, Route 7: 101 → 57
#   AGV 0, Route 7: 101 → 58
#   AGV 0, Route 7: 101 → 59
#   AGV 0, Route 7: 101 → 60
#   AGV 0, Route 7: 101 → 61
#   AGV 0, Route 7: 101 → 62
#   AGV 0, Route 7: 101 → 63
#   AGV 0, Route 7: 101 → 64
#   AGV 0, Route 7: 101 → 65
#   AGV 0, Route 7: 101 → 66
#   AGV 0, Route 7: 101 → 67
#   AGV 0, Route 7: 101 → 68
#   AGV 0, Route 7: 101 → 69
#   AGV 0, Route 7: 101 → 70
#   AGV 0, Route 7: 101 → 71
#   AGV 0, Route 7: 101 → 72
#   AGV 0, Route 7: 101 → 73
#   AGV 0, Route 7: 101 → 74
#   AGV 0, Route 7: 101 → 75
#   AGV 0, Route 7: 101 → 76
#   AGV 0, Route 7: 101 → 77
#   AGV 0, Route 7: 101 → 78
#   AGV 0, Route 7: 101 → 79
#   AGV 0, Route 7: 101 → 80
#   AGV 0, Route 7: 101 → 81
#   AGV 0, Route 7: 101 → 82
#   AGV 0, Route 7: 101 → 83
#   AGV 0, Route 7: 101 → 84
#   AGV 0, Route 7: 101 → 85
#   AGV 0, Route 7: 101 → 86
#   AGV 0, Route 7: 101 → 87
#   AGV 0, Route 7: 101 → 88
#   AGV 0, Route 7: 101 → 89
#   AGV 0, Route 7: 101 → 90
#   AGV 0, Route 7: 101 → 91
#   AGV 0, Route 7: 101 → 92
#   AGV 0, Route 7: 101 → 93
#   AGV 0, Route 7: 101 → 94
#   AGV 0, Route 7: 101 → 95
#   AGV 0, Route 7: 101 → 96
#   AGV 0, Route 7: 101 → 97
#   AGV 0, Route 7: 101 → 98
#   AGV 0, Route 7: 101 → 99
#   AGV 0, Route 7: 101 → 100
#   AGV 0, Route 8: 0 → 93
#   AGV 0, Route 8: 0 → 101
#   AGV 0, Route 8: 93 → 0
#   AGV 0, Route 8: 101 → 0
#   AGV 0, Route 8: 101 → 1
#   AGV 0, Route 8: 101 → 2
#   AGV 0, Route 8: 101 → 3
#   AGV 0, Route 8: 101 → 4
#   AGV 0, Route 8: 101 → 5
#   AGV 0, Route 8: 101 → 6
#   AGV 0, Route 8: 101 → 7
#   AGV 0, Route 8: 101 → 8
#   AGV 0, Route 8: 101 → 9
#   AGV 0, Route 8: 101 → 10
#   AGV 0, Route 8: 101 → 11
#   AGV 0, Route 8: 101 → 12
#   AGV 0, Route 8: 101 → 13
#   AGV 0, Route 8: 101 → 14
#   AGV 0, Route 8: 101 → 15
#   AGV 0, Route 8: 101 → 16
#   AGV 0, Route 8: 101 → 17
#   AGV 0, Route 8: 101 → 18
#   AGV 0, Route 8: 101 → 19
#   AGV 0, Route 8: 101 → 20
#   AGV 0, Route 8: 101 → 21
#   AGV 0, Route 8: 101 → 22
#   AGV 0, Route 8: 101 → 23
#   AGV 0, Route 8: 101 → 24
#   AGV 0, Route 8: 101 → 25
#   AGV 0, Route 8: 101 → 26
#   AGV 0, Route 8: 101 → 27
#   AGV 0, Route 8: 101 → 28
#   AGV 0, Route 8: 101 → 29
#   AGV 0, Route 8: 101 → 30
#   AGV 0, Route 8: 101 → 31
#   AGV 0, Route 8: 101 → 32
#   AGV 0, Route 8: 101 → 33
#   AGV 0, Route 8: 101 → 34
#   AGV 0, Route 8: 101 → 35
#   AGV 0, Route 8: 101 → 36
#   AGV 0, Route 8: 101 → 37
#   AGV 0, Route 8: 101 → 38
#   AGV 0, Route 8: 101 → 39
#   AGV 0, Route 8: 101 → 40
#   AGV 0, Route 8: 101 → 41
#   AGV 0, Route 8: 101 → 42
#   AGV 0, Route 8: 101 → 43
#   AGV 0, Route 8: 101 → 44
#   AGV 0, Route 8: 101 → 45
#   AGV 0, Route 8: 101 → 46
#   AGV 0, Route 8: 101 → 47
#   AGV 0, Route 8: 101 → 48
#   AGV 0, Route 8: 101 → 49
#   AGV 0, Route 8: 101 → 50
#   AGV 0, Route 8: 101 → 51
#   AGV 0, Route 8: 101 → 52
#   AGV 0, Route 8: 101 → 53
#   AGV 0, Route 8: 101 → 54
#   AGV 0, Route 8: 101 → 55
#   AGV 0, Route 8: 101 → 56
#   AGV 0, Route 8: 101 → 57
#   AGV 0, Route 8: 101 → 58
#   AGV 0, Route 8: 101 → 59
#   AGV 0, Route 8: 101 → 60
#   AGV 0, Route 8: 101 → 61
#   AGV 0, Route 8: 101 → 62
#   AGV 0, Route 8: 101 → 63
#   AGV 0, Route 8: 101 → 64
#   AGV 0, Route 8: 101 → 65
#   AGV 0, Route 8: 101 → 66
#   AGV 0, Route 8: 101 → 67
#   AGV 0, Route 8: 101 → 68
#   AGV 0, Route 8: 101 → 69
#   AGV 0, Route 8: 101 → 70
#   AGV 0, Route 8: 101 → 71
#   AGV 0, Route 8: 101 → 72
#   AGV 0, Route 8: 101 → 73
#   AGV 0, Route 8: 101 → 74
#   AGV 0, Route 8: 101 → 75
#   AGV 0, Route 8: 101 → 76
#   AGV 0, Route 8: 101 → 77
#   AGV 0, Route 8: 101 → 78
#   AGV 0, Route 8: 101 → 79
#   AGV 0, Route 8: 101 → 80
#   AGV 0, Route 8: 101 → 81
#   AGV 0, Route 8: 101 → 82
#   AGV 0, Route 8: 101 → 83
#   AGV 0, Route 8: 101 → 84
#   AGV 0, Route 8: 101 → 85
#   AGV 0, Route 8: 101 → 86
#   AGV 0, Route 8: 101 → 87
#   AGV 0, Route 8: 101 → 88
#   AGV 0, Route 8: 101 → 89
#   AGV 0, Route 8: 101 → 90
#   AGV 0, Route 8: 101 → 91
#   AGV 0, Route 8: 101 → 92
#   AGV 0, Route 8: 101 → 93
#   AGV 0, Route 8: 101 → 94
#   AGV 0, Route 8: 101 → 95
#   AGV 0, Route 8: 101 → 96
#   AGV 0, Route 8: 101 → 97
#   AGV 0, Route 8: 101 → 98
#   AGV 0, Route 8: 101 → 99
#   AGV 0, Route 8: 101 → 100
#   AGV 0, Route 9: 0 → 101
#   AGV 0, Route 9: 101 → 0
#   AGV 0, Route 9: 101 → 1
#   AGV 0, Route 9: 101 → 2
#   AGV 0, Route 9: 101 → 3
#   AGV 0, Route 9: 101 → 4
#   AGV 0, Route 9: 101 → 5
#   AGV 0, Route 9: 101 → 6
#   AGV 0, Route 9: 101 → 7
#   AGV 0, Route 9: 101 → 8
#   AGV 0, Route 9: 101 → 9
#   AGV 0, Route 9: 101 → 10
#   AGV 0, Route 9: 101 → 11
#   AGV 0, Route 9: 101 → 12
#   AGV 0, Route 9: 101 → 13
#   AGV 0, Route 9: 101 → 14
#   AGV 0, Route 9: 101 → 15
#   AGV 0, Route 9: 101 → 16
#   AGV 0, Route 9: 101 → 17
#   AGV 0, Route 9: 101 → 18
#   AGV 0, Route 9: 101 → 19
#   AGV 0, Route 9: 101 → 20
#   AGV 0, Route 9: 101 → 21
#   AGV 0, Route 9: 101 → 22
#   AGV 0, Route 9: 101 → 23
#   AGV 0, Route 9: 101 → 24
#   AGV 0, Route 9: 101 → 25
#   AGV 0, Route 9: 101 → 26
#   AGV 0, Route 9: 101 → 27
#   AGV 0, Route 9: 101 → 28
#   AGV 0, Route 9: 101 → 29
#   AGV 0, Route 9: 101 → 30
#   AGV 0, Route 9: 101 → 31
#   AGV 0, Route 9: 101 → 32
#   AGV 0, Route 9: 101 → 33
#   AGV 0, Route 9: 101 → 34
#   AGV 0, Route 9: 101 → 35
#   AGV 0, Route 9: 101 → 36
#   AGV 0, Route 9: 101 → 37
#   AGV 0, Route 9: 101 → 38
#   AGV 0, Route 9: 101 → 39
#   AGV 0, Route 9: 101 → 40
#   AGV 0, Route 9: 101 → 41
#   AGV 0, Route 9: 101 → 42
#   AGV 0, Route 9: 101 → 43
#   AGV 0, Route 9: 101 → 44
#   AGV 0, Route 9: 101 → 45
#   AGV 0, Route 9: 101 → 46
#   AGV 0, Route 9: 101 → 47
#   AGV 0, Route 9: 101 → 48
#   AGV 0, Route 9: 101 → 49
#   AGV 0, Route 9: 101 → 50
#   AGV 0, Route 9: 101 → 51
#   AGV 0, Route 9: 101 → 52
#   AGV 0, Route 9: 101 → 53
#   AGV 0, Route 9: 101 → 54
#   AGV 0, Route 9: 101 → 55
#   AGV 0, Route 9: 101 → 56
#   AGV 0, Route 9: 101 → 57
#   AGV 0, Route 9: 101 → 58
#   AGV 0, Route 9: 101 → 59
#   AGV 0, Route 9: 101 → 60
#   AGV 0, Route 9: 101 → 61
#   AGV 0, Route 9: 101 → 62
#   AGV 0, Route 9: 101 → 63
#   AGV 0, Route 9: 101 → 64
#   AGV 0, Route 9: 101 → 65
#   AGV 0, Route 9: 101 → 66
#   AGV 0, Route 9: 101 → 67
#   AGV 0, Route 9: 101 → 68
#   AGV 0, Route 9: 101 → 69
#   AGV 0, Route 9: 101 → 70
#   AGV 0, Route 9: 101 → 71
#   AGV 0, Route 9: 101 → 72
#   AGV 0, Route 9: 101 → 73
#   AGV 0, Route 9: 101 → 74
#   AGV 0, Route 9: 101 → 75
#   AGV 0, Route 9: 101 → 76
#   AGV 0, Route 9: 101 → 77
#   AGV 0, Route 9: 101 → 78
#   AGV 0, Route 9: 101 → 79
#   AGV 0, Route 9: 101 → 80
#   AGV 0, Route 9: 101 → 81
#   AGV 0, Route 9: 101 → 82
#   AGV 0, Route 9: 101 → 83
#   AGV 0, Route 9: 101 → 84
#   AGV 0, Route 9: 101 → 85
#   AGV 0, Route 9: 101 → 86
#   AGV 0, Route 9: 101 → 87
#   AGV 0, Route 9: 101 → 88
#   AGV 0, Route 9: 101 → 89
#   AGV 0, Route 9: 101 → 90
#   AGV 0, Route 9: 101 → 91
#   AGV 0, Route 9: 101 → 92
#   AGV 0, Route 9: 101 → 93
#   AGV 0, Route 9: 101 → 94
#   AGV 0, Route 9: 101 → 95
#   AGV 0, Route 9: 101 → 96
#   AGV 0, Route 9: 101 → 97
#   AGV 0, Route 9: 101 → 98
#   AGV 0, Route 9: 101 → 99
#   AGV 0, Route 9: 101 → 100
#   AGV 0, Route 10: 0 → 101
#   AGV 0, Route 10: 101 → 0
#   AGV 0, Route 10: 101 → 1
#   AGV 0, Route 10: 101 → 2
#   AGV 0, Route 10: 101 → 3
#   AGV 0, Route 10: 101 → 4
#   AGV 0, Route 10: 101 → 5
#   AGV 0, Route 10: 101 → 6
#   AGV 0, Route 10: 101 → 7
#   AGV 0, Route 10: 101 → 8
#   AGV 0, Route 10: 101 → 9
#   AGV 0, Route 10: 101 → 10
#   AGV 0, Route 10: 101 → 11
#   AGV 0, Route 10: 101 → 12
#   AGV 0, Route 10: 101 → 13
#   AGV 0, Route 10: 101 → 14
#   AGV 0, Route 10: 101 → 15
#   AGV 0, Route 10: 101 → 16
#   AGV 0, Route 10: 101 → 17
#   AGV 0, Route 10: 101 → 18
#   AGV 0, Route 10: 101 → 19
#   AGV 0, Route 10: 101 → 20
#   AGV 0, Route 10: 101 → 21
#   AGV 0, Route 10: 101 → 22
#   AGV 0, Route 10: 101 → 23
#   AGV 0, Route 10: 101 → 24
#   AGV 0, Route 10: 101 → 25
#   AGV 0, Route 10: 101 → 26
#   AGV 0, Route 10: 101 → 27
#   AGV 0, Route 10: 101 → 28
#   AGV 0, Route 10: 101 → 29
#   AGV 0, Route 10: 101 → 30
#   AGV 0, Route 10: 101 → 31
#   AGV 0, Route 10: 101 → 32
#   AGV 0, Route 10: 101 → 33
#   AGV 0, Route 10: 101 → 34
#   AGV 0, Route 10: 101 → 35
#   AGV 0, Route 10: 101 → 36
#   AGV 0, Route 10: 101 → 37
#   AGV 0, Route 10: 101 → 38
#   AGV 0, Route 10: 101 → 39
#   AGV 0, Route 10: 101 → 40
#   AGV 0, Route 10: 101 → 41
#   AGV 0, Route 10: 101 → 42
#   AGV 0, Route 10: 101 → 43
#   AGV 0, Route 10: 101 → 44
#   AGV 0, Route 10: 101 → 45
#   AGV 0, Route 10: 101 → 46
#   AGV 0, Route 10: 101 → 47
#   AGV 0, Route 10: 101 → 48
#   AGV 0, Route 10: 101 → 49
#   AGV 0, Route 10: 101 → 50
#   AGV 0, Route 10: 101 → 51
#   AGV 0, Route 10: 101 → 52
#   AGV 0, Route 10: 101 → 53
#   AGV 0, Route 10: 101 → 54
#   AGV 0, Route 10: 101 → 55
#   AGV 0, Route 10: 101 → 56
#   AGV 0, Route 10: 101 → 57
#   AGV 0, Route 10: 101 → 58
#   AGV 0, Route 10: 101 → 59
#   AGV 0, Route 10: 101 → 60
#   AGV 0, Route 10: 101 → 61
#   AGV 0, Route 10: 101 → 62
#   AGV 0, Route 10: 101 → 63
#   AGV 0, Route 10: 101 → 64
#   AGV 0, Route 10: 101 → 65
#   AGV 0, Route 10: 101 → 66
#   AGV 0, Route 10: 101 → 67
#   AGV 0, Route 10: 101 → 68
#   AGV 0, Route 10: 101 → 69
#   AGV 0, Route 10: 101 → 70
#   AGV 0, Route 10: 101 → 71
#   AGV 0, Route 10: 101 → 72
#   AGV 0, Route 10: 101 → 73
#   AGV 0, Route 10: 101 → 74
#   AGV 0, Route 10: 101 → 75
#   AGV 0, Route 10: 101 → 76
#   AGV 0, Route 10: 101 → 77
#   AGV 0, Route 10: 101 → 78
#   AGV 0, Route 10: 101 → 79
#   AGV 0, Route 10: 101 → 80
#   AGV 0, Route 10: 101 → 81
#   AGV 0, Route 10: 101 → 82
#   AGV 0, Route 10: 101 → 83
#   AGV 0, Route 10: 101 → 84
#   AGV 0, Route 10: 101 → 85
#   AGV 0, Route 10: 101 → 86
#   AGV 0, Route 10: 101 → 87
#   AGV 0, Route 10: 101 → 88
#   AGV 0, Route 10: 101 → 89
#   AGV 0, Route 10: 101 → 90
#   AGV 0, Route 10: 101 → 91
#   AGV 0, Route 10: 101 → 92
#   AGV 0, Route 10: 101 → 93
#   AGV 0, Route 10: 101 → 94
#   AGV 0, Route 10: 101 → 95
#   AGV 0, Route 10: 101 → 96
#   AGV 0, Route 10: 101 → 97
#   AGV 0, Route 10: 101 → 98
#   AGV 0, Route 10: 101 → 99
#   AGV 0, Route 10: 101 → 100
#   AGV 0, Route 11: 0 → 101
#   AGV 0, Route 11: 101 → 0
#   AGV 0, Route 11: 101 → 1
#   AGV 0, Route 11: 101 → 2
#   AGV 0, Route 11: 101 → 3
#   AGV 0, Route 11: 101 → 4
#   AGV 0, Route 11: 101 → 5
#   AGV 0, Route 11: 101 → 6
#   AGV 0, Route 11: 101 → 7
#   AGV 0, Route 11: 101 → 8
#   AGV 0, Route 11: 101 → 9
#   AGV 0, Route 11: 101 → 10
#   AGV 0, Route 11: 101 → 11
#   AGV 0, Route 11: 101 → 12
#   AGV 0, Route 11: 101 → 13
#   AGV 0, Route 11: 101 → 14
#   AGV 0, Route 11: 101 → 15
#   AGV 0, Route 11: 101 → 16
#   AGV 0, Route 11: 101 → 17
#   AGV 0, Route 11: 101 → 18
#   AGV 0, Route 11: 101 → 19
#   AGV 0, Route 11: 101 → 20
#   AGV 0, Route 11: 101 → 21
#   AGV 0, Route 11: 101 → 22
#   AGV 0, Route 11: 101 → 23
#   AGV 0, Route 11: 101 → 24
#   AGV 0, Route 11: 101 → 25
#   AGV 0, Route 11: 101 → 26
#   AGV 0, Route 11: 101 → 27
#   AGV 0, Route 11: 101 → 28
#   AGV 0, Route 11: 101 → 29
#   AGV 0, Route 11: 101 → 30
#   AGV 0, Route 11: 101 → 31
#   AGV 0, Route 11: 101 → 32
#   AGV 0, Route 11: 101 → 33
#   AGV 0, Route 11: 101 → 34
#   AGV 0, Route 11: 101 → 35
#   AGV 0, Route 11: 101 → 36
#   AGV 0, Route 11: 101 → 37
#   AGV 0, Route 11: 101 → 38
#   AGV 0, Route 11: 101 → 39
#   AGV 0, Route 11: 101 → 40
#   AGV 0, Route 11: 101 → 41
#   AGV 0, Route 11: 101 → 42
#   AGV 0, Route 11: 101 → 43
#   AGV 0, Route 11: 101 → 44
#   AGV 0, Route 11: 101 → 45
#   AGV 0, Route 11: 101 → 46
#   AGV 0, Route 11: 101 → 47
#   AGV 0, Route 11: 101 → 48
#   AGV 0, Route 11: 101 → 49
#   AGV 0, Route 11: 101 → 50
#   AGV 0, Route 11: 101 → 51
#   AGV 0, Route 11: 101 → 52
#   AGV 0, Route 11: 101 → 53
#   AGV 0, Route 11: 101 → 54
#   AGV 0, Route 11: 101 → 55
#   AGV 0, Route 11: 101 → 56
#   AGV 0, Route 11: 101 → 57
#   AGV 0, Route 11: 101 → 58
#   AGV 0, Route 11: 101 → 59
#   AGV 0, Route 11: 101 → 60
#   AGV 0, Route 11: 101 → 61
#   AGV 0, Route 11: 101 → 62
#   AGV 0, Route 11: 101 → 63
#   AGV 0, Route 11: 101 → 64
#   AGV 0, Route 11: 101 → 65
#   AGV 0, Route 11: 101 → 66
#   AGV 0, Route 11: 101 → 67
#   AGV 0, Route 11: 101 → 68
#   AGV 0, Route 11: 101 → 69
#   AGV 0, Route 11: 101 → 70
#   AGV 0, Route 11: 101 → 71
#   AGV 0, Route 11: 101 → 72
#   AGV 0, Route 11: 101 → 73
#   AGV 0, Route 11: 101 → 74
#   AGV 0, Route 11: 101 → 75
#   AGV 0, Route 11: 101 → 76
#   AGV 0, Route 11: 101 → 77
#   AGV 0, Route 11: 101 → 78
#   AGV 0, Route 11: 101 → 79
#   AGV 0, Route 11: 101 → 80
#   AGV 0, Route 11: 101 → 81
#   AGV 0, Route 11: 101 → 82
#   AGV 0, Route 11: 101 → 83
#   AGV 0, Route 11: 101 → 84
#   AGV 0, Route 11: 101 → 85
#   AGV 0, Route 11: 101 → 86
#   AGV 0, Route 11: 101 → 87
#   AGV 0, Route 11: 101 → 88
#   AGV 0, Route 11: 101 → 89
#   AGV 0, Route 11: 101 → 90
#   AGV 0, Route 11: 101 → 91
#   AGV 0, Route 11: 101 → 92
#   AGV 0, Route 11: 101 → 93
#   AGV 0, Route 11: 101 → 94
#   AGV 0, Route 11: 101 → 95
#   AGV 0, Route 11: 101 → 96
#   AGV 0, Route 11: 101 → 97
#   AGV 0, Route 11: 101 → 98
#   AGV 0, Route 11: 101 → 99
#   AGV 0, Route 11: 101 → 100
#   AGV 0, Route 12: 0 → 101
#   AGV 0, Route 12: 101 → 0
#   AGV 0, Route 12: 101 → 1
#   AGV 0, Route 12: 101 → 2
#   AGV 0, Route 12: 101 → 3
#   AGV 0, Route 12: 101 → 4
#   AGV 0, Route 12: 101 → 5
#   AGV 0, Route 12: 101 → 6
#   AGV 0, Route 12: 101 → 7
#   AGV 0, Route 12: 101 → 8
#   AGV 0, Route 12: 101 → 9
#   AGV 0, Route 12: 101 → 10
#   AGV 0, Route 12: 101 → 11
#   AGV 0, Route 12: 101 → 12
#   AGV 0, Route 12: 101 → 13
#   AGV 0, Route 12: 101 → 14
#   AGV 0, Route 12: 101 → 15
#   AGV 0, Route 12: 101 → 16
#   AGV 0, Route 12: 101 → 17
#   AGV 0, Route 12: 101 → 18
#   AGV 0, Route 12: 101 → 19
#   AGV 0, Route 12: 101 → 20
#   AGV 0, Route 12: 101 → 21
#   AGV 0, Route 12: 101 → 22
#   AGV 0, Route 12: 101 → 23
#   AGV 0, Route 12: 101 → 24
#   AGV 0, Route 12: 101 → 25
#   AGV 0, Route 12: 101 → 26
#   AGV 0, Route 12: 101 → 27
#   AGV 0, Route 12: 101 → 28
#   AGV 0, Route 12: 101 → 29
#   AGV 0, Route 12: 101 → 30
#   AGV 0, Route 12: 101 → 31
#   AGV 0, Route 12: 101 → 32
#   AGV 0, Route 12: 101 → 33
#   AGV 0, Route 12: 101 → 34
#   AGV 0, Route 12: 101 → 35
#   AGV 0, Route 12: 101 → 36
#   AGV 0, Route 12: 101 → 37
#   AGV 0, Route 12: 101 → 38
#   AGV 0, Route 12: 101 → 39
#   AGV 0, Route 12: 101 → 40
#   AGV 0, Route 12: 101 → 41
#   AGV 0, Route 12: 101 → 42
#   AGV 0, Route 12: 101 → 43
#   AGV 0, Route 12: 101 → 44
#   AGV 0, Route 12: 101 → 45
#   AGV 0, Route 12: 101 → 46
#   AGV 0, Route 12: 101 → 47
#   AGV 0, Route 12: 101 → 48
#   AGV 0, Route 12: 101 → 49
#   AGV 0, Route 12: 101 → 50
#   AGV 0, Route 12: 101 → 51
#   AGV 0, Route 12: 101 → 52
#   AGV 0, Route 12: 101 → 53
#   AGV 0, Route 12: 101 → 54
#   AGV 0, Route 12: 101 → 55
#   AGV 0, Route 12: 101 → 56
#   AGV 0, Route 12: 101 → 57
#   AGV 0, Route 12: 101 → 58
#   AGV 0, Route 12: 101 → 59
#   AGV 0, Route 12: 101 → 60
#   AGV 0, Route 12: 101 → 61
#   AGV 0, Route 12: 101 → 62
#   AGV 0, Route 12: 101 → 63
#   AGV 0, Route 12: 101 → 64
#   AGV 0, Route 12: 101 → 65
#   AGV 0, Route 12: 101 → 66
#   AGV 0, Route 12: 101 → 67
#   AGV 0, Route 12: 101 → 68
#   AGV 0, Route 12: 101 → 69
#   AGV 0, Route 12: 101 → 70
#   AGV 0, Route 12: 101 → 71
#   AGV 0, Route 12: 101 → 72
#   AGV 0, Route 12: 101 → 73
#   AGV 0, Route 12: 101 → 74
#   AGV 0, Route 12: 101 → 75
#   AGV 0, Route 12: 101 → 76
#   AGV 0, Route 12: 101 → 77
#   AGV 0, Route 12: 101 → 78
#   AGV 0, Route 12: 101 → 79
#   AGV 0, Route 12: 101 → 80
#   AGV 0, Route 12: 101 → 81
#   AGV 0, Route 12: 101 → 82
#   AGV 0, Route 12: 101 → 83
#   AGV 0, Route 12: 101 → 84
#   AGV 0, Route 12: 101 → 85
#   AGV 0, Route 12: 101 → 86
#   AGV 0, Route 12: 101 → 87
#   AGV 0, Route 12: 101 → 88
#   AGV 0, Route 12: 101 → 89
#   AGV 0, Route 12: 101 → 90
#   AGV 0, Route 12: 101 → 91
#   AGV 0, Route 12: 101 → 92
#   AGV 0, Route 12: 101 → 93
#   AGV 0, Route 12: 101 → 94
#   AGV 0, Route 12: 101 → 95
#   AGV 0, Route 12: 101 → 96
#   AGV 0, Route 12: 101 → 97
#   AGV 0, Route 12: 101 → 98
#   AGV 0, Route 12: 101 → 99
#   AGV 0, Route 12: 101 → 100
#   AGV 0, Route 13: 0 → 101
#   AGV 0, Route 13: 101 → 0
#   AGV 0, Route 13: 101 → 1
#   AGV 0, Route 13: 101 → 2
#   AGV 0, Route 13: 101 → 3
#   AGV 0, Route 13: 101 → 4
#   AGV 0, Route 13: 101 → 5
#   AGV 0, Route 13: 101 → 6
#   AGV 0, Route 13: 101 → 7
#   AGV 0, Route 13: 101 → 8
#   AGV 0, Route 13: 101 → 9
#   AGV 0, Route 13: 101 → 10
#   AGV 0, Route 13: 101 → 11
#   AGV 0, Route 13: 101 → 12
#   AGV 0, Route 13: 101 → 13
#   AGV 0, Route 13: 101 → 14
#   AGV 0, Route 13: 101 → 15
#   AGV 0, Route 13: 101 → 16
#   AGV 0, Route 13: 101 → 17
#   AGV 0, Route 13: 101 → 18
#   AGV 0, Route 13: 101 → 19
#   AGV 0, Route 13: 101 → 20
#   AGV 0, Route 13: 101 → 21
#   AGV 0, Route 13: 101 → 22
#   AGV 0, Route 13: 101 → 23
#   AGV 0, Route 13: 101 → 24
#   AGV 0, Route 13: 101 → 25
#   AGV 0, Route 13: 101 → 26
#   AGV 0, Route 13: 101 → 27
#   AGV 0, Route 13: 101 → 28
#   AGV 0, Route 13: 101 → 29
#   AGV 0, Route 13: 101 → 30
#   AGV 0, Route 13: 101 → 31
#   AGV 0, Route 13: 101 → 32
#   AGV 0, Route 13: 101 → 33
#   AGV 0, Route 13: 101 → 34
#   AGV 0, Route 13: 101 → 35
#   AGV 0, Route 13: 101 → 36
#   AGV 0, Route 13: 101 → 37
#   AGV 0, Route 13: 101 → 38
#   AGV 0, Route 13: 101 → 39
#   AGV 0, Route 13: 101 → 40
#   AGV 0, Route 13: 101 → 41
#   AGV 0, Route 13: 101 → 42
#   AGV 0, Route 13: 101 → 43
#   AGV 0, Route 13: 101 → 44
#   AGV 0, Route 13: 101 → 45
#   AGV 0, Route 13: 101 → 46
#   AGV 0, Route 13: 101 → 47
#   AGV 0, Route 13: 101 → 48
#   AGV 0, Route 13: 101 → 49
#   AGV 0, Route 13: 101 → 50
#   AGV 0, Route 13: 101 → 51
#   AGV 0, Route 13: 101 → 52
#   AGV 0, Route 13: 101 → 53
#   AGV 0, Route 13: 101 → 54
#   AGV 0, Route 13: 101 → 55
#   AGV 0, Route 13: 101 → 56
#   AGV 0, Route 13: 101 → 57
#   AGV 0, Route 13: 101 → 58
#   AGV 0, Route 13: 101 → 59
#   AGV 0, Route 13: 101 → 60
#   AGV 0, Route 13: 101 → 61
#   AGV 0, Route 13: 101 → 62
#   AGV 0, Route 13: 101 → 63
#   AGV 0, Route 13: 101 → 64
#   AGV 0, Route 13: 101 → 65
#   AGV 0, Route 13: 101 → 66
#   AGV 0, Route 13: 101 → 67
#   AGV 0, Route 13: 101 → 68
#   AGV 0, Route 13: 101 → 69
#   AGV 0, Route 13: 101 → 70
#   AGV 0, Route 13: 101 → 71
#   AGV 0, Route 13: 101 → 72
#   AGV 0, Route 13: 101 → 73
#   AGV 0, Route 13: 101 → 74
#   AGV 0, Route 13: 101 → 75
#   AGV 0, Route 13: 101 → 76
#   AGV 0, Route 13: 101 → 77
#   AGV 0, Route 13: 101 → 78
#   AGV 0, Route 13: 101 → 79
#   AGV 0, Route 13: 101 → 80
#   AGV 0, Route 13: 101 → 81
#   AGV 0, Route 13: 101 → 82
#   AGV 0, Route 13: 101 → 83
#   AGV 0, Route 13: 101 → 84
#   AGV 0, Route 13: 101 → 85
#   AGV 0, Route 13: 101 → 86
#   AGV 0, Route 13: 101 → 87
#   AGV 0, Route 13: 101 → 88
#   AGV 0, Route 13: 101 → 89
#   AGV 0, Route 13: 101 → 90
#   AGV 0, Route 13: 101 → 91
#   AGV 0, Route 13: 101 → 92
#   AGV 0, Route 13: 101 → 93
#   AGV 0, Route 13: 101 → 94
#   AGV 0, Route 13: 101 → 95
#   AGV 0, Route 13: 101 → 96
#   AGV 0, Route 13: 101 → 97
#   AGV 0, Route 13: 101 → 98
#   AGV 0, Route 13: 101 → 99
#   AGV 0, Route 13: 101 → 100
#   AGV 0, Route 14: 0 → 101
#   AGV 0, Route 14: 101 → 0
#   AGV 0, Route 14: 101 → 1
#   AGV 0, Route 14: 101 → 2
#   AGV 0, Route 14: 101 → 3
#   AGV 0, Route 14: 101 → 4
#   AGV 0, Route 14: 101 → 5
#   AGV 0, Route 14: 101 → 6
#   AGV 0, Route 14: 101 → 7
#   AGV 0, Route 14: 101 → 8
#   AGV 0, Route 14: 101 → 9
#   AGV 0, Route 14: 101 → 10
#   AGV 0, Route 14: 101 → 11
#   AGV 0, Route 14: 101 → 12
#   AGV 0, Route 14: 101 → 13
#   AGV 0, Route 14: 101 → 14
#   AGV 0, Route 14: 101 → 15
#   AGV 0, Route 14: 101 → 16
#   AGV 0, Route 14: 101 → 17
#   AGV 0, Route 14: 101 → 18
#   AGV 0, Route 14: 101 → 19
#   AGV 0, Route 14: 101 → 20
#   AGV 0, Route 14: 101 → 21
#   AGV 0, Route 14: 101 → 22
#   AGV 0, Route 14: 101 → 23
#   AGV 0, Route 14: 101 → 24
#   AGV 0, Route 14: 101 → 25
#   AGV 0, Route 14: 101 → 26
#   AGV 0, Route 14: 101 → 27
#   AGV 0, Route 14: 101 → 28
#   AGV 0, Route 14: 101 → 29
#   AGV 0, Route 14: 101 → 30
#   AGV 0, Route 14: 101 → 31
#   AGV 0, Route 14: 101 → 32
#   AGV 0, Route 14: 101 → 33
#   AGV 0, Route 14: 101 → 34
#   AGV 0, Route 14: 101 → 35
#   AGV 0, Route 14: 101 → 36
#   AGV 0, Route 14: 101 → 37
#   AGV 0, Route 14: 101 → 38
#   AGV 0, Route 14: 101 → 39
#   AGV 0, Route 14: 101 → 40
#   AGV 0, Route 14: 101 → 41
#   AGV 0, Route 14: 101 → 42
#   AGV 0, Route 14: 101 → 43
#   AGV 0, Route 14: 101 → 44
#   AGV 0, Route 14: 101 → 45
#   AGV 0, Route 14: 101 → 46
#   AGV 0, Route 14: 101 → 47
#   AGV 0, Route 14: 101 → 48
#   AGV 0, Route 14: 101 → 49
#   AGV 0, Route 14: 101 → 50
#   AGV 0, Route 14: 101 → 51
#   AGV 0, Route 14: 101 → 52
#   AGV 0, Route 14: 101 → 53
#   AGV 0, Route 14: 101 → 54
#   AGV 0, Route 14: 101 → 55
#   AGV 0, Route 14: 101 → 56
#   AGV 0, Route 14: 101 → 57
#   AGV 0, Route 14: 101 → 58
#   AGV 0, Route 14: 101 → 59
#   AGV 0, Route 14: 101 → 60
#   AGV 0, Route 14: 101 → 61
#   AGV 0, Route 14: 101 → 62
#   AGV 0, Route 14: 101 → 63
#   AGV 0, Route 14: 101 → 64
#   AGV 0, Route 14: 101 → 65
#   AGV 0, Route 14: 101 → 66
#   AGV 0, Route 14: 101 → 67
#   AGV 0, Route 14: 101 → 68
#   AGV 0, Route 14: 101 → 69
#   AGV 0, Route 14: 101 → 70
#   AGV 0, Route 14: 101 → 71
#   AGV 0, Route 14: 101 → 72
#   AGV 0, Route 14: 101 → 73
#   AGV 0, Route 14: 101 → 74
#   AGV 0, Route 14: 101 → 75
#   AGV 0, Route 14: 101 → 76
#   AGV 0, Route 14: 101 → 77
#   AGV 0, Route 14: 101 → 78
#   AGV 0, Route 14: 101 → 79
#   AGV 0, Route 14: 101 → 80
#   AGV 0, Route 14: 101 → 81
#   AGV 0, Route 14: 101 → 82
#   AGV 0, Route 14: 101 → 83
#   AGV 0, Route 14: 101 → 84
#   AGV 0, Route 14: 101 → 85
#   AGV 0, Route 14: 101 → 86
#   AGV 0, Route 14: 101 → 87
#   AGV 0, Route 14: 101 → 88
#   AGV 0, Route 14: 101 → 89
#   AGV 0, Route 14: 101 → 90
#   AGV 0, Route 14: 101 → 91
#   AGV 0, Route 14: 101 → 92
#   AGV 0, Route 14: 101 → 93
#   AGV 0, Route 14: 101 → 94
#   AGV 0, Route 14: 101 → 95
#   AGV 0, Route 14: 101 → 96
#   AGV 0, Route 14: 101 → 97
#   AGV 0, Route 14: 101 → 98
#   AGV 0, Route 14: 101 → 99
#   AGV 0, Route 14: 101 → 100
#   AGV 0, Route 15: 0 → 101
#   AGV 0, Route 15: 101 → 0
#   AGV 0, Route 15: 101 → 1
#   AGV 0, Route 15: 101 → 2
#   AGV 0, Route 15: 101 → 3
#   AGV 0, Route 15: 101 → 4
#   AGV 0, Route 15: 101 → 5
#   AGV 0, Route 15: 101 → 6
#   AGV 0, Route 15: 101 → 7
#   AGV 0, Route 15: 101 → 8
#   AGV 0, Route 15: 101 → 9
#   AGV 0, Route 15: 101 → 10
#   AGV 0, Route 15: 101 → 11
#   AGV 0, Route 15: 101 → 12
#   AGV 0, Route 15: 101 → 13
#   AGV 0, Route 15: 101 → 14
#   AGV 0, Route 15: 101 → 15
#   AGV 0, Route 15: 101 → 16
#   AGV 0, Route 15: 101 → 17
#   AGV 0, Route 15: 101 → 18
#   AGV 0, Route 15: 101 → 19
#   AGV 0, Route 15: 101 → 20
#   AGV 0, Route 15: 101 → 21
#   AGV 0, Route 15: 101 → 22
#   AGV 0, Route 15: 101 → 23
#   AGV 0, Route 15: 101 → 24
#   AGV 0, Route 15: 101 → 25
#   AGV 0, Route 15: 101 → 26
#   AGV 0, Route 15: 101 → 27
#   AGV 0, Route 15: 101 → 28
#   AGV 0, Route 15: 101 → 29
#   AGV 0, Route 15: 101 → 30
#   AGV 0, Route 15: 101 → 31
#   AGV 0, Route 15: 101 → 32
#   AGV 0, Route 15: 101 → 33
#   AGV 0, Route 15: 101 → 34
#   AGV 0, Route 15: 101 → 35
#   AGV 0, Route 15: 101 → 36
#   AGV 0, Route 15: 101 → 37
#   AGV 0, Route 15: 101 → 38
#   AGV 0, Route 15: 101 → 39
#   AGV 0, Route 15: 101 → 40
#   AGV 0, Route 15: 101 → 41
#   AGV 0, Route 15: 101 → 42
#   AGV 0, Route 15: 101 → 43
#   AGV 0, Route 15: 101 → 44
#   AGV 0, Route 15: 101 → 45
#   AGV 0, Route 15: 101 → 46
#   AGV 0, Route 15: 101 → 47
#   AGV 0, Route 15: 101 → 48
#   AGV 0, Route 15: 101 → 49
#   AGV 0, Route 15: 101 → 50
#   AGV 0, Route 15: 101 → 51
#   AGV 0, Route 15: 101 → 52
#   AGV 0, Route 15: 101 → 53
#   AGV 0, Route 15: 101 → 54
#   AGV 0, Route 15: 101 → 55
#   AGV 0, Route 15: 101 → 56
#   AGV 0, Route 15: 101 → 57
#   AGV 0, Route 15: 101 → 58
#   AGV 0, Route 15: 101 → 59
#   AGV 0, Route 15: 101 → 60
#   AGV 0, Route 15: 101 → 61
#   AGV 0, Route 15: 101 → 62
#   AGV 0, Route 15: 101 → 63
#   AGV 0, Route 15: 101 → 64
#   AGV 0, Route 15: 101 → 65
#   AGV 0, Route 15: 101 → 66
#   AGV 0, Route 15: 101 → 67
#   AGV 0, Route 15: 101 → 68
#   AGV 0, Route 15: 101 → 69
#   AGV 0, Route 15: 101 → 70
#   AGV 0, Route 15: 101 → 71
#   AGV 0, Route 15: 101 → 72
#   AGV 0, Route 15: 101 → 73
#   AGV 0, Route 15: 101 → 74
#   AGV 0, Route 15: 101 → 75
#   AGV 0, Route 15: 101 → 76
#   AGV 0, Route 15: 101 → 77
#   AGV 0, Route 15: 101 → 78
#   AGV 0, Route 15: 101 → 79
#   AGV 0, Route 15: 101 → 80
#   AGV 0, Route 15: 101 → 81
#   AGV 0, Route 15: 101 → 82
#   AGV 0, Route 15: 101 → 83
#   AGV 0, Route 15: 101 → 84
#   AGV 0, Route 15: 101 → 85
#   AGV 0, Route 15: 101 → 86
#   AGV 0, Route 15: 101 → 87
#   AGV 0, Route 15: 101 → 88
#   AGV 0, Route 15: 101 → 89
#   AGV 0, Route 15: 101 → 90
#   AGV 0, Route 15: 101 → 91
#   AGV 0, Route 15: 101 → 92
#   AGV 0, Route 15: 101 → 93
#   AGV 0, Route 15: 101 → 94
#   AGV 0, Route 15: 101 → 95
#   AGV 0, Route 15: 101 → 96
#   AGV 0, Route 15: 101 → 97
#   AGV 0, Route 15: 101 → 98
#   AGV 0, Route 15: 101 → 99
#   AGV 0, Route 15: 101 → 100
#   AGV 0, Route 16: 0 → 101
#   AGV 0, Route 16: 101 → 0
#   AGV 0, Route 16: 101 → 1
#   AGV 0, Route 16: 101 → 2
#   AGV 0, Route 16: 101 → 3
#   AGV 0, Route 16: 101 → 4
#   AGV 0, Route 16: 101 → 5
#   AGV 0, Route 16: 101 → 6
#   AGV 0, Route 16: 101 → 7
#   AGV 0, Route 16: 101 → 8
#   AGV 0, Route 16: 101 → 9
#   AGV 0, Route 16: 101 → 10
#   AGV 0, Route 16: 101 → 11
#   AGV 0, Route 16: 101 → 12
#   AGV 0, Route 16: 101 → 13
#   AGV 0, Route 16: 101 → 14
#   AGV 0, Route 16: 101 → 15
#   AGV 0, Route 16: 101 → 16
#   AGV 0, Route 16: 101 → 17
#   AGV 0, Route 16: 101 → 18
#   AGV 0, Route 16: 101 → 19
#   AGV 0, Route 16: 101 → 20
#   AGV 0, Route 16: 101 → 21
#   AGV 0, Route 16: 101 → 22
#   AGV 0, Route 16: 101 → 23
#   AGV 0, Route 16: 101 → 24
#   AGV 0, Route 16: 101 → 25
#   AGV 0, Route 16: 101 → 26
#   AGV 0, Route 16: 101 → 27
#   AGV 0, Route 16: 101 → 28
#   AGV 0, Route 16: 101 → 29
#   AGV 0, Route 16: 101 → 30
#   AGV 0, Route 16: 101 → 31
#   AGV 0, Route 16: 101 → 32
#   AGV 0, Route 16: 101 → 33
#   AGV 0, Route 16: 101 → 34
#   AGV 0, Route 16: 101 → 35
#   AGV 0, Route 16: 101 → 36
#   AGV 0, Route 16: 101 → 37
#   AGV 0, Route 16: 101 → 38
#   AGV 0, Route 16: 101 → 39
#   AGV 0, Route 16: 101 → 40
#   AGV 0, Route 16: 101 → 41
#   AGV 0, Route 16: 101 → 42
#   AGV 0, Route 16: 101 → 43
#   AGV 0, Route 16: 101 → 44
#   AGV 0, Route 16: 101 → 45
#   AGV 0, Route 16: 101 → 46
#   AGV 0, Route 16: 101 → 47
#   AGV 0, Route 16: 101 → 48
#   AGV 0, Route 16: 101 → 49
#   AGV 0, Route 16: 101 → 50
#   AGV 0, Route 16: 101 → 51
#   AGV 0, Route 16: 101 → 52
#   AGV 0, Route 16: 101 → 53
#   AGV 0, Route 16: 101 → 54
#   AGV 0, Route 16: 101 → 55
#   AGV 0, Route 16: 101 → 56
#   AGV 0, Route 16: 101 → 57
#   AGV 0, Route 16: 101 → 58
#   AGV 0, Route 16: 101 → 59
#   AGV 0, Route 16: 101 → 60
#   AGV 0, Route 16: 101 → 61
#   AGV 0, Route 16: 101 → 62
#   AGV 0, Route 16: 101 → 63
#   AGV 0, Route 16: 101 → 64
#   AGV 0, Route 16: 101 → 65
#   AGV 0, Route 16: 101 → 66
#   AGV 0, Route 16: 101 → 67
#   AGV 0, Route 16: 101 → 68
#   AGV 0, Route 16: 101 → 69
#   AGV 0, Route 16: 101 → 70
#   AGV 0, Route 16: 101 → 71
#   AGV 0, Route 16: 101 → 72
#   AGV 0, Route 16: 101 → 73
#   AGV 0, Route 16: 101 → 74
#   AGV 0, Route 16: 101 → 75
#   AGV 0, Route 16: 101 → 76
#   AGV 0, Route 16: 101 → 77
#   AGV 0, Route 16: 101 → 78
#   AGV 0, Route 16: 101 → 79
#   AGV 0, Route 16: 101 → 80
# ...
#   AGV 14, Route 47: 101 → 58
#   AGV 14, Route 47: 101 → 59
#   AGV 14, Route 47: 101 → 60
#   AGV 14, Route 47: 101 → 61
#   AGV 14, Route 47: 101 → 62
#   AGV 14, Route 47: 101 → 63
#   AGV 14, Route 47: 101 → 64
#   AGV 14, Route 47: 101 → 65
#   AGV 14, Route 47: 101 → 66
#   AGV 14, Route 47: 101 → 67
#   AGV 14, Route 47: 101 → 68
#   AGV 14, Route 47: 101 → 69
#   AGV 14, Route 47: 101 → 70
#   AGV 14, Route 47: 101 → 71
#   AGV 14, Route 47: 101 → 72
#   AGV 14, Route 47: 101 → 73
#   AGV 14, Route 47: 101 → 74
#   AGV 14, Route 47: 101 → 75
#   AGV 14, Route 47: 101 → 76
#   AGV 14, Route 47: 101 → 77
#   AGV 14, Route 47: 101 → 78
#   AGV 14, Route 47: 101 → 79
#   AGV 14, Route 47: 101 → 80
#   AGV 14, Route 47: 101 → 81
#   AGV 14, Route 47: 101 → 82
#   AGV 14, Route 47: 101 → 83
#   AGV 14, Route 47: 101 → 84
#   AGV 14, Route 47: 101 → 85
#   AGV 14, Route 47: 101 → 86
#   AGV 14, Route 47: 101 → 87
#   AGV 14, Route 47: 101 → 88
#   AGV 14, Route 47: 101 → 89
#   AGV 14, Route 47: 101 → 90
#   AGV 14, Route 47: 101 → 91
#   AGV 14, Route 47: 101 → 92
#   AGV 14, Route 47: 101 → 93
#   AGV 14, Route 47: 101 → 94
#   AGV 14, Route 47: 101 → 95
#   AGV 14, Route 47: 101 → 96
#   AGV 14, Route 47: 101 → 97
#   AGV 14, Route 47: 101 → 98
#   AGV 14, Route 47: 101 → 99
#   AGV 14, Route 47: 101 → 100
#   AGV 14, Route 48: 0 → 101
#   AGV 14, Route 48: 101 → 0
#   AGV 14, Route 48: 101 → 1
#   AGV 14, Route 48: 101 → 2
#   AGV 14, Route 48: 101 → 3
#   AGV 14, Route 48: 101 → 4
#   AGV 14, Route 48: 101 → 5
#   AGV 14, Route 48: 101 → 6
#   AGV 14, Route 48: 101 → 7
#   AGV 14, Route 48: 101 → 8
#   AGV 14, Route 48: 101 → 9
#   AGV 14, Route 48: 101 → 10
#   AGV 14, Route 48: 101 → 11
#   AGV 14, Route 48: 101 → 12
#   AGV 14, Route 48: 101 → 13
#   AGV 14, Route 48: 101 → 14
#   AGV 14, Route 48: 101 → 15
#   AGV 14, Route 48: 101 → 16
#   AGV 14, Route 48: 101 → 17
#   AGV 14, Route 48: 101 → 18
#   AGV 14, Route 48: 101 → 19
#   AGV 14, Route 48: 101 → 20
#   AGV 14, Route 48: 101 → 21
#   AGV 14, Route 48: 101 → 22
#   AGV 14, Route 48: 101 → 23
#   AGV 14, Route 48: 101 → 24
#   AGV 14, Route 48: 101 → 25
#   AGV 14, Route 48: 101 → 26
#   AGV 14, Route 48: 101 → 27
#   AGV 14, Route 48: 101 → 28
#   AGV 14, Route 48: 101 → 29
#   AGV 14, Route 48: 101 → 30
#   AGV 14, Route 48: 101 → 31
#   AGV 14, Route 48: 101 → 32
#   AGV 14, Route 48: 101 → 33
#   AGV 14, Route 48: 101 → 34
#   AGV 14, Route 48: 101 → 35
#   AGV 14, Route 48: 101 → 36
#   AGV 14, Route 48: 101 → 37
#   AGV 14, Route 48: 101 → 38
#   AGV 14, Route 48: 101 → 39
#   AGV 14, Route 48: 101 → 40
#   AGV 14, Route 48: 101 → 41
#   AGV 14, Route 48: 101 → 42
#   AGV 14, Route 48: 101 → 43
#   AGV 14, Route 48: 101 → 44
#   AGV 14, Route 48: 101 → 45
#   AGV 14, Route 48: 101 → 46
#   AGV 14, Route 48: 101 → 47
#   AGV 14, Route 48: 101 → 48
#   AGV 14, Route 48: 101 → 49
#   AGV 14, Route 48: 101 → 50
#   AGV 14, Route 48: 101 → 51
#   AGV 14, Route 48: 101 → 52
#   AGV 14, Route 48: 101 → 53
#   AGV 14, Route 48: 101 → 54
#   AGV 14, Route 48: 101 → 55
#   AGV 14, Route 48: 101 → 56
#   AGV 14, Route 48: 101 → 57
#   AGV 14, Route 48: 101 → 58
#   AGV 14, Route 48: 101 → 59
#   AGV 14, Route 48: 101 → 60
#   AGV 14, Route 48: 101 → 61
#   AGV 14, Route 48: 101 → 62
#   AGV 14, Route 48: 101 → 63
#   AGV 14, Route 48: 101 → 64
#   AGV 14, Route 48: 101 → 65
#   AGV 14, Route 48: 101 → 66
#   AGV 14, Route 48: 101 → 67
#   AGV 14, Route 48: 101 → 68
#   AGV 14, Route 48: 101 → 69
#   AGV 14, Route 48: 101 → 70
#   AGV 14, Route 48: 101 → 71
#   AGV 14, Route 48: 101 → 72
#   AGV 14, Route 48: 101 → 73
#   AGV 14, Route 48: 101 → 74
#   AGV 14, Route 48: 101 → 75
#   AGV 14, Route 48: 101 → 76
#   AGV 14, Route 48: 101 → 77
#   AGV 14, Route 48: 101 → 78
#   AGV 14, Route 48: 101 → 79
#   AGV 14, Route 48: 101 → 80
#   AGV 14, Route 48: 101 → 81
#   AGV 14, Route 48: 101 → 82
#   AGV 14, Route 48: 101 → 83
#   AGV 14, Route 48: 101 → 84
#   AGV 14, Route 48: 101 → 85
#   AGV 14, Route 48: 101 → 86
#   AGV 14, Route 48: 101 → 87
#   AGV 14, Route 48: 101 → 88
#   AGV 14, Route 48: 101 → 89
#   AGV 14, Route 48: 101 → 90
#   AGV 14, Route 48: 101 → 91
#   AGV 14, Route 48: 101 → 92
#   AGV 14, Route 48: 101 → 93
#   AGV 14, Route 48: 101 → 94
#   AGV 14, Route 48: 101 → 95
#   AGV 14, Route 48: 101 → 96
#   AGV 14, Route 48: 101 → 97
#   AGV 14, Route 48: 101 → 98
#   AGV 14, Route 48: 101 → 99
#   AGV 14, Route 48: 101 → 100
#   AGV 14, Route 49: 0 → 101
#   AGV 14, Route 49: 101 → 0
#   AGV 14, Route 49: 101 → 1
#   AGV 14, Route 49: 101 → 2
#   AGV 14, Route 49: 101 → 3
#   AGV 14, Route 49: 101 → 4
#   AGV 14, Route 49: 101 → 5
#   AGV 14, Route 49: 101 → 6
#   AGV 14, Route 49: 101 → 7
#   AGV 14, Route 49: 101 → 8
#   AGV 14, Route 49: 101 → 9
#   AGV 14, Route 49: 101 → 10
#   AGV 14, Route 49: 101 → 11
#   AGV 14, Route 49: 101 → 12
#   AGV 14, Route 49: 101 → 13
#   AGV 14, Route 49: 101 → 14
#   AGV 14, Route 49: 101 → 15
#   AGV 14, Route 49: 101 → 16
#   AGV 14, Route 49: 101 → 17
#   AGV 14, Route 49: 101 → 18
#   AGV 14, Route 49: 101 → 19
#   AGV 14, Route 49: 101 → 20
#   AGV 14, Route 49: 101 → 21
#   AGV 14, Route 49: 101 → 22
#   AGV 14, Route 49: 101 → 23
#   AGV 14, Route 49: 101 → 24
#   AGV 14, Route 49: 101 → 25
#   AGV 14, Route 49: 101 → 26
#   AGV 14, Route 49: 101 → 27
#   AGV 14, Route 49: 101 → 28
#   AGV 14, Route 49: 101 → 29
#   AGV 14, Route 49: 101 → 30
#   AGV 14, Route 49: 101 → 31
#   AGV 14, Route 49: 101 → 32
#   AGV 14, Route 49: 101 → 33
#   AGV 14, Route 49: 101 → 34
#   AGV 14, Route 49: 101 → 35
#   AGV 14, Route 49: 101 → 36
#   AGV 14, Route 49: 101 → 37
#   AGV 14, Route 49: 101 → 38
#   AGV 14, Route 49: 101 → 39
#   AGV 14, Route 49: 101 → 40
#   AGV 14, Route 49: 101 → 41
#   AGV 14, Route 49: 101 → 42
#   AGV 14, Route 49: 101 → 43
#   AGV 14, Route 49: 101 → 44
#   AGV 14, Route 49: 101 → 45
#   AGV 14, Route 49: 101 → 46
#   AGV 14, Route 49: 101 → 47
#   AGV 14, Route 49: 101 → 48
#   AGV 14, Route 49: 101 → 49
#   AGV 14, Route 49: 101 → 50
#   AGV 14, Route 49: 101 → 51
#   AGV 14, Route 49: 101 → 52
#   AGV 14, Route 49: 101 → 53
#   AGV 14, Route 49: 101 → 54
#   AGV 14, Route 49: 101 → 55
#   AGV 14, Route 49: 101 → 56
#   AGV 14, Route 49: 101 → 57
#   AGV 14, Route 49: 101 → 58
#   AGV 14, Route 49: 101 → 59
#   AGV 14, Route 49: 101 → 60
#   AGV 14, Route 49: 101 → 61
#   AGV 14, Route 49: 101 → 62
#   AGV 14, Route 49: 101 → 63
#   AGV 14, Route 49: 101 → 64
#   AGV 14, Route 49: 101 → 65
#   AGV 14, Route 49: 101 → 66
#   AGV 14, Route 49: 101 → 67
#   AGV 14, Route 49: 101 → 68
#   AGV 14, Route 49: 101 → 69
#   AGV 14, Route 49: 101 → 70
#   AGV 14, Route 49: 101 → 71
#   AGV 14, Route 49: 101 → 72
#   AGV 14, Route 49: 101 → 73
#   AGV 14, Route 49: 101 → 74
#   AGV 14, Route 49: 101 → 75
#   AGV 14, Route 49: 101 → 76
#   AGV 14, Route 49: 101 → 77
#   AGV 14, Route 49: 101 → 78
#   AGV 14, Route 49: 101 → 79
#   AGV 14, Route 49: 101 → 80
#   AGV 14, Route 49: 101 → 81
#   AGV 14, Route 49: 101 → 82
#   AGV 14, Route 49: 101 → 83
#   AGV 14, Route 49: 101 → 84
#   AGV 14, Route 49: 101 → 85
#   AGV 14, Route 49: 101 → 86
#   AGV 14, Route 49: 101 → 87
#   AGV 14, Route 49: 101 → 88
#   AGV 14, Route 49: 101 → 89
#   AGV 14, Route 49: 101 → 90
#   AGV 14, Route 49: 101 → 91
#   AGV 14, Route 49: 101 → 92
#   AGV 14, Route 49: 101 → 93
#   AGV 14, Route 49: 101 → 94
#   AGV 14, Route 49: 101 → 95
#   AGV 14, Route 49: 101 → 96
#   AGV 14, Route 49: 101 → 97
#   AGV 14, Route 49: 101 → 98
#   AGV 14, Route 49: 101 → 99
#   AGV 14, Route 49: 101 → 100
#   AGV 14, Route 50: 0 → 101
#   AGV 14, Route 50: 101 → 0
#   AGV 14, Route 50: 101 → 1
#   AGV 14, Route 50: 101 → 2
#   AGV 14, Route 50: 101 → 3
#   AGV 14, Route 50: 101 → 4
#   AGV 14, Route 50: 101 → 5
#   AGV 14, Route 50: 101 → 6
#   AGV 14, Route 50: 101 → 7
#   AGV 14, Route 50: 101 → 8
#   AGV 14, Route 50: 101 → 9
#   AGV 14, Route 50: 101 → 10
#   AGV 14, Route 50: 101 → 11
#   AGV 14, Route 50: 101 → 12
#   AGV 14, Route 50: 101 → 13
#   AGV 14, Route 50: 101 → 14
#   AGV 14, Route 50: 101 → 15
#   AGV 14, Route 50: 101 → 16
#   AGV 14, Route 50: 101 → 17
#   AGV 14, Route 50: 101 → 18
#   AGV 14, Route 50: 101 → 19
#   AGV 14, Route 50: 101 → 20
#   AGV 14, Route 50: 101 → 21
#   AGV 14, Route 50: 101 → 22
#   AGV 14, Route 50: 101 → 23
#   AGV 14, Route 50: 101 → 24
#   AGV 14, Route 50: 101 → 25
#   AGV 14, Route 50: 101 → 26
#   AGV 14, Route 50: 101 → 27
#   AGV 14, Route 50: 101 → 28
#   AGV 14, Route 50: 101 → 29
#   AGV 14, Route 50: 101 → 30
#   AGV 14, Route 50: 101 → 31
#   AGV 14, Route 50: 101 → 32
#   AGV 14, Route 50: 101 → 33
#   AGV 14, Route 50: 101 → 34
#   AGV 14, Route 50: 101 → 35
#   AGV 14, Route 50: 101 → 36
#   AGV 14, Route 50: 101 → 37
#   AGV 14, Route 50: 101 → 38
#   AGV 14, Route 50: 101 → 39
#   AGV 14, Route 50: 101 → 40
#   AGV 14, Route 50: 101 → 41
#   AGV 14, Route 50: 101 → 42
#   AGV 14, Route 50: 101 → 43
#   AGV 14, Route 50: 101 → 44
#   AGV 14, Route 50: 101 → 45
#   AGV 14, Route 50: 101 → 46
#   AGV 14, Route 50: 101 → 47
#   AGV 14, Route 50: 101 → 48
#   AGV 14, Route 50: 101 → 49
#   AGV 14, Route 50: 101 → 50
#   AGV 14, Route 50: 101 → 51
#   AGV 14, Route 50: 101 → 52
#   AGV 14, Route 50: 101 → 53
#   AGV 14, Route 50: 101 → 54
#   AGV 14, Route 50: 101 → 55
#   AGV 14, Route 50: 101 → 56
#   AGV 14, Route 50: 101 → 57
#   AGV 14, Route 50: 101 → 58
#   AGV 14, Route 50: 101 → 59
#   AGV 14, Route 50: 101 → 60
#   AGV 14, Route 50: 101 → 61
#   AGV 14, Route 50: 101 → 62
#   AGV 14, Route 50: 101 → 63
#   AGV 14, Route 50: 101 → 64
#   AGV 14, Route 50: 101 → 65
#   AGV 14, Route 50: 101 → 66
#   AGV 14, Route 50: 101 → 67
#   AGV 14, Route 50: 101 → 68
#   AGV 14, Route 50: 101 → 69
#   AGV 14, Route 50: 101 → 70
#   AGV 14, Route 50: 101 → 71
#   AGV 14, Route 50: 101 → 72
#   AGV 14, Route 50: 101 → 73
#   AGV 14, Route 50: 101 → 74
#   AGV 14, Route 50: 101 → 75
#   AGV 14, Route 50: 101 → 76
#   AGV 14, Route 50: 101 → 77
#   AGV 14, Route 50: 101 → 78
#   AGV 14, Route 50: 101 → 79
#   AGV 14, Route 50: 101 → 80
#   AGV 14, Route 50: 101 → 81
#   AGV 14, Route 50: 101 → 82
#   AGV 14, Route 50: 101 → 83
#   AGV 14, Route 50: 101 → 84
#   AGV 14, Route 50: 101 → 85
#   AGV 14, Route 50: 101 → 86
#   AGV 14, Route 50: 101 → 87
#   AGV 14, Route 50: 101 → 88
#   AGV 14, Route 50: 101 → 89
#   AGV 14, Route 50: 101 → 90
#   AGV 14, Route 50: 101 → 91
#   AGV 14, Route 50: 101 → 92
#   AGV 14, Route 50: 101 → 93
#   AGV 14, Route 50: 101 → 94
#   AGV 14, Route 50: 101 → 95
#   AGV 14, Route 50: 101 → 96
#   AGV 14, Route 50: 101 → 97
#   AGV 14, Route 50: 101 → 98
#   AGV 14, Route 50: 101 → 99
#   AGV 14, Route 50: 101 → 100
#   AGV 14, Route 51: 0 → 101
#   AGV 14, Route 51: 101 → 0
#   AGV 14, Route 51: 101 → 1
#   AGV 14, Route 51: 101 → 2
#   AGV 14, Route 51: 101 → 3
#   AGV 14, Route 51: 101 → 4
#   AGV 14, Route 51: 101 → 5
#   AGV 14, Route 51: 101 → 6
#   AGV 14, Route 51: 101 → 7
#   AGV 14, Route 51: 101 → 8
#   AGV 14, Route 51: 101 → 9
#   AGV 14, Route 51: 101 → 10
#   AGV 14, Route 51: 101 → 11
#   AGV 14, Route 51: 101 → 12
#   AGV 14, Route 51: 101 → 13
#   AGV 14, Route 51: 101 → 14
#   AGV 14, Route 51: 101 → 15
#   AGV 14, Route 51: 101 → 16
#   AGV 14, Route 51: 101 → 17
#   AGV 14, Route 51: 101 → 18
#   AGV 14, Route 51: 101 → 19
#   AGV 14, Route 51: 101 → 20
#   AGV 14, Route 51: 101 → 21
#   AGV 14, Route 51: 101 → 22
#   AGV 14, Route 51: 101 → 23
#   AGV 14, Route 51: 101 → 24
#   AGV 14, Route 51: 101 → 25
#   AGV 14, Route 51: 101 → 26
#   AGV 14, Route 51: 101 → 27
#   AGV 14, Route 51: 101 → 28
#   AGV 14, Route 51: 101 → 29
#   AGV 14, Route 51: 101 → 30
#   AGV 14, Route 51: 101 → 31
#   AGV 14, Route 51: 101 → 32
#   AGV 14, Route 51: 101 → 33
#   AGV 14, Route 51: 101 → 34
#   AGV 14, Route 51: 101 → 35
#   AGV 14, Route 51: 101 → 36
#   AGV 14, Route 51: 101 → 37
#   AGV 14, Route 51: 101 → 38
#   AGV 14, Route 51: 101 → 39
#   AGV 14, Route 51: 101 → 40
#   AGV 14, Route 51: 101 → 41
#   AGV 14, Route 51: 101 → 42
#   AGV 14, Route 51: 101 → 43
#   AGV 14, Route 51: 101 → 44
#   AGV 14, Route 51: 101 → 45
#   AGV 14, Route 51: 101 → 46
#   AGV 14, Route 51: 101 → 47
#   AGV 14, Route 51: 101 → 48
#   AGV 14, Route 51: 101 → 49
#   AGV 14, Route 51: 101 → 50
#   AGV 14, Route 51: 101 → 51
#   AGV 14, Route 51: 101 → 52
#   AGV 14, Route 51: 101 → 53
#   AGV 14, Route 51: 101 → 54
#   AGV 14, Route 51: 101 → 55
#   AGV 14, Route 51: 101 → 56
#   AGV 14, Route 51: 101 → 57
#   AGV 14, Route 51: 101 → 58
#   AGV 14, Route 51: 101 → 59
#   AGV 14, Route 51: 101 → 60
#   AGV 14, Route 51: 101 → 61
#   AGV 14, Route 51: 101 → 62
#   AGV 14, Route 51: 101 → 63
#   AGV 14, Route 51: 101 → 64
#   AGV 14, Route 51: 101 → 65
#   AGV 14, Route 51: 101 → 66
#   AGV 14, Route 51: 101 → 67
#   AGV 14, Route 51: 101 → 68
#   AGV 14, Route 51: 101 → 69
#   AGV 14, Route 51: 101 → 70
#   AGV 14, Route 51: 101 → 71
#   AGV 14, Route 51: 101 → 72
#   AGV 14, Route 51: 101 → 73
#   AGV 14, Route 51: 101 → 74
#   AGV 14, Route 51: 101 → 75
#   AGV 14, Route 51: 101 → 76
#   AGV 14, Route 51: 101 → 77
#   AGV 14, Route 51: 101 → 78
#   AGV 14, Route 51: 101 → 79
#   AGV 14, Route 51: 101 → 80
#   AGV 14, Route 51: 101 → 81
#   AGV 14, Route 51: 101 → 82
#   AGV 14, Route 51: 101 → 83
#   AGV 14, Route 51: 101 → 84
#   AGV 14, Route 51: 101 → 85
#   AGV 14, Route 51: 101 → 86
#   AGV 14, Route 51: 101 → 87
#   AGV 14, Route 51: 101 → 88
#   AGV 14, Route 51: 101 → 89
#   AGV 14, Route 51: 101 → 90
#   AGV 14, Route 51: 101 → 91
#   AGV 14, Route 51: 101 → 92
#   AGV 14, Route 51: 101 → 93
#   AGV 14, Route 51: 101 → 94
#   AGV 14, Route 51: 101 → 95
#   AGV 14, Route 51: 101 → 96
#   AGV 14, Route 51: 101 → 97
#   AGV 14, Route 51: 101 → 98
#   AGV 14, Route 51: 101 → 99
#   AGV 14, Route 51: 101 → 100
#   AGV 14, Route 52: 0 → 101
#   AGV 14, Route 52: 101 → 0
#   AGV 14, Route 52: 101 → 1
#   AGV 14, Route 52: 101 → 2
#   AGV 14, Route 52: 101 → 3
#   AGV 14, Route 52: 101 → 4
#   AGV 14, Route 52: 101 → 5
#   AGV 14, Route 52: 101 → 6
#   AGV 14, Route 52: 101 → 7
#   AGV 14, Route 52: 101 → 8
#   AGV 14, Route 52: 101 → 9
#   AGV 14, Route 52: 101 → 10
#   AGV 14, Route 52: 101 → 11
#   AGV 14, Route 52: 101 → 12
#   AGV 14, Route 52: 101 → 13
#   AGV 14, Route 52: 101 → 14
#   AGV 14, Route 52: 101 → 15
#   AGV 14, Route 52: 101 → 16
#   AGV 14, Route 52: 101 → 17
#   AGV 14, Route 52: 101 → 18
#   AGV 14, Route 52: 101 → 19
#   AGV 14, Route 52: 101 → 20
#   AGV 14, Route 52: 101 → 21
#   AGV 14, Route 52: 101 → 22
#   AGV 14, Route 52: 101 → 23
#   AGV 14, Route 52: 101 → 24
#   AGV 14, Route 52: 101 → 25
#   AGV 14, Route 52: 101 → 26
#   AGV 14, Route 52: 101 → 27
#   AGV 14, Route 52: 101 → 28
#   AGV 14, Route 52: 101 → 29
#   AGV 14, Route 52: 101 → 30
#   AGV 14, Route 52: 101 → 31
#   AGV 14, Route 52: 101 → 32
#   AGV 14, Route 52: 101 → 33
#   AGV 14, Route 52: 101 → 34
#   AGV 14, Route 52: 101 → 35
#   AGV 14, Route 52: 101 → 36
#   AGV 14, Route 52: 101 → 37
#   AGV 14, Route 52: 101 → 38
#   AGV 14, Route 52: 101 → 39
#   AGV 14, Route 52: 101 → 40
#   AGV 14, Route 52: 101 → 41
#   AGV 14, Route 52: 101 → 42
#   AGV 14, Route 52: 101 → 43
#   AGV 14, Route 52: 101 → 44
#   AGV 14, Route 52: 101 → 45
#   AGV 14, Route 52: 101 → 46
#   AGV 14, Route 52: 101 → 47
#   AGV 14, Route 52: 101 → 48
#   AGV 14, Route 52: 101 → 49
#   AGV 14, Route 52: 101 → 50
#   AGV 14, Route 52: 101 → 51
#   AGV 14, Route 52: 101 → 52
#   AGV 14, Route 52: 101 → 53
#   AGV 14, Route 52: 101 → 54
#   AGV 14, Route 52: 101 → 55
#   AGV 14, Route 52: 101 → 56
#   AGV 14, Route 52: 101 → 57
#   AGV 14, Route 52: 101 → 58
#   AGV 14, Route 52: 101 → 59
#   AGV 14, Route 52: 101 → 60
#   AGV 14, Route 52: 101 → 61
#   AGV 14, Route 52: 101 → 62
#   AGV 14, Route 52: 101 → 63
#   AGV 14, Route 52: 101 → 64
#   AGV 14, Route 52: 101 → 65
#   AGV 14, Route 52: 101 → 66
#   AGV 14, Route 52: 101 → 67
#   AGV 14, Route 52: 101 → 68
#   AGV 14, Route 52: 101 → 69
#   AGV 14, Route 52: 101 → 70
#   AGV 14, Route 52: 101 → 71
#   AGV 14, Route 52: 101 → 72
#   AGV 14, Route 52: 101 → 73
#   AGV 14, Route 52: 101 → 74
#   AGV 14, Route 52: 101 → 75
#   AGV 14, Route 52: 101 → 76
#   AGV 14, Route 52: 101 → 77
#   AGV 14, Route 52: 101 → 78
#   AGV 14, Route 52: 101 → 79
#   AGV 14, Route 52: 101 → 80
#   AGV 14, Route 52: 101 → 81
#   AGV 14, Route 52: 101 → 82
#   AGV 14, Route 52: 101 → 83
#   AGV 14, Route 52: 101 → 84
#   AGV 14, Route 52: 101 → 85
#   AGV 14, Route 52: 101 → 86
#   AGV 14, Route 52: 101 → 87
#   AGV 14, Route 52: 101 → 88
#   AGV 14, Route 52: 101 → 89
#   AGV 14, Route 52: 101 → 90
#   AGV 14, Route 52: 101 → 91
#   AGV 14, Route 52: 101 → 92
#   AGV 14, Route 52: 101 → 93
#   AGV 14, Route 52: 101 → 94
#   AGV 14, Route 52: 101 → 95
#   AGV 14, Route 52: 101 → 96
#   AGV 14, Route 52: 101 → 97
#   AGV 14, Route 52: 101 → 98
#   AGV 14, Route 52: 101 → 99
#   AGV 14, Route 52: 101 → 100

# %%
# === AGV 별 전체 경로 문자열로 저장 ===
from collections import defaultdict

# 경로 재구성
agv_routes = defaultdict(lambda: defaultdict(list))  # agv_routes[k][r] = [(i, j)]

if model.status in [GRB.OPTIMAL, GRB.TIME_LIMIT, GRB.INTERRUPTED]:
    for k in K:
        for r in range(T_max[k]):
            arcs = []
            for i in N_s_t:
                for j in N_s_t:
                    if i != j and (k, i, j, r) in x and x[k, i, j, r].X > 0.5:
                        arcs.append((i, j))
            if arcs:
                agv_routes[k][r] = arcs

    # 각 AGV별 경로 정렬 및 문자열화
    final_paths = []
    for k in agv_routes:
        full_path = []
        used = set()
        for r in sorted(agv_routes[k].keys()):
            arcs = agv_routes[k][r]
            # 경로를 순서대로 정렬
            route = []
            current = 0  # depot에서 시작
            while True:
                next_nodes = [j for (i, j) in arcs if i == current and (i, j) not in used]
                if not next_nodes:
                    break
                next_node = next_nodes[0]
                route.append(next_node)
                used.add((current, next_node))
                current = next_node
            # 노드 이름 포맷 변경: 0 → DEPOT, others → T00XX
            formatted = ["DEPOT"]
            for node in route:
                if node == 0 or node == len(N_s_t) - 1:
                    formatted.append("DEPOT")
                else:
                    formatted.append(f"T{node:04d}")
            full_path.extend(formatted)

        # 중복 DEPOT 제거
        clean_path = [full_path[0]]
        for node in full_path[1:]:
            if node != "DEPOT" or clean_path[-1] != "DEPOT":
                clean_path.append(node)

        final_paths.append({
            "agv_id": f"A{k+1:03d}",
            "route": ",".join(clean_path)
        })

    # CSV 저장
    path_df = pd.DataFrame(final_paths)
    output_path = "agv_routes_formatted.csv"
    path_df.to_csv(output_path, index=False)
    print(f"📁 AGV 경로가 저장되었습니다: {output_path}")
else:
    print("⚠️ 최적 해를 찾지 못했기 때문에 경로를 저장하지 않습니다.")
# Out:
# 📁 AGV 경로가 저장되었습니다: agv_routes_formatted.csv
