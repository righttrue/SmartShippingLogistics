# %%
from gurobipy import Model, GRB, quicksum
import pandas as pd

# Load data
tasks = pd.read_csv("./open_v2/task.csv")
# tasks= tasks[:20]
agvs = pd.read_csv("./open_v2/agv.csv")
# agvs = agvs[:5]
# === Parameters & sets ===
depot = (0, 0)
points = [(idx + 1, row['x'], row['y']) for idx, row in tasks.iterrows()]
points = [(0, *depot)] + points + [(len(points) + 1, *depot)]

distance = {
    i_idx: {
        j_idx: abs(i_x - j_x) + abs(i_y - j_y)
        for j_idx, j_x, j_y in points
    }
    for i_idx, i_x, i_y in points
}

NODE = len(tasks) + 2
K = list(range(len(agvs)))
N = list(range(1, len(points) - 1))
N_s = list(range(0, len(points) - 1))
N_t = list(range(0, len(points)))
N_s_t = list(range(0, len(points)))
T_max = [4 for _ in range(len(agvs))]

v = agvs['speed_cells_per_sec'].tolist()
Q = agvs['capacity'].tolist()
D = agvs['max_distance'].tolist()
s = [0] + tasks['service_time'].tolist() + [0]
u = [0] + tasks['demand'].tolist() + [0]
deadlines = [0] + tasks['deadline'].tolist() + [0]
demand_max = max(tasks['demand'])
dead_line_max = max(tasks['deadline'])
M = 1000
alpha, beta = 1, 2

# %%
# === Build Gurobi model ===
model = Model("Corrected_AGV_Routing")
x, y, o, t = {}, {}, {}, {}

for k in K:
    for r in range(T_max[k]):
        for i in N_s_t:
            for j in N_s_t:
                if i != j:
                    x[k, i, j, r] = model.addVar(vtype=GRB.BINARY, name=f"x_{k}_{i}_{j}_{r}")
        for i in N_s_t:
            y[k, i, r] = model.addVar(vtype=GRB.BINARY, name=f"y_{k}_{i}_{r}")
            o[k, i, r] = model.addVar(vtype=GRB.INTEGER, name=f"o_{k}_{i}_{r}")
            t[k, i, r] = model.addVar(vtype=GRB.CONTINUOUS, name=f"t_{k}_{i}_{r}")

late = {}
for i in N:
    late[i] = model.addVar(vtype=GRB.CONTINUOUS, name=f"late_{i}")

model.update()

# === Constraints ===

# 1. Start depot only once
for k in K:
    model.addConstr(quicksum(x[k, 0, j, 0] for j in N ) == 1)
    for r in range(0, T_max[k]):
        model.addConstr(quicksum(x[k, 0, j, r] for j in N ) <= quicksum(x[k, j,N_t[-1], r] for j in N ))

for k in K:
    for r in range(T_max[k]):
        for j in N:
            model.addConstr(quicksum(x[k, i, j, r] for i in N_s if i != j ) == quicksum(x[k, j, i, r] for i in N_t if i != j ))


for k in K:
    for r in range(T_max[k]):
        for j in N_t:
            model.addConstr(quicksum(x[k, i, j, r] for i in N_s if i != j ) == y[k, j, r])

# 3. Time sequencing (big-M)
for k in K:
    for r in range(T_max[k]):
        for i in N_s:
            for j in N_t:
                if i != j :
                    model.addConstr(
                        t[k, j, r] >= t[k, i, r] + distance[i][j] / v[k] + s[i] - M * (1 - x[k, i, j, r])
                    )

# 4. Demand served only if visited
for k in K:
    for r in range(T_max[k]):
        for i in N:
            model.addConstr(o[k, i, r] == u[i] * y[k, i, r])

# 5. Capacity constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(quicksum(o[k, i, r] for i in N) <= Q[k])
        

# 6. Distance constraint
for k in K:
    for r in range(T_max[k]):
        model.addConstr(quicksum(distance[i][j] * x[k, i, j, r] for i in N_s_t for j in N_s_t if i != j ) <= D[k])

# 7. Each task must be served at least once
for j in N:
    model.addConstr(quicksum(y[k, j, r] for k in K for r in range(T_max[k])) == 1)

# 8. Start times are 0
for k in K:
    model.addConstr(t[k, 0, 0] == 0)

for k in K:
    for r in range(T_max[k]):
        for i in N:
            model.addConstr(late[i] >= t[k, i, r] - deadlines[i])
            model.addConstr(late[i] >= 0)

for k in K:
    for r in range(1, T_max[k]):
            model.addConstr(t[k, N_t[-1], r-1] <= t[k, 0, r] )
for k in K:
    for r in range(0, T_max[k]):
            model.addConstr(t[k, 0, r] <= t[k,  N_t[-1], r] )

tardiness = quicksum(late[i] for i in N)

travel_cost = quicksum(
    (distance[i][j] / v[k]) * x[k, i, j, r]
    for k in K for r in range(T_max[k])
    for i in N_s_t for j in N_s_t
    if i != j
)
model.addConstr(alpha * travel_cost + beta * tardiness >= 5000)
# === Objective ===
model.setObjective(alpha * travel_cost + beta * tardiness, GRB.MINIMIZE)
model.setParam(GRB.Param.TimeLimit, 3600*3)
# model.Params.MIPFocus     = 1       # lean to finding high-quality incumbents quickly
# model.Params.Presolve     = 2  
# === Solve ===

USER_UB = 9000
model.setParam(GRB.Param.Cutoff, USER_UB)

model.optimize()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2636023
# Academic license - for non-commercial use only - expires 2026-03-13
# Set parameter TimeLimit to value 10800
# Set parameter Cutoff to value 9000
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# Cutoff  9000
# TimeLimit  10800
#
# Optimize a model with 642596 rows, 636580 columns and 4952185 nonzeros
# Model fingerprint: 0x2dd735a5
# Variable types: 6220 continuous, 630360 integer (624240 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [5e-01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Presolve removed 21225 rows and 16275 columns (presolve time = 5s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 10s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 15s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 20s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 25s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 30s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 35s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 40s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 45s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 50s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 55s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 60s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 65s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 70s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 75s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 80s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 85s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 90s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 95s)...
# Presolve removed 21225 rows and 16275 columns (presolve time = 100s)...
# Presolve removed 21225 rows and 154099 columns (presolve time = 126s)...
# Presolve removed 44673 rows and 147994 columns
# Presolve time: 128.01s
# Presolved: 597923 rows, 488586 columns, 3561190 nonzeros
# Variable types: 6145 continuous, 482441 integer (480641 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 19s
# Elapsed ordering time = 20s
# Ordering time: 72.79s
# Elapsed ordering time = 76s
# Elapsed ordering time = 98s
# Elapsed ordering time = 100s
# Elapsed ordering time = 105s
# Elapsed ordering time = 110s
# Elapsed ordering time = 115s
# Elapsed ordering time = 120s
# Elapsed ordering time = 126s
# Elapsed ordering time = 150s
# Elapsed ordering time = 152s
# Elapsed ordering time = 155s
# Elapsed ordering time = 160s
# Elapsed ordering time = 165s
# Elapsed ordering time = 170s
# Elapsed ordering time = 175s
# Elapsed ordering time = 196s
# Elapsed ordering time = 200s
# Elapsed ordering time = 205s
# Elapsed ordering time = 210s
# Elapsed ordering time = 215s
# Elapsed ordering time = 220s
# Elapsed ordering time = 225s
# Ordering time: 231.31s
# Elapsed ordering time = 234s
# Elapsed ordering time = 235s
# Elapsed ordering time = 253s
# Elapsed ordering time = 262s
# Elapsed ordering time = 265s
# Elapsed ordering time = 270s
# Elapsed ordering time = 277s
# Elapsed ordering time = 280s
# Elapsed ordering time = 285s
# Elapsed ordering time = 290s
# Elapsed ordering time = 317s
# Elapsed ordering time = 322s
# Elapsed ordering time = 325s
# Elapsed ordering time = 331s
# Elapsed ordering time = 336s
# Elapsed ordering time = 341s
# Elapsed ordering time = 345s
# Elapsed ordering time = 350s
# Elapsed ordering time = 377s
# Elapsed ordering time = 384s
# Elapsed ordering time = 385s
# Elapsed ordering time = 390s
# Elapsed ordering time = 395s
# Elapsed ordering time = 400s
# Elapsed ordering time = 405s
# Elapsed ordering time = 411s
# Ordering time: 419.96s
#
# Barrier statistics:
#  Dense cols : 45
#  AA' NZ     : 9.889e+07
#  Factor NZ  : 1.724e+09 (roughly 14.0 GB of memory)
#  Factor Ops : 7.175e+12 (roughly 10 seconds per iteration)
#  Threads    : 17
#
# Barrier performed 0 iterations in 571.57 seconds (208.95 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 335.39s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   151361    5.0000000e+03   0.000000e+00   0.000000e+00    572s
#
# Root relaxation: objective 5.000000e+03, 151361 iterations, 442.17 seconds (83.84 work units)
# Total elapsed time = 759.67s (DegenMoves)
# Total elapsed time = 763.67s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5000.00000    0  242          - 5000.00000      -     -  773s
#      0     0 5000.00000    0  959          - 5000.00000      -     -  891s
#      0     0 5000.00000    0 1047          - 5000.00000      -     -  921s
#      0     0 5000.00000    0 1158          - 5000.00000      -     - 1256s
#      0     0 5000.00000    0 1198          - 5000.00000      -     - 1285s

# %%
# === AGV 별 전체 경로 문자열로 저장 ===
from collections import defaultdict

# 경로 재구성
agv_routes = defaultdict(lambda: defaultdict(list))  # agv_routes[k][r] = [(i, j)]

if model.status in [GRB.OPTIMAL, GRB.TIME_LIMIT, GRB.INTERRUPTED]:
    for k in K:
        for r in range(T_max[k]):
            arcs = []
            for i in N_s_t:
                for j in N_s_t:
                    if i != j and (k, i, j, r) in x and x[k, i, j, r].X > 0.5:
                        arcs.append((i, j))
            if arcs:
                agv_routes[k][r] = arcs

    # 각 AGV별 경로 정렬 및 문자열화
    final_paths = []
    for k in agv_routes:
        full_path = []
        used = set()
        for r in sorted(agv_routes[k].keys()):
            arcs = agv_routes[k][r]
            # 경로를 순서대로 정렬
            route = []
            current = 0  # depot에서 시작
            while True:
                next_nodes = [j for (i, j) in arcs if i == current and (i, j) not in used]
                if not next_nodes:
                    break
                next_node = next_nodes[0]
                route.append(next_node)
                used.add((current, next_node))
                current = next_node
            # 노드 이름 포맷 변경: 0 → DEPOT, others → T 00XX
            formatted = ["DEPOT"]
            for node in route:
                if node == 0 or node == len(N_s_t) - 1:
                    formatted.append("DEPOT")
                else:
                    formatted.append(f"T{node:04d}")
            full_path.extend(formatted)

        # 중복 DEPOT 제거
        clean_path = [full_path[0]]
        for node in full_path[1:]:
            if node != "DEPOT" or clean_path[-1] != "DEPOT":
                clean_path.append(node)

        final_paths.append({
            "agv_id": f"A{k+1:03d}",
            "route": ",".join(clean_path)
        })

    # CSV 저장
    path_df = pd.DataFrame(final_paths)
    output_path = "0930_agv_routes_formatted_2.csv"
    path_df.to_csv(output_path, index=False)
    print(f"📁 AGV 경로가 저장되었습니다: {output_path}")
else:
    print("⚠️ 최적 해를 찾지 못했기 때문에 경로를 저장하지 않습니다.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      11 for i in N_s_t:
#      12     for j in N_s_t:
# ---> 13         if i != j and (k, i, j, r) in x and x[k, i, j, r].X > 0.5:
#      14             arcs.append((i, j))
#      15 if arcs:
#
# File src\\gurobipy\\var.pxi:128, in gurobipy._core.Var.__getattr__()
#
# File src\\gurobipy\\var.pxi:156, in gurobipy._core.Var.getAttr()
#
# File src\\gurobipy\\_attrutil.pyx:117, in gurobipy._attrutil._getattr()
#
# AttributeError: Unable to retrieve attribute 'X'

# %%
import matplotlib.pyplot as plt

# 좌표 dict로 변환 (노드 번호 → (x, y))
coord = {i: (x, y) for i, x, y in points}

plt.figure(figsize=(12, 8))

# 모든 노드를 scatter
for i, (xi, yi) in coord.items():
    plt.scatter(xi, yi, c='black', zorder=3)
    plt.text(xi + 0.5, yi + 0.5, f"{i}", fontsize=9)

colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan', 'magenta', 'brown']

for k in K:
    for r in range(T_max[k]):
        route_color = colors[(k * 3 + r) % len(colors)]
        for i in coord:
            for j in coord:
                if i != j and (k, i, j, r) in x:
                    if x[k, i, j, r].X > 0.5:
                        xi, yi = coord[i]
                        xj, yj = coord[j]
                        plt.arrow(xi, yi, xj - xi, yj - yi, 
                                    head_width=1, length_includes_head=True, 
                                    color=route_color, alpha=0.7, zorder=2)
        plt.plot([], [], color=route_color, label=f"AGV {k}, Route {r}")

plt.title("AGV Routing Plan")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
# plt.legend()
plt.axis("equal")
plt.show()

# %%
t
# Out:
# {(0, 0, 0): <gurobi.Var t_0_0_0 (value 0.0)>,
#  (0, 1, 0): <gurobi.Var t_0_1_0 (value 17.5)>,
#  (0, 2, 0): <gurobi.Var t_0_2_0 (value 7.0)>,
#  (0, 3, 0): <gurobi.Var t_0_3_0 (value 2.0)>,
#  (0, 4, 0): <gurobi.Var t_0_4_0 (value 8.5)>,
#  (0, 5, 0): <gurobi.Var t_0_5_0 (value 6.0)>,
#  (0, 6, 0): <gurobi.Var t_0_6_0 (value 24.5)>,
#  (0, 7, 0): <gurobi.Var t_0_7_0 (value 19.5)>,
#  (0, 8, 0): <gurobi.Var t_0_8_0 (value 26.5)>,
#  (0, 9, 0): <gurobi.Var t_0_9_0 (value 13.0)>,
#  (0, 10, 0): <gurobi.Var t_0_10_0 (value 6.5)>,
#  (0, 11, 0): <gurobi.Var t_0_11_0 (value 22.5)>,
#  (0, 12, 0): <gurobi.Var t_0_12_0 (value 12.5)>,
#  (0, 13, 0): <gurobi.Var t_0_13_0 (value 127.0)>,
#  (0, 14, 0): <gurobi.Var t_0_14_0 (value 13.0)>,
#  (0, 15, 0): <gurobi.Var t_0_15_0 (value 0.0)>,
#  (0, 16, 0): <gurobi.Var t_0_16_0 (value 1.0)>,
#  (0, 17, 0): <gurobi.Var t_0_17_0 (value 9.5)>,
#  (0, 18, 0): <gurobi.Var t_0_18_0 (value 14.5)>,
#  (0, 19, 0): <gurobi.Var t_0_19_0 (value 0.0)>,
#  (0, 20, 0): <gurobi.Var t_0_20_0 (value 194.0)>,
#  (0, 21, 0): <gurobi.Var t_0_21_0 (value 230.0)>,
#  (0, 0, 1): <gurobi.Var t_0_0_1 (value 230.0)>,
#  (0, 1, 1): <gurobi.Var t_0_1_1 (value 436.0)>,
#  (0, 2, 1): <gurobi.Var t_0_2_1 (value 356.0)>,
#  (0, 3, 1): <gurobi.Var t_0_3_1 (value 395.0)>,
#  (0, 4, 1): <gurobi.Var t_0_4_1 (value 573.0)>,
#  (0, 5, 1): <gurobi.Var t_0_5_1 (value 404.0)>,
#  (0, 6, 1): <gurobi.Var t_0_6_1 (value 301.5)>,
#  (0, 7, 1): <gurobi.Var t_0_7_1 (value 355.5)>,
#  (0, 8, 1): <gurobi.Var t_0_8_1 (value 394.0)>,
#  (0, 9, 1): <gurobi.Var t_0_9_1 (value 471.0)>,
#  (0, 10, 1): <gurobi.Var t_0_10_1 (value 399.0)>,
#  (0, 11, 1): <gurobi.Var t_0_11_1 (value 511.0)>,
#  (0, 12, 1): <gurobi.Var t_0_12_1 (value 532.0)>,
#  (0, 13, 1): <gurobi.Var t_0_13_1 (value 354.0)>,
#  (0, 14, 1): <gurobi.Var t_0_14_1 (value 328.0)>,
#  (0, 15, 1): <gurobi.Var t_0_15_1 (value 415.0)>,
#  (0, 16, 1): <gurobi.Var t_0_16_1 (value 375.0)>,
#  (0, 17, 1): <gurobi.Var t_0_17_1 (value 254.5)>,
#  (0, 18, 1): <gurobi.Var t_0_18_1 (value 583.0)>,
#  (0, 19, 1): <gurobi.Var t_0_19_1 (value 362.0)>,
#  (0, 20, 1): <gurobi.Var t_0_20_1 (value 249.0)>,
#  (0, 21, 1): <gurobi.Var t_0_21_1 (value 470.0)>,
#  (0, 0, 2): <gurobi.Var t_0_0_2 (value 470.0)>,
#  (0, 1, 2): <gurobi.Var t_0_1_2 (value 436.0)>,
#  (0, 2, 2): <gurobi.Var t_0_2_2 (value 356.0)>,
#  (0, 3, 2): <gurobi.Var t_0_3_2 (value 395.0)>,
#  (0, 4, 2): <gurobi.Var t_0_4_2 (value 573.0)>,
#  (0, 5, 2): <gurobi.Var t_0_5_2 (value 404.0)>,
#  (0, 6, 2): <gurobi.Var t_0_6_2 (value 522.0)>,
#  (0, 7, 2): <gurobi.Var t_0_7_2 (value 506.0)>,
#  (0, 8, 2): <gurobi.Var t_0_8_2 (value 394.0)>,
#  (0, 9, 2): <gurobi.Var t_0_9_2 (value 471.0)>,
#  (0, 10, 2): <gurobi.Var t_0_10_2 (value 399.0)>,
#  (0, 11, 2): <gurobi.Var t_0_11_2 (value 511.0)>,
#  (0, 12, 2): <gurobi.Var t_0_12_2 (value 532.0)>,
#  (0, 13, 2): <gurobi.Var t_0_13_2 (value 354.0)>,
#  (0, 14, 2): <gurobi.Var t_0_14_2 (value 328.0)>,
#  (0, 15, 2): <gurobi.Var t_0_15_2 (value 415.0)>,
#  (0, 16, 2): <gurobi.Var t_0_16_2 (value 375.0)>,
#  (0, 17, 2): <gurobi.Var t_0_17_2 (value 375.0)>,
#  (0, 18, 2): <gurobi.Var t_0_18_2 (value 583.0)>,
#  (0, 19, 2): <gurobi.Var t_0_19_2 (value 362.0)>,
#  (0, 20, 2): <gurobi.Var t_0_20_2 (value 249.0)>,
#  (0, 21, 2): <gurobi.Var t_0_21_2 (value 470.0)>,
#  (0, 0, 3): <gurobi.Var t_0_0_3 (value 470.0)>,
#  (0, 1, 3): <gurobi.Var t_0_1_3 (value 436.0)>,
#  (0, 2, 3): <gurobi.Var t_0_2_3 (value 356.0)>,
#  (0, 3, 3): <gurobi.Var t_0_3_3 (value 395.0)>,
#  (0, 4, 3): <gurobi.Var t_0_4_3 (value 500.5)>,
#  (0, 5, 3): <gurobi.Var t_0_5_3 (value 404.0)>,
#  (0, 6, 3): <gurobi.Var t_0_6_3 (value 522.0)>,
#  (0, 7, 3): <gurobi.Var t_0_7_3 (value 506.0)>,
#  (0, 8, 3): <gurobi.Var t_0_8_3 (value 394.0)>,
#  (0, 9, 3): <gurobi.Var t_0_9_3 (value 471.0)>,
#  (0, 10, 3): <gurobi.Var t_0_10_3 (value 399.0)>,
#  (0, 11, 3): <gurobi.Var t_0_11_3 (value 511.0)>,
#  (0, 12, 3): <gurobi.Var t_0_12_3 (value 532.0)>,
#  (0, 13, 3): <gurobi.Var t_0_13_3 (value 0.0)>,
#  (0, 14, 3): <gurobi.Var t_0_14_3 (value 328.0)>,
#  (0, 15, 3): <gurobi.Var t_0_15_3 (value 0.0)>,
#  (0, 16, 3): <gurobi.Var t_0_16_3 (value 375.0)>,
#  (0, 17, 3): <gurobi.Var t_0_17_3 (value 375.0)>,
#  (0, 18, 3): <gurobi.Var t_0_18_3 (value 583.0)>,
#  (0, 19, 3): <gurobi.Var t_0_19_3 (value 362.0)>,
#  (0, 20, 3): <gurobi.Var t_0_20_3 (value 249.0)>,
#  (0, 21, 3): <gurobi.Var t_0_21_3 (value 601.0)>,
#  (1, 0, 0): <gurobi.Var t_1_0_0 (value 0.0)>,
#  (1, 1, 0): <gurobi.Var t_1_1_0 (value 29.0)>,
#  (1, 2, 0): <gurobi.Var t_1_2_0 (value 165.0)>,
#  (1, 3, 0): <gurobi.Var t_1_3_0 (value 4.0)>,
#  (1, 4, 0): <gurobi.Var t_1_4_0 (value 61.0)>,
#  (1, 5, 0): <gurobi.Var t_1_5_0 (value 2.0)>,
#  (1, 6, 0): <gurobi.Var t_1_6_0 (value 41.0)>,
#  (1, 7, 0): <gurobi.Var t_1_7_0 (value 31.0)>,
#  (1, 8, 0): <gurobi.Var t_1_8_0 (value 43.0)>,
#  (1, 9, 0): <gurobi.Var t_1_9_0 (value 68.0)>,
#  (1, 10, 0): <gurobi.Var t_1_10_0 (value 0.0)>,
#  (1, 11, 0): <gurobi.Var t_1_11_0 (value 53.0)>,
#  (1, 12, 0): <gurobi.Var t_1_12_0 (value 65.0)>,
#  (1, 13, 0): <gurobi.Var t_1_13_0 (value 4.0)>,
#  (1, 14, 0): <gurobi.Var t_1_14_0 (value 0.0)>,
#  (1, 15, 0): <gurobi.Var t_1_15_0 (value 0.0)>,
#  (1, 16, 0): <gurobi.Var t_1_16_0 (value 40.0)>,
#  (1, 17, 0): <gurobi.Var t_1_17_0 (value 49.0)>,
#  (1, 18, 0): <gurobi.Var t_1_18_0 (value 73.0)>,
#  (1, 19, 0): <gurobi.Var t_1_19_0 (value 0.0)>,
#  (1, 20, 0): <gurobi.Var t_1_20_0 (value 34.0)>,
#  (1, 21, 0): <gurobi.Var t_1_21_0 (value 288.0)>,
#  (1, 0, 1): <gurobi.Var t_1_0_1 (value 288.0)>,
#  (1, 1, 1): <gurobi.Var t_1_1_1 (value 436.0)>,
#  (1, 2, 1): <gurobi.Var t_1_2_1 (value 356.0)>,
#  (1, 3, 1): <gurobi.Var t_1_3_1 (value 395.0)>,
#  (1, 4, 1): <gurobi.Var t_1_4_1 (value 573.0)>,
#  (1, 5, 1): <gurobi.Var t_1_5_1 (value 404.0)>,
#  (1, 6, 1): <gurobi.Var t_1_6_1 (value 522.0)>,
#  (1, 7, 1): <gurobi.Var t_1_7_1 (value 506.0)>,
#  (1, 8, 1): <gurobi.Var t_1_8_1 (value 394.0)>,
#  (1, 9, 1): <gurobi.Var t_1_9_1 (value 471.0)>,
#  (1, 10, 1): <gurobi.Var t_1_10_1 (value 399.0)>,
#  (1, 11, 1): <gurobi.Var t_1_11_1 (value 511.0)>,
#  (1, 12, 1): <gurobi.Var t_1_12_1 (value 532.0)>,
#  (1, 13, 1): <gurobi.Var t_1_13_1 (value 354.0)>,
#  (1, 14, 1): <gurobi.Var t_1_14_1 (value 328.0)>,
#  (1, 15, 1): <gurobi.Var t_1_15_1 (value 415.0)>,
#  (1, 16, 1): <gurobi.Var t_1_16_1 (value 375.0)>,
#  (1, 17, 1): <gurobi.Var t_1_17_1 (value 375.0)>,
#  (1, 18, 1): <gurobi.Var t_1_18_1 (value 583.0)>,
#  (1, 19, 1): <gurobi.Var t_1_19_1 (value 362.0)>,
#  (1, 20, 1): <gurobi.Var t_1_20_1 (value 235.0)>,
#  (1, 21, 1): <gurobi.Var t_1_21_1 (value 288.0)>,
#  (1, 0, 2): <gurobi.Var t_1_0_2 (value 288.0)>,
#  (1, 1, 2): <gurobi.Var t_1_1_2 (value 436.0)>,
#  (1, 2, 2): <gurobi.Var t_1_2_2 (value 356.0)>,
#  (1, 3, 2): <gurobi.Var t_1_3_2 (value 395.0)>,
#  (1, 4, 2): <gurobi.Var t_1_4_2 (value 573.0)>,
#  (1, 5, 2): <gurobi.Var t_1_5_2 (value 336.0)>,
#  (1, 6, 2): <gurobi.Var t_1_6_2 (value 522.0)>,
#  (1, 7, 2): <gurobi.Var t_1_7_2 (value 506.0)>,
#  (1, 8, 2): <gurobi.Var t_1_8_2 (value 394.0)>,
#  (1, 9, 2): <gurobi.Var t_1_9_2 (value 471.0)>,
#  (1, 10, 2): <gurobi.Var t_1_10_2 (value 399.0)>,
#  (1, 11, 2): <gurobi.Var t_1_11_2 (value 511.0)>,
#  (1, 12, 2): <gurobi.Var t_1_12_2 (value 532.0)>,
#  (1, 13, 2): <gurobi.Var t_1_13_2 (value 0.0)>,
#  (1, 14, 2): <gurobi.Var t_1_14_2 (value 328.0)>,
#  (1, 15, 2): <gurobi.Var t_1_15_2 (value 399.0)>,
#  (1, 16, 2): <gurobi.Var t_1_16_2 (value 375.0)>,
#  (1, 17, 2): <gurobi.Var t_1_17_2 (value 375.0)>,
#  (1, 18, 2): <gurobi.Var t_1_18_2 (value 583.0)>,
#  (1, 19, 2): <gurobi.Var t_1_19_2 (value 362.0)>,
#  (1, 20, 2): <gurobi.Var t_1_20_2 (value 249.0)>,
#  (1, 21, 2): <gurobi.Var t_1_21_2 (value 555.0)>,
#  (1, 0, 3): <gurobi.Var t_1_0_3 (value 555.0)>,
#  (1, 1, 3): <gurobi.Var t_1_1_3 (value 436.0)>,
#  (1, 2, 3): <gurobi.Var t_1_2_3 (value 356.0)>,
#  (1, 3, 3): <gurobi.Var t_1_3_3 (value 395.0)>,
#  (1, 4, 3): <gurobi.Var t_1_4_3 (value 573.0)>,
#  (1, 5, 3): <gurobi.Var t_1_5_3 (value 404.0)>,
#  (1, 6, 3): <gurobi.Var t_1_6_3 (value 522.0)>,
#  (1, 7, 3): <gurobi.Var t_1_7_3 (value 506.0)>,
#  (1, 8, 3): <gurobi.Var t_1_8_3 (value 394.0)>,
#  (1, 9, 3): <gurobi.Var t_1_9_3 (value 471.0)>,
#  (1, 10, 3): <gurobi.Var t_1_10_3 (value 399.0)>,
#  (1, 11, 3): <gurobi.Var t_1_11_3 (value 511.0)>,
#  (1, 12, 3): <gurobi.Var t_1_12_3 (value 620.0)>,
#  (1, 13, 3): <gurobi.Var t_1_13_3 (value 354.0)>,
#  (1, 14, 3): <gurobi.Var t_1_14_3 (value 328.0)>,
#  (1, 15, 3): <gurobi.Var t_1_15_3 (value 415.0)>,
#  (1, 16, 3): <gurobi.Var t_1_16_3 (value 375.0)>,
#  (1, 17, 3): <gurobi.Var t_1_17_3 (value 375.0)>,
#  (1, 18, 3): <gurobi.Var t_1_18_3 (value 583.0)>,
#  (1, 19, 3): <gurobi.Var t_1_19_3 (value 362.0)>,
#  (1, 20, 3): <gurobi.Var t_1_20_3 (value 249.0)>,
#  (1, 21, 3): <gurobi.Var t_1_21_3 (value 784.0)>,
#  (2, 0, 0): <gurobi.Var t_2_0_0 (value 0.0)>,
#  (2, 1, 0): <gurobi.Var t_2_1_0 (value 17.5)>,
#  (2, 2, 0): <gurobi.Var t_2_2_0 (value 7.0)>,
#  (2, 3, 0): <gurobi.Var t_2_3_0 (value 8.0)>,
#  (2, 4, 0): <gurobi.Var t_2_4_0 (value 8.5)>,
#  (2, 5, 0): <gurobi.Var t_2_5_0 (value 6.0)>,
#  (2, 6, 0): <gurobi.Var t_2_6_0 (value 24.5)>,
#  (2, 7, 0): <gurobi.Var t_2_7_0 (value 19.5)>,
#  (2, 8, 0): <gurobi.Var t_2_8_0 (value 26.5)>,
#  (2, 9, 0): <gurobi.Var t_2_9_0 (value 13.0)>,
#  (2, 10, 0): <gurobi.Var t_2_10_0 (value 6.5)>,
#  (2, 11, 0): <gurobi.Var t_2_11_0 (value 22.5)>,
#  (2, 12, 0): <gurobi.Var t_2_12_0 (value 12.5)>,
#  (2, 13, 0): <gurobi.Var t_2_13_0 (value 0.0)>,
#  (2, 14, 0): <gurobi.Var t_2_14_0 (value 0.0)>,
#  (2, 15, 0): <gurobi.Var t_2_15_0 (value 5.0)>,
#  (2, 16, 0): <gurobi.Var t_2_16_0 (value 1.0)>,
#  (2, 17, 0): <gurobi.Var t_2_17_0 (value 9.5)>,
#  (2, 18, 0): <gurobi.Var t_2_18_0 (value 14.5)>,
#  (2, 19, 0): <gurobi.Var t_2_19_0 (value 0.0)>,
#  (2, 20, 0): <gurobi.Var t_2_20_0 (value 0.0)>,
#  (2, 21, 0): <gurobi.Var t_2_21_0 (value 136.0)>,
#  (2, 0, 1): <gurobi.Var t_2_0_1 (value 136.0)>,
#  (2, 1, 1): <gurobi.Var t_2_1_1 (value 436.0)>,
#  (2, 2, 1): <gurobi.Var t_2_2_1 (value 356.0)>,
#  (2, 3, 1): <gurobi.Var t_2_3_1 (value 395.0)>,
#  (2, 4, 1): <gurobi.Var t_2_4_1 (value 573.0)>,
#  (2, 5, 1): <gurobi.Var t_2_5_1 (value 404.0)>,
#  (2, 6, 1): <gurobi.Var t_2_6_1 (value 522.0)>,
#  (2, 7, 1): <gurobi.Var t_2_7_1 (value 506.0)>,
#  (2, 8, 1): <gurobi.Var t_2_8_1 (value 394.0)>,
#  (2, 9, 1): <gurobi.Var t_2_9_1 (value 471.0)>,
#  (2, 10, 1): <gurobi.Var t_2_10_1 (value 399.0)>,
#  (2, 11, 1): <gurobi.Var t_2_11_1 (value 511.0)>,
#  (2, 12, 1): <gurobi.Var t_2_12_1 (value 532.0)>,
#  (2, 13, 1): <gurobi.Var t_2_13_1 (value 354.0)>,
#  (2, 14, 1): <gurobi.Var t_2_14_1 (value 328.0)>,
#  (2, 15, 1): <gurobi.Var t_2_15_1 (value 415.0)>,
#  (2, 16, 1): <gurobi.Var t_2_16_1 (value 375.0)>,
#  (2, 17, 1): <gurobi.Var t_2_17_1 (value 375.0)>,
#  (2, 18, 1): <gurobi.Var t_2_18_1 (value 583.0)>,
#  (2, 19, 1): <gurobi.Var t_2_19_1 (value 147.0)>,
#  (2, 20, 1): <gurobi.Var t_2_20_1 (value 249.0)>,
#  (2, 21, 1): <gurobi.Var t_2_21_1 (value 253.0)>,
#  (2, 0, 2): <gurobi.Var t_2_0_2 (value 253.0)>,
#  (2, 1, 2): <gurobi.Var t_2_1_2 (value 436.0)>,
#  (2, 2, 2): <gurobi.Var t_2_2_2 (value 356.0)>,
#  (2, 3, 2): <gurobi.Var t_2_3_2 (value 395.0)>,
#  (2, 4, 2): <gurobi.Var t_2_4_2 (value 573.0)>,
#  (2, 5, 2): <gurobi.Var t_2_5_2 (value 404.0)>,
#  (2, 6, 2): <gurobi.Var t_2_6_2 (value 522.0)>,
#  (2, 7, 2): <gurobi.Var t_2_7_2 (value 506.0)>,
#  (2, 8, 2): <gurobi.Var t_2_8_2 (value 282.5)>,
#  (2, 9, 2): <gurobi.Var t_2_9_2 (value 471.0)>,
#  (2, 10, 2): <gurobi.Var t_2_10_2 (value 399.0)>,
#  (2, 11, 2): <gurobi.Var t_2_11_2 (value 511.0)>,
#  (2, 12, 2): <gurobi.Var t_2_12_2 (value 532.0)>,
#  (2, 13, 2): <gurobi.Var t_2_13_2 (value 354.0)>,
#  (2, 14, 2): <gurobi.Var t_2_14_2 (value 328.0)>,
#  (2, 15, 2): <gurobi.Var t_2_15_2 (value 415.0)>,
#  (2, 16, 2): <gurobi.Var t_2_16_2 (value 375.0)>,
#  (2, 17, 2): <gurobi.Var t_2_17_2 (value 375.0)>,
#  (2, 18, 2): <gurobi.Var t_2_18_2 (value 583.0)>,
#  (2, 19, 2): <gurobi.Var t_2_19_2 (value 362.0)>,
#  (2, 20, 2): <gurobi.Var t_2_20_2 (value 249.0)>,
#  (2, 21, 2): <gurobi.Var t_2_21_2 (value 351.0)>,
#  (2, 0, 3): <gurobi.Var t_2_0_3 (value 351.0)>,
#  (2, 1, 3): <gurobi.Var t_2_1_3 (value 436.0)>,
#  (2, 2, 3): <gurobi.Var t_2_2_3 (value 356.0)>,
#  (2, 3, 3): <gurobi.Var t_2_3_3 (value 395.0)>,
#  (2, 4, 3): <gurobi.Var t_2_4_3 (value 573.0)>,
#  (2, 5, 3): <gurobi.Var t_2_5_3 (value 0.0)>,
#  (2, 6, 3): <gurobi.Var t_2_6_3 (value 522.0)>,
#  (2, 7, 3): <gurobi.Var t_2_7_3 (value 506.0)>,
#  (2, 8, 3): <gurobi.Var t_2_8_3 (value 394.0)>,
#  (2, 9, 3): <gurobi.Var t_2_9_3 (value 471.0)>,
#  (2, 10, 3): <gurobi.Var t_2_10_3 (value 482.5)>,
#  (2, 11, 3): <gurobi.Var t_2_11_3 (value 511.0)>,
#  (2, 12, 3): <gurobi.Var t_2_12_3 (value 532.0)>,
#  (2, 13, 3): <gurobi.Var t_2_13_3 (value 354.0)>,
#  (2, 14, 3): <gurobi.Var t_2_14_3 (value 328.0)>,
#  (2, 15, 3): <gurobi.Var t_2_15_3 (value 415.0)>,
#  (2, 16, 3): <gurobi.Var t_2_16_3 (value 375.0)>,
#  (2, 17, 3): <gurobi.Var t_2_17_3 (value 375.0)>,
#  (2, 18, 3): <gurobi.Var t_2_18_3 (value 387.5)>,
#  (2, 19, 3): <gurobi.Var t_2_19_3 (value 362.0)>,
#  (2, 20, 3): <gurobi.Var t_2_20_3 (value 249.0)>,
#  (2, 21, 3): <gurobi.Var t_2_21_3 (value 613.0)>,
#  (3, 0, 0): <gurobi.Var t_3_0_0 (value 0.0)>,
#  (3, 1, 0): <gurobi.Var t_3_1_0 (value 17.5)>,
#  (3, 2, 0): <gurobi.Var t_3_2_0 (value 7.0)>,
#  (3, 3, 0): <gurobi.Var t_3_3_0 (value 2.0)>,
#  (3, 4, 0): <gurobi.Var t_3_4_0 (value 8.5)>,
#  (3, 5, 0): <gurobi.Var t_3_5_0 (value 6.0)>,
#  (3, 6, 0): <gurobi.Var t_3_6_0 (value 24.5)>,
#  (3, 7, 0): <gurobi.Var t_3_7_0 (value 19.5)>,
#  (3, 8, 0): <gurobi.Var t_3_8_0 (value 26.5)>,
#  (3, 9, 0): <gurobi.Var t_3_9_0 (value 34.0)>,
#  (3, 10, 0): <gurobi.Var t_3_10_0 (value 6.5)>,
#  (3, 11, 0): <gurobi.Var t_3_11_0 (value 22.5)>,
#  (3, 12, 0): <gurobi.Var t_3_12_0 (value 12.5)>,
#  (3, 13, 0): <gurobi.Var t_3_13_0 (value 2.0)>,
#  (3, 14, 0): <gurobi.Var t_3_14_0 (value 4.0)>,
#  (3, 15, 0): <gurobi.Var t_3_15_0 (value 1.0)>,
#  (3, 16, 0): <gurobi.Var t_3_16_0 (value 1.0)>,
#  (3, 17, 0): <gurobi.Var t_3_17_0 (value 2.5)>,
#  (3, 18, 0): <gurobi.Var t_3_18_0 (value 14.5)>,
#  (3, 19, 0): <gurobi.Var t_3_19_0 (value 0.0)>,
#  (3, 20, 0): <gurobi.Var t_3_20_0 (value 0.0)>,
#  (3, 21, 0): <gurobi.Var t_3_21_0 (value 953.5)>,
#  (3, 0, 1): <gurobi.Var t_3_0_1 (value 953.5)>,
#  (3, 1, 1): <gurobi.Var t_3_1_1 (value 436.0)>,
#  (3, 2, 1): <gurobi.Var t_3_2_1 (value 356.0)>,
#  (3, 3, 1): <gurobi.Var t_3_3_1 (value 395.0)>,
#  (3, 4, 1): <gurobi.Var t_3_4_1 (value 573.0)>,
#  (3, 5, 1): <gurobi.Var t_3_5_1 (value 404.0)>,
#  (3, 6, 1): <gurobi.Var t_3_6_1 (value 522.0)>,
#  (3, 7, 1): <gurobi.Var t_3_7_1 (value 506.0)>,
#  (3, 8, 1): <gurobi.Var t_3_8_1 (value 394.0)>,
#  (3, 9, 1): <gurobi.Var t_3_9_1 (value 471.0)>,
#  (3, 10, 1): <gurobi.Var t_3_10_1 (value 399.0)>,
#  (3, 11, 1): <gurobi.Var t_3_11_1 (value 511.0)>,
#  (3, 12, 1): <gurobi.Var t_3_12_1 (value 532.0)>,
#  (3, 13, 1): <gurobi.Var t_3_13_1 (value 354.0)>,
#  (3, 14, 1): <gurobi.Var t_3_14_1 (value 328.0)>,
#  (3, 15, 1): <gurobi.Var t_3_15_1 (value 415.0)>,
#  (3, 16, 1): <gurobi.Var t_3_16_1 (value 375.0)>,
#  (3, 17, 1): <gurobi.Var t_3_17_1 (value 375.0)>,
#  (3, 18, 1): <gurobi.Var t_3_18_1 (value 583.0)>,
#  (3, 19, 1): <gurobi.Var t_3_19_1 (value 362.0)>,
#  (3, 20, 1): <gurobi.Var t_3_20_1 (value 249.0)>,
#  (3, 21, 1): <gurobi.Var t_3_21_1 (value 1232.0)>,
#  (3, 0, 2): <gurobi.Var t_3_0_2 (value 1232.0)>,
#  (3, 1, 2): <gurobi.Var t_3_1_2 (value 436.0)>,
#  (3, 2, 2): <gurobi.Var t_3_2_2 (value 356.0)>,
#  (3, 3, 2): <gurobi.Var t_3_3_2 (value 395.0)>,
#  (3, 4, 2): <gurobi.Var t_3_4_2 (value 573.0)>,
#  (3, 5, 2): <gurobi.Var t_3_5_2 (value 404.0)>,
#  (3, 6, 2): <gurobi.Var t_3_6_2 (value 522.0)>,
#  (3, 7, 2): <gurobi.Var t_3_7_2 (value 506.0)>,
#  (3, 8, 2): <gurobi.Var t_3_8_2 (value 394.0)>,
#  (3, 9, 2): <gurobi.Var t_3_9_2 (value 471.0)>,
#  (3, 10, 2): <gurobi.Var t_3_10_2 (value 399.0)>,
#  (3, 11, 2): <gurobi.Var t_3_11_2 (value 511.0)>,
#  (3, 12, 2): <gurobi.Var t_3_12_2 (value 532.0)>,
#  (3, 13, 2): <gurobi.Var t_3_13_2 (value 354.0)>,
#  (3, 14, 2): <gurobi.Var t_3_14_2 (value 328.0)>,
#  (3, 15, 2): <gurobi.Var t_3_15_2 (value 415.0)>,
#  (3, 16, 2): <gurobi.Var t_3_16_2 (value 375.0)>,
#  (3, 17, 2): <gurobi.Var t_3_17_2 (value 375.0)>,
#  (3, 18, 2): <gurobi.Var t_3_18_2 (value 583.0)>,
#  (3, 19, 2): <gurobi.Var t_3_19_2 (value 362.0)>,
#  (3, 20, 2): <gurobi.Var t_3_20_2 (value 249.0)>,
#  (3, 21, 2): <gurobi.Var t_3_21_2 (value 1232.0)>,
#  (3, 0, 3): <gurobi.Var t_3_0_3 (value 1232.0)>,
#  (3, 1, 3): <gurobi.Var t_3_1_3 (value 436.0)>,
#  (3, 2, 3): <gurobi.Var t_3_2_3 (value 356.0)>,
#  (3, 3, 3): <gurobi.Var t_3_3_3 (value 395.0)>,
#  (3, 4, 3): <gurobi.Var t_3_4_3 (value 573.0)>,
#  (3, 5, 3): <gurobi.Var t_3_5_3 (value 404.0)>,
#  (3, 6, 3): <gurobi.Var t_3_6_3 (value 522.0)>,
#  (3, 7, 3): <gurobi.Var t_3_7_3 (value 506.0)>,
#  (3, 8, 3): <gurobi.Var t_3_8_3 (value 394.0)>,
#  (3, 9, 3): <gurobi.Var t_3_9_3 (value 471.0)>,
#  (3, 10, 3): <gurobi.Var t_3_10_3 (value 399.0)>,
#  (3, 11, 3): <gurobi.Var t_3_11_3 (value 511.0)>,
#  (3, 12, 3): <gurobi.Var t_3_12_3 (value 532.0)>,
#  (3, 13, 3): <gurobi.Var t_3_13_3 (value 354.0)>,
#  (3, 14, 3): <gurobi.Var t_3_14_3 (value 328.0)>,
#  (3, 15, 3): <gurobi.Var t_3_15_3 (value 415.0)>,
#  (3, 16, 3): <gurobi.Var t_3_16_3 (value 375.0)>,
#  (3, 17, 3): <gurobi.Var t_3_17_3 (value 375.0)>,
#  (3, 18, 3): <gurobi.Var t_3_18_3 (value 583.0)>,
#  (3, 19, 3): <gurobi.Var t_3_19_3 (value 362.0)>,
#  (3, 20, 3): <gurobi.Var t_3_20_3 (value 249.0)>,
#  (3, 21, 3): <gurobi.Var t_3_21_3 (value 1232.0)>,
#  (4, 0, 0): <gurobi.Var t_4_0_0 (value 0.0)>,
#  (4, 1, 0): <gurobi.Var t_4_1_0 (value 27.5)>,
#  (4, 2, 0): <gurobi.Var t_4_2_0 (value 4.0)>,
#  (4, 3, 0): <gurobi.Var t_4_3_0 (value 2.0)>,
#  (4, 4, 0): <gurobi.Var t_4_4_0 (value 4.5)>,
#  (4, 5, 0): <gurobi.Var t_4_5_0 (value 1.0)>,
#  (4, 6, 0): <gurobi.Var t_4_6_0 (value 20.5)>,
#  (4, 7, 0): <gurobi.Var t_4_7_0 (value 15.5)>,
#  (4, 8, 0): <gurobi.Var t_4_8_0 (value 21.5)>,
#  (4, 9, 0): <gurobi.Var t_4_9_0 (value 13.0)>,
#  (4, 10, 0): <gurobi.Var t_4_10_0 (value 6.5)>,
#  (4, 11, 0): <gurobi.Var t_4_11_0 (value 102.5)>,
#  (4, 12, 0): <gurobi.Var t_4_12_0 (value 12.5)>,
#  (4, 13, 0): <gurobi.Var t_4_13_0 (value 2.0)>,
#  (4, 14, 0): <gurobi.Var t_4_14_0 (value 4.0)>,
#  (4, 15, 0): <gurobi.Var t_4_15_0 (value 0.0)>,
#  (4, 16, 0): <gurobi.Var t_4_16_0 (value 1.0)>,
#  (4, 17, 0): <gurobi.Var t_4_17_0 (value 0.0)>,
#  (4, 18, 0): <gurobi.Var t_4_18_0 (value 2.5)>,
#  (4, 19, 0): <gurobi.Var t_4_19_0 (value 0.0)>,
#  (4, 20, 0): <gurobi.Var t_4_20_0 (value 0.0)>,
#  (4, 21, 0): <gurobi.Var t_4_21_0 (value 977.0)>,
#  (4, 0, 1): <gurobi.Var t_4_0_1 (value 977.0)>,
#  (4, 1, 1): <gurobi.Var t_4_1_1 (value 436.0)>,
#  (4, 2, 1): <gurobi.Var t_4_2_1 (value 356.0)>,
#  (4, 3, 1): <gurobi.Var t_4_3_1 (value 395.0)>,
#  (4, 4, 1): <gurobi.Var t_4_4_1 (value 573.0)>,
#  (4, 5, 1): <gurobi.Var t_4_5_1 (value 404.0)>,
#  (4, 6, 1): <gurobi.Var t_4_6_1 (value 522.0)>,
#  (4, 7, 1): <gurobi.Var t_4_7_1 (value 506.0)>,
#  (4, 8, 1): <gurobi.Var t_4_8_1 (value 394.0)>,
#  (4, 9, 1): <gurobi.Var t_4_9_1 (value 471.0)>,
#  (4, 10, 1): <gurobi.Var t_4_10_1 (value 399.0)>,
#  (4, 11, 1): <gurobi.Var t_4_11_1 (value 511.0)>,
#  (4, 12, 1): <gurobi.Var t_4_12_1 (value 532.0)>,
#  (4, 13, 1): <gurobi.Var t_4_13_1 (value 0.0)>,
#  (4, 14, 1): <gurobi.Var t_4_14_1 (value 0.0)>,
#  (4, 15, 1): <gurobi.Var t_4_15_1 (value 0.0)>,
#  (4, 16, 1): <gurobi.Var t_4_16_1 (value 375.0)>,
#  (4, 17, 1): <gurobi.Var t_4_17_1 (value 375.0)>,
#  (4, 18, 1): <gurobi.Var t_4_18_1 (value 583.0)>,
#  (4, 19, 1): <gurobi.Var t_4_19_1 (value 362.0)>,
#  (4, 20, 1): <gurobi.Var t_4_20_1 (value 249.0)>,
#  (4, 21, 1): <gurobi.Var t_4_21_1 (value 1232.0)>,
#  (4, 0, 2): <gurobi.Var t_4_0_2 (value 1232.0)>,
#  (4, 1, 2): <gurobi.Var t_4_1_2 (value 436.0)>,
#  (4, 2, 2): <gurobi.Var t_4_2_2 (value 356.0)>,
#  (4, 3, 2): <gurobi.Var t_4_3_2 (value 395.0)>,
#  (4, 4, 2): <gurobi.Var t_4_4_2 (value 573.0)>,
#  (4, 5, 2): <gurobi.Var t_4_5_2 (value 404.0)>,
#  (4, 6, 2): <gurobi.Var t_4_6_2 (value 522.0)>,
#  (4, 7, 2): <gurobi.Var t_4_7_2 (value 506.0)>,
#  (4, 8, 2): <gurobi.Var t_4_8_2 (value 394.0)>,
#  (4, 9, 2): <gurobi.Var t_4_9_2 (value 471.0)>,
#  (4, 10, 2): <gurobi.Var t_4_10_2 (value 399.0)>,
#  (4, 11, 2): <gurobi.Var t_4_11_2 (value 511.0)>,
#  (4, 12, 2): <gurobi.Var t_4_12_2 (value 532.0)>,
#  (4, 13, 2): <gurobi.Var t_4_13_2 (value 354.0)>,
#  (4, 14, 2): <gurobi.Var t_4_14_2 (value 328.0)>,
#  (4, 15, 2): <gurobi.Var t_4_15_2 (value 415.0)>,
#  (4, 16, 2): <gurobi.Var t_4_16_2 (value 375.0)>,
#  (4, 17, 2): <gurobi.Var t_4_17_2 (value 375.0)>,
#  (4, 18, 2): <gurobi.Var t_4_18_2 (value 583.0)>,
#  (4, 19, 2): <gurobi.Var t_4_19_2 (value 362.0)>,
#  (4, 20, 2): <gurobi.Var t_4_20_2 (value 249.0)>,
#  (4, 21, 2): <gurobi.Var t_4_21_2 (value 1232.0)>,
#  (4, 0, 3): <gurobi.Var t_4_0_3 (value 1232.0)>,
#  (4, 1, 3): <gurobi.Var t_4_1_3 (value 436.0)>,
#  (4, 2, 3): <gurobi.Var t_4_2_3 (value 356.0)>,
#  (4, 3, 3): <gurobi.Var t_4_3_3 (value 395.0)>,
#  (4, 4, 3): <gurobi.Var t_4_4_3 (value 573.0)>,
#  (4, 5, 3): <gurobi.Var t_4_5_3 (value 404.0)>,
#  (4, 6, 3): <gurobi.Var t_4_6_3 (value 522.0)>,
#  (4, 7, 3): <gurobi.Var t_4_7_3 (value 506.0)>,
#  (4, 8, 3): <gurobi.Var t_4_8_3 (value 394.0)>,
#  (4, 9, 3): <gurobi.Var t_4_9_3 (value 471.0)>,
#  (4, 10, 3): <gurobi.Var t_4_10_3 (value 399.0)>,
#  (4, 11, 3): <gurobi.Var t_4_11_3 (value 511.0)>,
#  (4, 12, 3): <gurobi.Var t_4_12_3 (value 532.0)>,
#  (4, 13, 3): <gurobi.Var t_4_13_3 (value 354.0)>,
#  (4, 14, 3): <gurobi.Var t_4_14_3 (value 328.0)>,
#  (4, 15, 3): <gurobi.Var t_4_15_3 (value 415.0)>,
#  (4, 16, 3): <gurobi.Var t_4_16_3 (value 375.0)>,
#  (4, 17, 3): <gurobi.Var t_4_17_3 (value 375.0)>,
#  (4, 18, 3): <gurobi.Var t_4_18_3 (value 583.0)>,
#  (4, 19, 3): <gurobi.Var t_4_19_3 (value 362.0)>,
#  (4, 20, 3): <gurobi.Var t_4_20_3 (value 249.0)>,
#  (4, 21, 3): <gurobi.Var t_4_21_3 (value 1232.0)>}

# %%
for k in K:
    for r in range(T_max[k]):
        for i in N_s_t:
            for j in N_s_t:
                if i != j and x[k,i,j,r].x > 0.5:
                    print(k,r,i,j)
# Out:
# 0 0 0 14
# 0 0 13 20
# 0 0 14 13
# 0 0 20 21
# 0 0 21 3
# 0 0 21 6
# 0 0 21 7
# 0 0 21 8
# 0 0 21 9
# 0 0 21 11
# 0 0 21 12
# 0 0 21 13
# 0 0 21 14
# 0 0 21 15
# 0 0 21 16
# 0 0 21 17
# 0 0 21 18
# 0 0 21 19
# 0 0 21 20
# 0 1 0 17
# 0 1 6 7
# 0 1 7 21
# 0 1 17 6
# 0 1 21 3
# 0 1 21 5
# 0 1 21 6
# 0 1 21 7
# 0 1 21 8
# 0 1 21 9
# 0 1 21 10
# 0 1 21 11
# 0 1 21 15
# 0 1 21 17
# 0 1 21 18
# 0 1 21 19
# 0 1 21 20
# 0 2 21 3
# 0 2 21 4
# 0 2 21 5
# 0 2 21 7
# 0 2 21 8
# 0 2 21 9
# 0 2 21 10
# 0 2 21 11
# 0 2 21 12
# 0 2 21 13
# 0 2 21 14
# 0 2 21 15
# 0 2 21 17
# 0 2 21 18
# 0 2 21 19
# 0 2 21 20
# 0 3 0 4
# 0 3 4 21
# 0 3 21 3
# 0 3 21 7
# 0 3 21 15
# 0 3 21 18
# 1 0 0 16
# 1 0 2 21
# 1 0 16 2
# 1 1 21 2
# 1 1 21 3
# 1 1 21 4
# 1 1 21 5
# 1 1 21 7
# 1 1 21 8
# 1 1 21 9
# 1 1 21 10
# 1 1 21 11
# 1 1 21 12
# 1 1 21 13
# 1 1 21 14
# 1 1 21 15
# 1 1 21 16
# 1 1 21 17
# 1 1 21 18
# 1 1 21 19
# 1 1 21 20
# 1 2 0 5
# 1 2 5 15
# 1 2 15 21
# 1 2 21 2
# 1 2 21 3
# 1 2 21 4
# 1 2 21 6
# 1 2 21 7
# 1 2 21 8
# 1 2 21 10
# 1 2 21 11
# 1 2 21 14
# 1 2 21 15
# 1 2 21 16
# 1 2 21 17
# 1 2 21 19
# 1 3 0 12
# 1 3 12 21
# 1 3 21 3
# 2 0 0 3
# 2 0 3 21
# 2 0 21 1
# 2 0 21 3
# 2 0 21 8
# 2 0 21 9
# 2 0 21 11
# 2 0 21 12
# 2 0 21 13
# 2 0 21 15
# 2 0 21 18
# 2 0 21 19
# 2 1 0 19
# 2 1 19 21
# 2 1 21 2
# 2 1 21 16
# 2 1 21 19
# 2 2 0 8
# 2 2 8 21
# 2 2 21 1
# 2 2 21 2
# 2 2 21 3
# 2 2 21 8
# 2 2 21 9
# 2 2 21 11
# 2 2 21 16
# 2 2 21 19
# 2 3 0 18
# 2 3 10 21
# 2 3 18 10
# 2 3 21 2
# 2 3 21 3
# 2 3 21 8
# 2 3 21 9
# 2 3 21 14
# 2 3 21 15
# 2 3 21 16
# 2 3 21 17
# 2 3 21 20
# 3 0 0 9
# 3 0 9 21
# 3 0 21 10
# 3 1 21 6
# 3 1 21 7
# 3 1 21 8
# 3 1 21 9
# 3 1 21 10
# 3 1 21 11
# 3 1 21 12
# 3 1 21 13
# 3 1 21 14
# 3 1 21 15
# 3 1 21 17
# 3 1 21 18
# 3 1 21 20
# 3 2 21 5
# 3 2 21 6
# 3 2 21 7
# 3 2 21 8
# 3 2 21 9
# 3 2 21 10
# 3 2 21 11
# 3 2 21 12
# 3 2 21 13
# 3 2 21 15
# 3 2 21 17
# 3 2 21 18
# 3 2 21 19
# 3 2 21 20
# 3 3 21 5
# 3 3 21 6
# 3 3 21 7
# 3 3 21 8
# 3 3 21 10
# 3 3 21 11
# 3 3 21 12
# 3 3 21 13
# 3 3 21 15
# 3 3 21 17
# 3 3 21 18
# 3 3 21 19
# 3 3 21 20
# 4 0 0 1
# 4 0 1 11
# 4 0 11 21
# 4 0 21 2
# 4 0 21 3
# 4 0 21 8
# 4 0 21 9
# 4 0 21 10
# 4 0 21 11
# 4 0 21 12
# 4 0 21 13
# 4 0 21 14
# 4 0 21 15
# 4 0 21 16
# 4 0 21 17
# 4 0 21 18
# 4 0 21 19
# 4 0 21 20
# 4 1 21 2
# 4 1 21 5
# 4 1 21 6
# 4 1 21 7
# 4 1 21 8
# 4 1 21 9
# 4 1 21 10
# 4 1 21 11
# 4 1 21 12
# 4 1 21 13
# 4 1 21 15
# 4 1 21 16
# 4 1 21 17
# 4 1 21 18
# 4 1 21 19
# 4 1 21 20
# 4 2 21 2
# 4 2 21 8
# 4 2 21 11
# 4 2 21 14
# 4 2 21 16
# 4 2 21 20
# 4 3 21 8
# 4 3 21 10
# 4 3 21 11
# 4 3 21 13
# 4 3 21 14
# 4 3 21 15
# 4 3 21 19
# 4 3 21 20

# %%
T_max[1]
# Out:
# 4
